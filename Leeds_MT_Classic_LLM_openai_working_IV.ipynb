# %% [markdown]
# <a href="https://colab.research.google.com/github/andipasti/smupo/blob/main/Leeds_MT_Classic_LLM_openai_working_IV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os



# Now you can proceed with your code that requires this environment variable

from google.colab import userdata
os.environ['HUGGINGFACE_TOKEN'] = userdata.get('HUGGINGFACE_TOKEN')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
# Loading the dataset from a JSON file
df = pd.read_json('./drive/Othercomputers/X1/code/datas.json')
display(df)
# Out:
#      issue_id                                        issue_title  \
# 0      116550  [MBA#1127156] Layout-Anpassung auf Typo 3 - We...
# 1      116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# 2      116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# 3      116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# 4      116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# ..        ...                                                ...
# 995    116165             KEN: Module freischalten [MBA#1127666]
# 996    116165             KEN: Module freischalten [MBA#1127666]
# 997    116164                            KEN: Signage einrichten
# 998    116163                        KEN: mobile App aufschalten
# 999    116163                        KEN: mobile App aufschalten
#
#                                      issue_description  journal_id  \
# 0    Guten Morgen\r\n\r\nIch habe eine eher speziel...      266857
# 1    Guten Morgen allerseits\r\n\r\nSchule: KSLZH\r...      266862
# 2    Guten Morgen allerseits\r\n\r\nSchule: KSLZH\r...      266861
# 3    Guten Morgen allerseits\r\n\r\nSchule: KSLZH\r...      266851
# 4    Guten Morgen allerseits\r\n\r\nSchule: KSLZH\r...      266847
# ..                                                 ...         ...
# 995  - Basis (AP 001)\r\n- Basis+ (AP 002) MATAR, I...      265988
# 996  - Basis (AP 001)\r\n- Basis+ (AP 002) MATAR, I...      264323
# 997        Bitte einen Beispiel-Raspi startklar machen      266525
# 998               Einfach mal alle Module freischalten      264890
# 999               Einfach mal alle Module freischalten      264884
#
#       journal_created_on                                      journal_notes  \
# 0    2024-03-25 10:02:24                                   Bist du da dran?
# 1    2024-03-25 10:28:33  > PS: Weiss man was das Problem war? LG Andrea...
# 2    2024-03-25 10:17:20  KRW Andreas Berger\r\nKSL Cseri Laszlo\r\n\r\n...
# 3    2024-03-25 09:49:46  Super danke :-)\r\n\r\nTest Servicedesk erfolg...
# 4    2024-03-25 09:40:21  Die Warteschlangen werden nun abgebaut, das Sy...
# ..                   ...                                                ...
# 995  2024-03-04 13:35:30  * Basis (AP 001) *ok*\r\n* Basis+ (AP 002)\r\n...
# 996  2024-02-02 15:04:40  * Basis (AP 001)\n* Basis+ (AP 002)\n** MATAR ...
# 997  2024-03-13 16:23:45            Raspi aufgesetzt und mit KEN verbunden.
# 998  2024-02-13 13:35:56  Super, der Benutzer wechsel klappt nun auch.\r...
# 999  2024-02-13 12:01:04              LDAP: ou und upn sind jetzt vorhanden
#
#      journal_author
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 995               0
# 996               0
# 997               0
# 998               0
# 999               0
#
# [1000 rows x 7 columns]

# %%
column_names = list(df.columns)
print(column_names)
# Out:
# ['issue_id', 'issue_title', 'issue_description', 'journal_id', 'journal_created_on', 'journal_notes', 'journal_author']

# %%
df.drop(['journal_id', 'journal_created_on', 'journal_author'], axis=1, inplace=True)

# %%
import pandas as pd

df_merged = df.groupby(['issue_id', 'issue_title', 'issue_description'])['journal_notes'].apply(lambda notes: '\n---\n'.join(notes)).reset_index()

df_merged.rename(columns={'journal_notes': 'merged_journal_notes'}, inplace=True)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# First, convert all relevant columns to string type to avoid any concatenation issues
df = df.astype(str)

# Now, group by 'issue_id' and concatenate all information into a single cell
df_merged = df.groupby('issue_id').apply(lambda x: x['issue_title'].iloc[0] + '\n---\n' +
                                         x['issue_description'].iloc[0] + '\n---\n' +
                                         '\n---\n'.join(x['journal_notes'])).reset_index(name='all_information')

df_merged
# Out:
#     issue_id                                    all_information
# 0     116163  KEN: mobile App aufschalten\n---\nEinfach mal ...
# 1     116164  KEN: Signage einrichten\n---\nBitte einen Beis...
# 2     116165  KEN: Module freischalten [MBA#1127666]\n---\n-...
# 3     116166  KST [MBA#1125513] - IN2 - Blöcke streichen/lös...
# 4     116167  KZI [MBA#1125671] - IN2 - IU-Stundenplan - bus...
# ..       ...                                                ...
# 251   116537  KZN [MBA#1128871] IM: Neues gemischtes Profil ...
# 252   116538  Fwd: [MBA#1128639] AW: Druckereinstellungen Se...
# 253   116539  KZI Miniinfo Neue Common Name Prozedur für Kur...
# 254   116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# 255   116550  [MBA#1127156] Layout-Anpassung auf Typo 3 - We...
#
# [256 rows x 2 columns]

# %%
column_names = list(df_merged.columns)
print(column_names)
# Out:
# ['issue_id', 'all_information']

# %%
# Set Pandas display options to show the full content of 'merged_journal_notes'
pd.set_option('display.max_colwidth', None)

df = df_merged
df
# Out:
#     issue_id  \
# 0     116163
# 1     116164
# 2     116165
# 3     116166
# 4     116167
# ..       ...
# 251   116537
# 252   116538
# 253   116539
# 254   116543
# 255   116550
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       all_information
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               KEN: mobile App aufschalten\n---\nEinfach mal alle Module freischalten\n---\nSuper, der Benutzer wechsel klappt nun auch.\r\nAber für das aktuelle Login bräuchten die KEN-User einen LDAP-Account, das Login über ihren Azure-Tenant geht erst mit v1.8.\n---\nLDAP: ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             KEN: Signage einrichten\n---\nBitte einen Beispiel-Raspi startklar machen\n---\nRaspi aufgesetzt und mit KEN verbunden.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         KEN: Module freischalten [MBA#1127666]\n---\n- Basis (AP 001)\r\n- Basis+ (AP 002) MATAR, IU & Micropage\r\n- Stundenplan (AP 004)\r\n- Absenzenerfassung (AP 005)\r\n- Absenzenprozesse (AP 006) \r\n- Newsletter (AP 009)\r\n- Elektronisches Klassenbuch (AP 010)\n---\n* Basis (AP 001) *ok*\r\n* Basis+ (AP 002)\r\n** MATAR *ok* https://intranet.tam.ch/ken/matar\r\n** IU *ok*\r\n** Micropage *ok*  https://intranet.tam.ch/ken/micropage\r\n* Stundenplan (AP 004) *ok*\r\n* Absenzenerfassung (AP 005)\r\n* Absenzenprozesse (AP 006) \r\n* Newsletter (AP 009) *ok* https://intranet.tam.ch/ken/newsletter\r\n* Elektronisches Klassenbuch (AP 010) *ok*\r\n\r\nDie Module sind weitgehend bereit, die konkrete Konfiguration wäre der nächste Schritt\n---\n* Basis (AP 001)\n* Basis+ (AP 002)\n** MATAR *ok* https://intranet.tam.ch/ken/matar\n** IU *ok*\n** Micropage *ok*  https://intranet.tam.ch/ken/micropage\n* Stundenplan (AP 004) *ok*\n* Absenzenerfassung (AP 005)\n* Absenzenprozesse (AP 006) \n* Newsletter (AP 009) *ok* https://intranet.tam.ch/ken/newsletter\n* Elektronisches Klassenbuch (AP 010) *ok*
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       KST [MBA#1125513] - IN2 - Blöcke streichen/löschen funktioniert nicht\n---\nHallo zusammen\r\n\r\nDas streichen von Blöcken funktioniert aktuell bei der KST nicht.\r\nDas Fenster öffnet sich zwar, man kann auch auf "Block streichen" klicken,\r\naber das Fenster schliesst sich dann und der Block ist dann nicht\r\ngelöscht/gestrichen.\r\n\r\nEvtl. hat es etwas mit diesem Ticket zu tun Incident #116149 \r\n\r\nFreundliche Grüsse\r\nDani\r\n——\r\n\r\n> \r\n> Hoi Dani\r\n> \r\n> Reservationen funktionieren wieder, Ferien-Blocks können nach wie vor nicht\r\n> verändert werden.\r\n> \r\n> LG\r\n> \r\n> Kai Homberg\r\n> \r\n>\n---\nAuf live korrigiert.\n---\nIst auf live\n---\nAuf stage korrigiert\n---\nfunktioniert\n---\nSollte auf stage gefixed sein. Kannst noch testen?\n---\nHabe es in diesem Fall in der DB gelöscht.\r\n\r\nBitte anschauen\n---\nJemand scheint Änderungen am Stundenplan unternommen zu haben. \r\nAlle Ferien können nicht mehr gelöscht werden.\n---\nHolidayID = 132, Karfreitag. Wieso lässt sich das nicht löschen?
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        KZI [MBA#1125671] - IN2 - IU-Stundenplan - busy-Lektion\n---\nHallo zusammen\r\n\r\nKönnt Ihr bitte die Lektion im Anhang für die KZI löschen? \r\n\r\nFreundliche Grüsse\r\nDani\r\n——\r\n\r\n>  Hallo Support\r\n \r\nDas in Ticket MBA#1124354 gemeldete Problem, dass im IU-Stundenplantool in\r\neinem IU-Lehrstundenplan ein «busy» Eintrag nicht gelöscht werden kann, trat\r\nnun wieder auf:\r\nImmerhin weiss ich unterdessen, wie das passiert: Wenn man den Stundenplan\r\neines Schülers eingblendet hat und dann dort auf eine frei Lektion klickt,\r\nerscheint nachher im Lehrerstundenplan eine «busy» Lektion.\r\nSo geschehen bei LP roger.ruetti.kzi - s. Beilage\r\nBitte diese Lektion löschen oder mir mitteilen, wie ich das erledigen kann.\r\n \r\nLieben Gruss Daniel Stucki\n---\nDas ist eine der Grundfunktionen des IU-Planners: Will man bei einem Schüler zusätzlich zum Grundstundenplan eine Lektion sperren, klickt man im Schülerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.\r\n\r\n(Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt :-) )
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  KZN [MBA#1128871] IM: Neues gemischtes Profil N/PPP\n---\nHallo zusammen\r\n\r\nBitte das neue Profil erfassen.\r\n\r\nVielen Dank im voraus\r\nGruess\r\nRoman\r\n  > Geschätztes Support-Team  \r\n> \r\n> Aufgrund der sich abzeichnenden Klasseneinteilung für das nächste Schuljahr\r\n> braucht die KZN neu das gemischte Profil Neusprachlich/PPP, das wir hiermit\r\n> gerne bestellen würden.\r\n> \r\n> LG\r\n> \r\n> Giusi\r\n> \r\n>\n---\nDas Profil N/PPP steht jetzt zur Auswahl
# 252                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Fwd: [MBA#1128639] AW: Druckereinstellungen Sekretariat KFR\n---\nHallo\r\n\r\nSeit der Umstellung auf Leunet hat die KFR Schwierigkeiten beim Drucken mit\r\ndem Drucker Canon ImageRunner Advance  C5560i, IP: 10.95.36.110\r\nDie Probleme treten nur in der VDI auf. Jedes Mal, wenn sie drucken wollen,\r\nmüssen sie zuerst den Drucker in der Liste anwählen, da dieser nicht als\r\nStandard eingestellt ist und es müssen auch alle weiteren Einstellungen wie\r\n«einseitig drucken» neu ausgewählt werden. Ausserdem druckt es immer nur ein\r\nExemplar aus, auch wenn man die Anzahl der Exemplare anpasst. Das Papierfach\r\nwird ebenfalls willkürlich ausgewählt. Habt ihr eine Idee wie man das beheben\r\nkönnte? Ihr könnt gerne etwas versuchen und wir testen das dann. Falls ihr\r\nnoch mehr Infos benötigt, dann liefere ich diese gerne nach. Danke!\r\n\r\nVG\r\nMax\n---\nSali,\r\n\r\nBitte kurz folgenden Drucker hinzufügen und testen:\r\n\\print002.mbazh.ch\KFR: Canon iR-ADV C5550-5560 PCL6.2\r\n\r\nUm die Liste für den Standard Drucker zu prüfen, benötige ich noch die Namen derjenigen, welche den als Standard hinterlegt haben sollten.\r\nDie Drucker sind normalerweise eingestellt Doppelseitig zu drucken, kann ich aber ändern.\r\nAuch das Papierfach kann ich anpassen, die Auswahl besteht hier aus Auto, Mehrzweck-Fach, Einzug 1, Einzug 2.\r\n\r\nGruss\r\nMartin\r\n\r\n\n---\nIst der Drucker in der Tabelle eingetragen?
# 253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            KZI Miniinfo Neue Common Name Prozedur für Kurse [MBA#1128844]\n---\nNach Rücksprache mit den MV verstehe ich, dass die Anleitung "CommonNames"\r\nnicht ohne eine weitere Installation einer Prozedur greift, deshalb gebe ich\r\ndas Ticket nun mit dem Auftrag zur untigen Anfrage von Daniel Stucki\r\n\r\nIch bitte um Installation der neuen MiniInfo-Prozedur zum Setzen der Common\r\nNames und Kurslabels auf KURSEN - wenn möglich im Ordner «Common Names».\r\nDie neue Prozedur zum Setzen der cn auf Klassen habe ich bereits installiert.\n---\nDie Prozeduren für CN und Labels sind bei allen Schulen vorhanden. An der KZI muss einfach noch spr_TAMMI_set_commonname_on_course im MiniInfo administriert werden (=> Roman, Danijel?)
# 254  [MBA#1128940] Zimbra Störung komplette Schule: E-Mails senden und empfangen (kslzh.ch) funktioniert nicht\n---\nGuten Morgen allerseits\r\n\r\nSchule: KSLZH\r\nMelder: Laszlo Cseri\r\n\r\nProblem Zimbra:\r\n\r\nWir (kslzh.ch) können keine E-Mails senden (auch Mails von GMX und icloud.com versendet) und empfangen. Im Webmail erhalten wir folgende Hinweise beim versenden von E-Mails:\r\n\r\n!clipboard-202403250751-h8l4i.png!\r\n\r\n!clipboard-202403250751-h6e8a.png!\r\n\r\nEine Überprüfung mit MXToolbox zeigt bei einem SMTP-Check folgendes an: \r\n\r\n!clipboard-202403250751-2pdnb.png!\r\n\r\nDürfen wir euch bitten, das Problem sofort zu beheben?\r\n\r\nNachtrag: Bei meinen Recherchen habe ich festgestellt, dass es auch die stud.kslzh.ch-Domain auch betrifft:\r\n\r\n!clipboard-202403250752-fxdsc.png!\r\n\n---\n> PS: Weiss man was das Problem war? LG Andreas Stössel\r\nIm Detail nicht.  Die Kommunikation zwischen MTA und Edge-Server war gestört, aber man sieht nicht, was das ausgelöst hat.\r\n(Das System ist schon länger im EoL-Status, wir investieren keine Zeit mehr in Fehlersuche)\r\n\r\n\n---\nKRW Andreas Berger\r\nKSL Cseri Laszlo\r\n\r\nRückmeldung Zimbra funktioniert wieder :-) \r\n\r\nPS: Weiss man was das Problem war? LG Andreas Stössel\n---\nSuper danke :-)\r\n\r\nTest Servicedesk erfolgreich. Versand von Zimbra und Empfang auf MBA Adresse i.o.\r\n\r\n!clipboard-202403250948-gpgxs.png!\r\n!clipboard-202403250948-st3cq.png!\r\n\r\nSieht also soweit wieder gut aus :-) Ich werde mal die Schulen anschreiben und warte auf Rückmeldung. LG Andreas Stössel\n---\nDie Warteschlangen werden nun abgebaut, das System scheint wieder normal unterwegs zu sein.\r\nKontrolliert doch mit euren Konten auch noch schnell.\n---\nNachtrag von KZU:\r\n\r\nMelderin: Andrea Emonds\r\n\r\nProblem: Absenzen können nicht versendet werden. (Wird Zimbra Problem sein, dies noch zur Kenntnisnahme):\r\n!clipboard-202403250922-bernz.png!\r\n\r\n\n---\nFolgende Details:\r\n!clipboard-202403250816-hxubf.png!\r\n\r\nAusserdem habe ich den Fehlerbericht im Zimbra gesendet.\n---\n\r\nServicedesk: Ich habe eine Test Mail erfolglos gesendet. Von Zimbra an andreas.stoessel@mba.zh.ch\r\n!clipboard-202403250810-kmwuh.png!\r\n\n---\nDie KRW und die KZU haben jetzt ebenfalls dieses Problem gemeldet\n---\nBeobachtet ihr mit eurer Domain it.mba.zh.ch den gleichen Effekt (für uns funktioniert alles, an den edge-Servern liegt's kaum)?
# 255                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [MBA#1127156] Layout-Anpassung auf Typo 3 - Webseite (KWI)\n---\nGuten Morgen\r\n\r\nIch habe eine eher spezielle Anfrage von der Kantonsschule Wiedikon.\r\n\r\nDie Kantonsschule Wiedikon wünscht eine Layout Anpassung für mobile Geräte zu machen für das Video welches auf der Webseite der KWI (Baustand der Hohlstrasse) hochgeladen wurde. Die Kontaktperson (bei früheren Anpassungen) bei euch war Noemi Schmid. Die Schule wünscht nun eine Kontaktaufnahme von euch  mit Herrn Philippe da Silva Wong, Tel. 044 457 71 53 um die Einzelheiten zu besprechen.\r\nWäre eine Kontaktaufnahme seitens von euch möglich?\r\n\r\nDieses Ticket eilt ein wenig da es schon länger auf eine Antwort wartet. Ich habe das Ticket am 27.02.2024 an euch weitergeleitet ohne Rückmeldung bis jetzt.\r\n \r\nFreundliche Grüsse\r\nKushtrim Veliji\r\n——\r\nBildungsdirektion Kanton Zürich\r\nMittelschul- und Berufsbildungsamt\r\nDigital Service Center Sek II\r\nAusstellungsstrasse 80\r\n8090 Zürich\r\nTelefon 043 259 77 27\n---\nBist du da dran?
#
# [256 rows x 2 columns]

# %%
import pandas as pd

# Example DataFrame
# df = pd.DataFrame({'text': ["Example text\r\n\r\nwith special characters &*%$#@!"]})

# Replace "\r\n\r\n" with a space
df['all_information'] = df['all_information'].str.replace(r"\n", " ", regex=True)
df['all_information'] = df['all_information'].str.replace(r"\r", " ", regex=True)

# Replace any character that is not a letter, number, or common punctuation with a space
df['all_information'] = df['all_information'].str.replace(r"[^a-zA-Z0-9\s.,;!?']", " ", regex=True)

print(df)
# Out:
#     issue_id  \
# 0     116163
# 1     116164
# 2     116165
# 3     116166
# 4     116167
# ..       ...
# 251   116537
# 252   116538
# 253   116539
# 254   116543
# 255   116550
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           all_information
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           KEN  mobile App aufschalten     Einfach mal alle Module freischalten     Super, der Benutzer wechsel klappt nun auch.  Aber f r das aktuelle Login br uchten die KEN User einen LDAP Account, das Login  ber ihren Azure Tenant geht erst mit v1.8.     LDAP  ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     KEN  Signage einrichten     Bitte einen Beispiel Raspi startklar machen     Raspi aufgesetzt und mit KEN verbunden.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              KEN  Module freischalten  MBA 1127666        Basis  AP 001     Basis   AP 002  MATAR, IU   Micropage    Stundenplan  AP 004     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009     Elektronisches Klassenbuch  AP 010        Basis  AP 001   ok     Basis   AP 002      MATAR  ok  https   intranet.tam.ch ken matar     IU  ok      Micropage  ok   https   intranet.tam.ch ken micropage    Stundenplan  AP 004   ok     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter    Elektronisches Klassenbuch  AP 010   ok     Die Module sind weitgehend bereit, die konkrete Konfiguration w re der n chste Schritt       Basis  AP 001    Basis   AP 002     MATAR  ok  https   intranet.tam.ch ken matar    IU  ok     Micropage  ok   https   intranet.tam.ch ken micropage   Stundenplan  AP 004   ok    Absenzenerfassung  AP 005    Absenzenprozesse  AP 006     Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter   Elektronisches Klassenbuch  AP 010   ok
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 KST  MBA 1125513    IN2   Bl cke streichen l schen funktioniert nicht     Hallo zusammen    Das streichen von Bl cken funktioniert aktuell bei der KST nicht.  Das Fenster  ffnet sich zwar, man kann auch auf  Block streichen  klicken,  aber das Fenster schliesst sich dann und der Block ist dann nicht  gel scht gestrichen.    Evtl. hat es etwas mit diesem Ticket zu tun Incident  116149     Freundliche Gr sse  Dani              Hoi Dani        Reservationen funktionieren wieder, Ferien Blocks k nnen nach wie vor nicht    ver ndert werden.        LG        Kai Homberg            Auf live korrigiert.     Ist auf live     Auf stage korrigiert     funktioniert     Sollte auf stage gefixed sein. Kannst noch testen?     Habe es in diesem Fall in der DB gel scht.    Bitte anschauen     Jemand scheint  nderungen am Stundenplan unternommen zu haben.   Alle Ferien k nnen nicht mehr gel scht werden.     HolidayID   132, Karfreitag. Wieso l sst sich das nicht l schen?
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          KZI  MBA 1125671    IN2   IU Stundenplan   busy Lektion     Hallo zusammen    K nnt Ihr bitte die Lektion im Anhang f r die KZI l schen?     Freundliche Gr sse  Dani           Hallo Support     Das in Ticket MBA 1124354 gemeldete Problem, dass im IU Stundenplantool in  einem IU Lehrstundenplan ein  busy  Eintrag nicht gel scht werden kann, trat  nun wieder auf   Immerhin weiss ich unterdessen, wie das passiert  Wenn man den Stundenplan  eines Sch lers eingblendet hat und dann dort auf eine frei Lektion klickt,  erscheint nachher im Lehrerstundenplan eine  busy  Lektion.  So geschehen bei LP roger.ruetti.kzi   s. Beilage  Bitte diese Lektion l schen oder mir mitteilen, wie ich das erledigen kann.     Lieben Gruss Daniel Stucki     Das ist eine der Grundfunktionen des IU Planners  Will man bei einem Sch ler zus tzlich zum Grundstundenplan eine Lektion sperren, klickt man im Sch lerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.     Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            KZN  MBA 1128871  IM  Neues gemischtes Profil N PPP     Hallo zusammen    Bitte das neue Profil erfassen.    Vielen Dank im voraus  Gruess  Roman      Gesch tztes Support Team          Aufgrund der sich abzeichnenden Klasseneinteilung f r das n chste Schuljahr    braucht die KZN neu das gemischte Profil Neusprachlich PPP, das wir hiermit    gerne bestellen w rden.        LG        Giusi            Das Profil N PPP steht jetzt zur Auswahl
# 252                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Fwd   MBA 1128639  AW  Druckereinstellungen Sekretariat KFR     Hallo    Seit der Umstellung auf Leunet hat die KFR Schwierigkeiten beim Drucken mit  dem Drucker Canon ImageRunner Advance  C5560i, IP  10.95.36.110  Die Probleme treten nur in der VDI auf. Jedes Mal, wenn sie drucken wollen,  m ssen sie zuerst den Drucker in der Liste anw hlen, da dieser nicht als  Standard eingestellt ist und es m ssen auch alle weiteren Einstellungen wie   einseitig drucken  neu ausgew hlt werden. Ausserdem druckt es immer nur ein  Exemplar aus, auch wenn man die Anzahl der Exemplare anpasst. Das Papierfach  wird ebenfalls willk rlich ausgew hlt. Habt ihr eine Idee wie man das beheben  k nnte? Ihr k nnt gerne etwas versuchen und wir testen das dann. Falls ihr  noch mehr Infos ben tigt, dann liefere ich diese gerne nach. Danke!    VG  Max     Sali,    Bitte kurz folgenden Drucker hinzuf gen und testen     print002.mbazh.ch KFR  Canon iR ADV C5550 5560 PCL6.2    Um die Liste f r den Standard Drucker zu pr fen, ben tige ich noch die Namen derjenigen, welche den als Standard hinterlegt haben sollten.  Die Drucker sind normalerweise eingestellt Doppelseitig zu drucken, kann ich aber  ndern.  Auch das Papierfach kann ich anpassen, die Auswahl besteht hier aus Auto, Mehrzweck Fach, Einzug 1, Einzug 2.    Gruss  Martin         Ist der Drucker in der Tabelle eingetragen?
# 253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                KZI Miniinfo Neue Common Name Prozedur f r Kurse  MBA 1128844      Nach R cksprache mit den MV verstehe ich, dass die Anleitung  CommonNames   nicht ohne eine weitere Installation einer Prozedur greift, deshalb gebe ich  das Ticket nun mit dem Auftrag zur untigen Anfrage von Daniel Stucki    Ich bitte um Installation der neuen MiniInfo Prozedur zum Setzen der Common  Names und Kurslabels auf KURSEN   wenn m glich im Ordner  Common Names .  Die neue Prozedur zum Setzen der cn auf Klassen habe ich bereits installiert.     Die Prozeduren f r CN und Labels sind bei allen Schulen vorhanden. An der KZI muss einfach noch spr TAMMI set commonname on course im MiniInfo administriert werden     Roman, Danijel?
# 254   MBA 1128940  Zimbra St rung komplette Schule  E Mails senden und empfangen  kslzh.ch  funktioniert nicht     Guten Morgen allerseits    Schule  KSLZH  Melder  Laszlo Cseri    Problem Zimbra     Wir  kslzh.ch  k nnen keine E Mails senden  auch Mails von GMX und icloud.com versendet  und empfangen. Im Webmail erhalten wir folgende Hinweise beim versenden von E Mails     !clipboard 202403250751 h8l4i.png!    !clipboard 202403250751 h6e8a.png!    Eine  berpr fung mit MXToolbox zeigt bei einem SMTP Check folgendes an      !clipboard 202403250751 2pdnb.png!    D rfen wir euch bitten, das Problem sofort zu beheben?    Nachtrag  Bei meinen Recherchen habe ich festgestellt, dass es auch die stud.kslzh.ch Domain auch betrifft     !clipboard 202403250752 fxdsc.png!         PS  Weiss man was das Problem war? LG Andreas St ssel  Im Detail nicht.  Die Kommunikation zwischen MTA und Edge Server war gest rt, aber man sieht nicht, was das ausgel st hat.   Das System ist schon l nger im EoL Status, wir investieren keine Zeit mehr in Fehlersuche          KRW Andreas Berger  KSL Cseri Laszlo    R ckmeldung Zimbra funktioniert wieder         PS  Weiss man was das Problem war? LG Andreas St ssel     Super danke        Test Servicedesk erfolgreich. Versand von Zimbra und Empfang auf MBA Adresse i.o.    !clipboard 202403250948 gpgxs.png!  !clipboard 202403250948 st3cq.png!    Sieht also soweit wieder gut aus     Ich werde mal die Schulen anschreiben und warte auf R ckmeldung. LG Andreas St ssel     Die Warteschlangen werden nun abgebaut, das System scheint wieder normal unterwegs zu sein.  Kontrolliert doch mit euren Konten auch noch schnell.     Nachtrag von KZU     Melderin  Andrea Emonds    Problem  Absenzen k nnen nicht versendet werden.  Wird Zimbra Problem sein, dies noch zur Kenntnisnahme    !clipboard 202403250922 bernz.png!         Folgende Details   !clipboard 202403250816 hxubf.png!    Ausserdem habe ich den Fehlerbericht im Zimbra gesendet.       Servicedesk  Ich habe eine Test Mail erfolglos gesendet. Von Zimbra an andreas.stoessel mba.zh.ch  !clipboard 202403250810 kmwuh.png!       Die KRW und die KZU haben jetzt ebenfalls dieses Problem gemeldet     Beobachtet ihr mit eurer Domain it.mba.zh.ch den gleichen Effekt  f r uns funktioniert alles, an den edge Servern liegt's kaum ?
# 255                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  MBA 1127156  Layout Anpassung auf Typo 3   Webseite  KWI      Guten Morgen    Ich habe eine eher spezielle Anfrage von der Kantonsschule Wiedikon.    Die Kantonsschule Wiedikon w nscht eine Layout Anpassung f r mobile Ger te zu machen f r das Video welches auf der Webseite der KWI  Baustand der Hohlstrasse  hochgeladen wurde. Die Kontaktperson  bei fr heren Anpassungen  bei euch war Noemi Schmid. Die Schule w nscht nun eine Kontaktaufnahme von euch  mit Herrn Philippe da Silva Wong, Tel. 044 457 71 53 um die Einzelheiten zu besprechen.  W re eine Kontaktaufnahme seitens von euch m glich?    Dieses Ticket eilt ein wenig da es schon l nger auf eine Antwort wartet. Ich habe das Ticket am 27.02.2024 an euch weitergeleitet ohne R ckmeldung bis jetzt.     Freundliche Gr sse  Kushtrim Veliji      Bildungsdirektion Kanton Z rich  Mittelschul  und Berufsbildungsamt  Digital Service Center Sek II  Ausstellungsstrasse 80  8090 Z rich  Telefon 043 259 77 27     Bist du da dran?
#
# [256 rows x 2 columns]

# %%
# !pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /usr/local/lib/python3.10/dist-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)

# %%
import openai
import pandas as pd

from google.colab import userdata
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')
print("DONE")
# Out:
# DONE

# %%
import os

# Check if the OPENAI_API_KEY environment variable is set
if "OPENAI_API_KEY" in os.environ:
    print("OpenAI API key is set.")
else:
    print("OpenAI API key is not set.")
# Out:
# OpenAI API key is set.

# %% [markdown]
# TEST

# %%
import os
import pandas as pd
import openai


def rework_ticket_description_with_gptturbo(ticket_text):
    """
    Reworks a ticket description into a structured summary using the GPT-3.5 Turbo model through Chat Completion.

    :param ticket_text: The text of the ticket.
    :return: Reworked ticket text.
    """

    # Explicitly set the OpenAI API key
    openai.api_key = os.getenv("OPENAI_API_KEY")


    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are a helpful assistant tasked with summarizing technical support tickets."},
                {"role": "user", "content": ticket_text}
            ]

        )

        # Assuming the response structure has a 'choices' list with at least one item,
        # and 'message' contains the 'content' field with our reworked text.
        if response and 'choices' in response and len(response['choices']) > 0:
            reworked_text = response['choices'][0].get('message', {}).get('content', '')
            return reworked_text.strip()
        else:
            return "Failed to generate reworked text. No valid response."
    except Exception as e:
        return f"An error occurred: {str(e)}"

# %%
# Apply the function to your DataFrame
df['reworked_information'] = df['all_information'].apply(rework_ticket_description_with_gptturbo)

# Display the first few rows of the processed DataFrame
print(df.head())
# Out:
#   issue_id  \
# 0   116163
# 1   116164
# 2   116165
# 3   116166
# 4   116167
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   all_information  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   KEN  mobile App aufschalten     Einfach mal alle Module freischalten     Super, der Benutzer wechsel klappt nun auch.  Aber f r das aktuelle Login br uchten die KEN User einen LDAP Account, das Login  ber ihren Azure Tenant geht erst mit v1.8.     LDAP  ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             KEN  Signage einrichten     Bitte einen Beispiel Raspi startklar machen     Raspi aufgesetzt und mit KEN verbunden.
# 2      KEN  Module freischalten  MBA 1127666        Basis  AP 001     Basis   AP 002  MATAR, IU   Micropage    Stundenplan  AP 004     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009     Elektronisches Klassenbuch  AP 010        Basis  AP 001   ok     Basis   AP 002      MATAR  ok  https   intranet.tam.ch ken matar     IU  ok      Micropage  ok   https   intranet.tam.ch ken micropage    Stundenplan  AP 004   ok     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter    Elektronisches Klassenbuch  AP 010   ok     Die Module sind weitgehend bereit, die konkrete Konfiguration w re der n chste Schritt       Basis  AP 001    Basis   AP 002     MATAR  ok  https   intranet.tam.ch ken matar    IU  ok     Micropage  ok   https   intranet.tam.ch ken micropage   Stundenplan  AP 004   ok    Absenzenerfassung  AP 005    Absenzenprozesse  AP 006     Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter   Elektronisches Klassenbuch  AP 010   ok
# 3                                                                                         KST  MBA 1125513    IN2   Bl cke streichen l schen funktioniert nicht     Hallo zusammen    Das streichen von Bl cken funktioniert aktuell bei der KST nicht.  Das Fenster  ffnet sich zwar, man kann auch auf  Block streichen  klicken,  aber das Fenster schliesst sich dann und der Block ist dann nicht  gel scht gestrichen.    Evtl. hat es etwas mit diesem Ticket zu tun Incident  116149     Freundliche Gr sse  Dani              Hoi Dani        Reservationen funktionieren wieder, Ferien Blocks k nnen nach wie vor nicht    ver ndert werden.        LG        Kai Homberg            Auf live korrigiert.     Ist auf live     Auf stage korrigiert     funktioniert     Sollte auf stage gefixed sein. Kannst noch testen?     Habe es in diesem Fall in der DB gel scht.    Bitte anschauen     Jemand scheint  nderungen am Stundenplan unternommen zu haben.   Alle Ferien k nnen nicht mehr gel scht werden.     HolidayID   132, Karfreitag. Wieso l sst sich das nicht l schen?
# 4  KZI  MBA 1125671    IN2   IU Stundenplan   busy Lektion     Hallo zusammen    K nnt Ihr bitte die Lektion im Anhang f r die KZI l schen?     Freundliche Gr sse  Dani           Hallo Support     Das in Ticket MBA 1124354 gemeldete Problem, dass im IU Stundenplantool in  einem IU Lehrstundenplan ein  busy  Eintrag nicht gel scht werden kann, trat  nun wieder auf   Immerhin weiss ich unterdessen, wie das passiert  Wenn man den Stundenplan  eines Sch lers eingblendet hat und dann dort auf eine frei Lektion klickt,  erscheint nachher im Lehrerstundenplan eine  busy  Lektion.  So geschehen bei LP roger.ruetti.kzi   s. Beilage  Bitte diese Lektion l schen oder mir mitteilen, wie ich das erledigen kann.     Lieben Gruss Daniel Stucki     Das ist eine der Grundfunktionen des IU Planners  Will man bei einem Sch ler zus tzlich zum Grundstundenplan eine Lektion sperren, klickt man im Sch lerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.     Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   reworked_information
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Zusammenfassung:\n- Alle Module der KEN Mobile App wurden erfolgreich freigeschaltet.\n- Der Benutzerwechsel funktioniert jetzt problemlos.\n- Für das aktuelle Login benötigen KEN-Benutzer einen LDAP-Account, da das Login über ihren Azure-Tenant erst in Version 1.8 möglich ist.\n- Die LDAP-OU und UPN sind jetzt verfügbar.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Zusammenfassung:  Benötigt wird ein Beispiel für die Einrichtung von KEN-Schildern auf einem Raspberry Pi, nachdem der Raspberry Pi eingerichtet und mit KEN verbunden wurde.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                   The technical support ticket is about activating a KEN module MBA 1127666 and configuring various components such as Basis AP 001, Basis AP 002, MATAR, IU, Micropage, Stundenplan AP 004, Absenzenerfassung AP 005, Absenzenprozesse AP 006, Newsletter AP 009, and Elektronisches Klassenbuch AP 010. The ticket indicates that most modules are ready with specific configurations provided for each component. The next step would be to finalize the configuration settings. Links to access some components are also included in the ticket.
# 3  Issue: The function to delete or strike through blocks is not working for KST MBA 1125513.\n- Users can click on "Block streichen," but the window closes without deleting or striking through the block.\n- This issue may be related to another incident (Incident 116149) where reservations were fixed but holiday blocks still cannot be modified.\n\nActions taken:\n- Changes were made on the live and stage environments to correct the issue.\n- A specific holiday (HolidayID 132, Karfreitag) cannot be deleted, and adjustments were made in the database to address this.\n- It seems someone has made changes to the schedule affecting the ability to delete all holidays.\n\nFurther steps:\n- Verify if the fix on the stage environment is successful by testing the deletion/striking through blocks.\n- Investigate why the specific holiday (Karfreitag) cannot be deleted and ensure proper functionality for modifying holiday blocks.\n\nBest regards,\n[Assistant's Name]
# 4                                                                                                                                                                                                                                                                                                                                                 Summary:\n\n- User Dani reported a problem where a "busy" entry cannot be deleted from the IU lesson plan.\n- The issue occurred when displaying a student's schedule and clicking on a free lesson, resulting in the appearance of a "busy" lesson in the teacher's schedule.\n- The user has identified the cause of the problem and requested assistance in deleting the busy lesson.\n- Another user, Daniel Stucki, shared insight that the ability to lock/unlock a lesson is a fundamental function of the IU Planner.\n- It was mentioned that this functionality dates back to the Intranet Version 1, which is approximately 15 years old.

# %%
# Save the DataFrame to a JSON file
df.to_json('./drive/Othercomputers/X1/code/processed_summarization_per_ticket.json', orient='records', lines=True)

# To ensure it's saved, you can also download it to your local system with the following:
from google.colab import files
files.download('./drive/Othercomputers/X1/code/processed_summarization_per_ticket.json')

# %%
# Read the JSON file into a DataFrame
df = pd.read_json('./drive/Othercomputers/X1/code/processed_summarization_per_ticket.json', lines=True)

# %%
df
# Out:
#      issue_id  \
# 0      116163
# 1      116164
# 2      116165
# 3      116166
# 4      116167
# ..        ...
# 251    116537
# 252    116538
# 253    116539
# 254    116543
# 255    116550
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           all_information  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           KEN  mobile App aufschalten     Einfach mal alle Module freischalten     Super, der Benutzer wechsel klappt nun auch.  Aber f r das aktuelle Login br uchten die KEN User einen LDAP Account, das Login  ber ihren Azure Tenant geht erst mit v1.8.     LDAP  ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     KEN  Signage einrichten     Bitte einen Beispiel Raspi startklar machen     Raspi aufgesetzt und mit KEN verbunden.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              KEN  Module freischalten  MBA 1127666        Basis  AP 001     Basis   AP 002  MATAR, IU   Micropage    Stundenplan  AP 004     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009     Elektronisches Klassenbuch  AP 010        Basis  AP 001   ok     Basis   AP 002      MATAR  ok  https   intranet.tam.ch ken matar     IU  ok      Micropage  ok   https   intranet.tam.ch ken micropage    Stundenplan  AP 004   ok     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter    Elektronisches Klassenbuch  AP 010   ok     Die Module sind weitgehend bereit, die konkrete Konfiguration w re der n chste Schritt       Basis  AP 001    Basis   AP 002     MATAR  ok  https   intranet.tam.ch ken matar    IU  ok     Micropage  ok   https   intranet.tam.ch ken micropage   Stundenplan  AP 004   ok    Absenzenerfassung  AP 005    Absenzenprozesse  AP 006     Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter   Elektronisches Klassenbuch  AP 010   ok
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 KST  MBA 1125513    IN2   Bl cke streichen l schen funktioniert nicht     Hallo zusammen    Das streichen von Bl cken funktioniert aktuell bei der KST nicht.  Das Fenster  ffnet sich zwar, man kann auch auf  Block streichen  klicken,  aber das Fenster schliesst sich dann und der Block ist dann nicht  gel scht gestrichen.    Evtl. hat es etwas mit diesem Ticket zu tun Incident  116149     Freundliche Gr sse  Dani              Hoi Dani        Reservationen funktionieren wieder, Ferien Blocks k nnen nach wie vor nicht    ver ndert werden.        LG        Kai Homberg            Auf live korrigiert.     Ist auf live     Auf stage korrigiert     funktioniert     Sollte auf stage gefixed sein. Kannst noch testen?     Habe es in diesem Fall in der DB gel scht.    Bitte anschauen     Jemand scheint  nderungen am Stundenplan unternommen zu haben.   Alle Ferien k nnen nicht mehr gel scht werden.     HolidayID   132, Karfreitag. Wieso l sst sich das nicht l schen?
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          KZI  MBA 1125671    IN2   IU Stundenplan   busy Lektion     Hallo zusammen    K nnt Ihr bitte die Lektion im Anhang f r die KZI l schen?     Freundliche Gr sse  Dani           Hallo Support     Das in Ticket MBA 1124354 gemeldete Problem, dass im IU Stundenplantool in  einem IU Lehrstundenplan ein  busy  Eintrag nicht gel scht werden kann, trat  nun wieder auf   Immerhin weiss ich unterdessen, wie das passiert  Wenn man den Stundenplan  eines Sch lers eingblendet hat und dann dort auf eine frei Lektion klickt,  erscheint nachher im Lehrerstundenplan eine  busy  Lektion.  So geschehen bei LP roger.ruetti.kzi   s. Beilage  Bitte diese Lektion l schen oder mir mitteilen, wie ich das erledigen kann.     Lieben Gruss Daniel Stucki     Das ist eine der Grundfunktionen des IU Planners  Will man bei einem Sch ler zus tzlich zum Grundstundenplan eine Lektion sperren, klickt man im Sch lerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.     Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            KZN  MBA 1128871  IM  Neues gemischtes Profil N PPP     Hallo zusammen    Bitte das neue Profil erfassen.    Vielen Dank im voraus  Gruess  Roman      Gesch tztes Support Team          Aufgrund der sich abzeichnenden Klasseneinteilung f r das n chste Schuljahr    braucht die KZN neu das gemischte Profil Neusprachlich PPP, das wir hiermit    gerne bestellen w rden.        LG        Giusi            Das Profil N PPP steht jetzt zur Auswahl
# 252                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Fwd   MBA 1128639  AW  Druckereinstellungen Sekretariat KFR     Hallo    Seit der Umstellung auf Leunet hat die KFR Schwierigkeiten beim Drucken mit  dem Drucker Canon ImageRunner Advance  C5560i, IP  10.95.36.110  Die Probleme treten nur in der VDI auf. Jedes Mal, wenn sie drucken wollen,  m ssen sie zuerst den Drucker in der Liste anw hlen, da dieser nicht als  Standard eingestellt ist und es m ssen auch alle weiteren Einstellungen wie   einseitig drucken  neu ausgew hlt werden. Ausserdem druckt es immer nur ein  Exemplar aus, auch wenn man die Anzahl der Exemplare anpasst. Das Papierfach  wird ebenfalls willk rlich ausgew hlt. Habt ihr eine Idee wie man das beheben  k nnte? Ihr k nnt gerne etwas versuchen und wir testen das dann. Falls ihr  noch mehr Infos ben tigt, dann liefere ich diese gerne nach. Danke!    VG  Max     Sali,    Bitte kurz folgenden Drucker hinzuf gen und testen     print002.mbazh.ch KFR  Canon iR ADV C5550 5560 PCL6.2    Um die Liste f r den Standard Drucker zu pr fen, ben tige ich noch die Namen derjenigen, welche den als Standard hinterlegt haben sollten.  Die Drucker sind normalerweise eingestellt Doppelseitig zu drucken, kann ich aber  ndern.  Auch das Papierfach kann ich anpassen, die Auswahl besteht hier aus Auto, Mehrzweck Fach, Einzug 1, Einzug 2.    Gruss  Martin         Ist der Drucker in der Tabelle eingetragen?
# 253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                KZI Miniinfo Neue Common Name Prozedur f r Kurse  MBA 1128844      Nach R cksprache mit den MV verstehe ich, dass die Anleitung  CommonNames   nicht ohne eine weitere Installation einer Prozedur greift, deshalb gebe ich  das Ticket nun mit dem Auftrag zur untigen Anfrage von Daniel Stucki    Ich bitte um Installation der neuen MiniInfo Prozedur zum Setzen der Common  Names und Kurslabels auf KURSEN   wenn m glich im Ordner  Common Names .  Die neue Prozedur zum Setzen der cn auf Klassen habe ich bereits installiert.     Die Prozeduren f r CN und Labels sind bei allen Schulen vorhanden. An der KZI muss einfach noch spr TAMMI set commonname on course im MiniInfo administriert werden     Roman, Danijel?
# 254   MBA 1128940  Zimbra St rung komplette Schule  E Mails senden und empfangen  kslzh.ch  funktioniert nicht     Guten Morgen allerseits    Schule  KSLZH  Melder  Laszlo Cseri    Problem Zimbra     Wir  kslzh.ch  k nnen keine E Mails senden  auch Mails von GMX und icloud.com versendet  und empfangen. Im Webmail erhalten wir folgende Hinweise beim versenden von E Mails     !clipboard 202403250751 h8l4i.png!    !clipboard 202403250751 h6e8a.png!    Eine  berpr fung mit MXToolbox zeigt bei einem SMTP Check folgendes an      !clipboard 202403250751 2pdnb.png!    D rfen wir euch bitten, das Problem sofort zu beheben?    Nachtrag  Bei meinen Recherchen habe ich festgestellt, dass es auch die stud.kslzh.ch Domain auch betrifft     !clipboard 202403250752 fxdsc.png!         PS  Weiss man was das Problem war? LG Andreas St ssel  Im Detail nicht.  Die Kommunikation zwischen MTA und Edge Server war gest rt, aber man sieht nicht, was das ausgel st hat.   Das System ist schon l nger im EoL Status, wir investieren keine Zeit mehr in Fehlersuche          KRW Andreas Berger  KSL Cseri Laszlo    R ckmeldung Zimbra funktioniert wieder         PS  Weiss man was das Problem war? LG Andreas St ssel     Super danke        Test Servicedesk erfolgreich. Versand von Zimbra und Empfang auf MBA Adresse i.o.    !clipboard 202403250948 gpgxs.png!  !clipboard 202403250948 st3cq.png!    Sieht also soweit wieder gut aus     Ich werde mal die Schulen anschreiben und warte auf R ckmeldung. LG Andreas St ssel     Die Warteschlangen werden nun abgebaut, das System scheint wieder normal unterwegs zu sein.  Kontrolliert doch mit euren Konten auch noch schnell.     Nachtrag von KZU     Melderin  Andrea Emonds    Problem  Absenzen k nnen nicht versendet werden.  Wird Zimbra Problem sein, dies noch zur Kenntnisnahme    !clipboard 202403250922 bernz.png!         Folgende Details   !clipboard 202403250816 hxubf.png!    Ausserdem habe ich den Fehlerbericht im Zimbra gesendet.       Servicedesk  Ich habe eine Test Mail erfolglos gesendet. Von Zimbra an andreas.stoessel mba.zh.ch  !clipboard 202403250810 kmwuh.png!       Die KRW und die KZU haben jetzt ebenfalls dieses Problem gemeldet     Beobachtet ihr mit eurer Domain it.mba.zh.ch den gleichen Effekt  f r uns funktioniert alles, an den edge Servern liegt's kaum ?
# 255                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  MBA 1127156  Layout Anpassung auf Typo 3   Webseite  KWI      Guten Morgen    Ich habe eine eher spezielle Anfrage von der Kantonsschule Wiedikon.    Die Kantonsschule Wiedikon w nscht eine Layout Anpassung f r mobile Ger te zu machen f r das Video welches auf der Webseite der KWI  Baustand der Hohlstrasse  hochgeladen wurde. Die Kontaktperson  bei fr heren Anpassungen  bei euch war Noemi Schmid. Die Schule w nscht nun eine Kontaktaufnahme von euch  mit Herrn Philippe da Silva Wong, Tel. 044 457 71 53 um die Einzelheiten zu besprechen.  W re eine Kontaktaufnahme seitens von euch m glich?    Dieses Ticket eilt ein wenig da es schon l nger auf eine Antwort wartet. Ich habe das Ticket am 27.02.2024 an euch weitergeleitet ohne R ckmeldung bis jetzt.     Freundliche Gr sse  Kushtrim Veliji      Bildungsdirektion Kanton Z rich  Mittelschul  und Berufsbildungsamt  Digital Service Center Sek II  Ausstellungsstrasse 80  8090 Z rich  Telefon 043 259 77 27     Bist du da dran?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     reworked_information
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    Zusammenfassung:\n- Alle Module der KEN Mobile App wurden erfolgreich freigeschaltet.\n- Der Benutzerwechsel funktioniert jetzt problemlos.\n- Für das aktuelle Login benötigen KEN-Benutzer einen LDAP-Account, da das Login über ihren Azure-Tenant erst in Version 1.8 möglich ist.\n- Die LDAP-OU und UPN sind jetzt verfügbar.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Zusammenfassung:  Benötigt wird ein Beispiel für die Einrichtung von KEN-Schildern auf einem Raspberry Pi, nachdem der Raspberry Pi eingerichtet und mit KEN verbunden wurde.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                     The technical support ticket is about activating a KEN module MBA 1127666 and configuring various components such as Basis AP 001, Basis AP 002, MATAR, IU, Micropage, Stundenplan AP 004, Absenzenerfassung AP 005, Absenzenprozesse AP 006, Newsletter AP 009, and Elektronisches Klassenbuch AP 010. The ticket indicates that most modules are ready with specific configurations provided for each component. The next step would be to finalize the configuration settings. Links to access some components are also included in the ticket.
# 3    Issue: The function to delete or strike through blocks is not working for KST MBA 1125513.\n- Users can click on "Block streichen," but the window closes without deleting or striking through the block.\n- This issue may be related to another incident (Incident 116149) where reservations were fixed but holiday blocks still cannot be modified.\n\nActions taken:\n- Changes were made on the live and stage environments to correct the issue.\n- A specific holiday (HolidayID 132, Karfreitag) cannot be deleted, and adjustments were made in the database to address this.\n- It seems someone has made changes to the schedule affecting the ability to delete all holidays.\n\nFurther steps:\n- Verify if the fix on the stage environment is successful by testing the deletion/striking through blocks.\n- Investigate why the specific holiday (Karfreitag) cannot be deleted and ensure proper functionality for modifying holiday blocks.\n\nBest regards,\n[Assistant's Name]
# 4                                                                                                                                                                                                                                                                                                                                                   Summary:\n\n- User Dani reported a problem where a "busy" entry cannot be deleted from the IU lesson plan.\n- The issue occurred when displaying a student's schedule and clicking on a free lesson, resulting in the appearance of a "busy" lesson in the teacher's schedule.\n- The user has identified the cause of the problem and requested assistance in deleting the busy lesson.\n- Another user, Daniel Stucki, shared insight that the ability to lock/unlock a lesson is a fundamental function of the IU Planner.\n- It was mentioned that this functionality dates back to the Intranet Version 1, which is approximately 15 years old.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              Summary: The user is requesting the creation of a new profile named Neusprachlich PPP for the KZN system due to upcoming class allocations for the next school year. The profile has been made available for selection.
# 252                                                                                                                                                                                                                                                                    Summary:\n- The KFR team is experiencing printing issues with the Canon ImageRunner Advance C5560i printer since switching to Leunet, specifically in the VDI environment.\n- The printer is not set as the default printer, requiring manual selection before each print job.\n- Additional settings such as one-sided printing need to be reselected for each print job.\n- The printer only prints one copy regardless of the specified number of copies, and the paper tray selection is random.\n- Support is requested to address these issues and test potential solutions, with the addition of a new printer for testing provided in the email thread.\n- Further information and assistance are available upon request.
# 253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Summary: The user is requesting the installation of a new MiniInfo procedure to set common names and course labels on courses under the "Common Names" folder. They have already installed the procedure for setting common names on classes. The procedures for common names and labels are available at all schools, but they need the specific procedure "TAMMI set commonname on course" to be administered at the KZI. The user is asking for Roman or Danijel to handle this request.
# 254                                                                               Summary of Technical Support Ticket:\n\n- Issue reported by Laszlo Cseri from KSLZH school regarding Zimbra email service not working for sending and receiving emails for kslzh.ch domain.\n- MXToolbox check showed SMTP issues.\n- Communication problem between MTA and Edge Server, which was not identified.\n- System in End-of-Life status, no further investment in troubleshooting.\n- Issue resolved, Zimbra service working again.\n- Follow-up by Andreas Stössel confirmed successful testing of Zimbra service.\n- Schools to be informed about the resolution.\n- Waiting for feedback from schools.\n- Absentee notifications not able to be sent, Zimbra issue suspected.\n- Error report sent in Zimbra.\n- Test emails unsuccessful, issue reported by KRW and KZU.\n- Question raised if the domain it.mba.zh.ch is also facing similar issues.\n- Requests for further monitoring of the system.
# 255                                                                                                                                                                                                                                                                                                                                                                                            Summary:\n- The Kantonsschule Wiedikon (KWI) has a specific request for a layout adjustment on their Typo3 website for mobile devices related to a video on the Baustand der Hohlstrasse.\n- Previous contact for website adjustments was Noemi Schmid, but now they are requesting contact with Mr. Philippe da Silva Wong at 044 457 71 53 to discuss details.\n- Urgency is emphasized as the ticket has been awaiting a response since 27.02.2024.\n- Contact person is Kushtrim Veliji from the Bildungsdirektion Kanton Zurich.\n- Requesting confirmation if action has been taken on this ticket.
#
# [256 rows x 3 columns]

# %% [markdown]
# END TEST

# %%
# TEST VERSIONfrom transformers import AutoTokenizer, AutoModel
import torch
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
import pandas as pd
import openai
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

# Function to get embeddings from OpenAI
def get_openai_embeddings(texts):
    embeddings = []
    for text in texts:
        response = openai.Embedding.create(
            input=text,
            engine="text-embedding-ada-002"  # Choose the appropriate engine for your task
        )
        embeddings.append(response['data'][0]['embedding'])
    return np.array(embeddings)

# Assuming df is your DataFrame and 'reworked_information' is the column with texts
texts = df['reworked_information'].tolist()
matrix = get_openai_embeddings(texts)

# Perform hierarchical clustering
Z = linkage(matrix, 'ward')

# Plot the dendrogram to visualize clusters
plt.figure(figsize=(25, 10))
dendrogram(
    Z,
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,  # font size for the x axis labels
)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample index or (Cluster size)')
plt.ylabel('Distance')
plt.show()

# %%
df.head()
# Out:
#    issue_id  \
# 0    116163
# 1    116164
# 2    116165
# 3    116166
# 4    116167
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   all_information  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   KEN  mobile App aufschalten     Einfach mal alle Module freischalten     Super, der Benutzer wechsel klappt nun auch.  Aber f r das aktuelle Login br uchten die KEN User einen LDAP Account, das Login  ber ihren Azure Tenant geht erst mit v1.8.     LDAP  ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             KEN  Signage einrichten     Bitte einen Beispiel Raspi startklar machen     Raspi aufgesetzt und mit KEN verbunden.
# 2      KEN  Module freischalten  MBA 1127666        Basis  AP 001     Basis   AP 002  MATAR, IU   Micropage    Stundenplan  AP 004     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009     Elektronisches Klassenbuch  AP 010        Basis  AP 001   ok     Basis   AP 002      MATAR  ok  https   intranet.tam.ch ken matar     IU  ok      Micropage  ok   https   intranet.tam.ch ken micropage    Stundenplan  AP 004   ok     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter    Elektronisches Klassenbuch  AP 010   ok     Die Module sind weitgehend bereit, die konkrete Konfiguration w re der n chste Schritt       Basis  AP 001    Basis   AP 002     MATAR  ok  https   intranet.tam.ch ken matar    IU  ok     Micropage  ok   https   intranet.tam.ch ken micropage   Stundenplan  AP 004   ok    Absenzenerfassung  AP 005    Absenzenprozesse  AP 006     Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter   Elektronisches Klassenbuch  AP 010   ok
# 3                                                                                         KST  MBA 1125513    IN2   Bl cke streichen l schen funktioniert nicht     Hallo zusammen    Das streichen von Bl cken funktioniert aktuell bei der KST nicht.  Das Fenster  ffnet sich zwar, man kann auch auf  Block streichen  klicken,  aber das Fenster schliesst sich dann und der Block ist dann nicht  gel scht gestrichen.    Evtl. hat es etwas mit diesem Ticket zu tun Incident  116149     Freundliche Gr sse  Dani              Hoi Dani        Reservationen funktionieren wieder, Ferien Blocks k nnen nach wie vor nicht    ver ndert werden.        LG        Kai Homberg            Auf live korrigiert.     Ist auf live     Auf stage korrigiert     funktioniert     Sollte auf stage gefixed sein. Kannst noch testen?     Habe es in diesem Fall in der DB gel scht.    Bitte anschauen     Jemand scheint  nderungen am Stundenplan unternommen zu haben.   Alle Ferien k nnen nicht mehr gel scht werden.     HolidayID   132, Karfreitag. Wieso l sst sich das nicht l schen?
# 4  KZI  MBA 1125671    IN2   IU Stundenplan   busy Lektion     Hallo zusammen    K nnt Ihr bitte die Lektion im Anhang f r die KZI l schen?     Freundliche Gr sse  Dani           Hallo Support     Das in Ticket MBA 1124354 gemeldete Problem, dass im IU Stundenplantool in  einem IU Lehrstundenplan ein  busy  Eintrag nicht gel scht werden kann, trat  nun wieder auf   Immerhin weiss ich unterdessen, wie das passiert  Wenn man den Stundenplan  eines Sch lers eingblendet hat und dann dort auf eine frei Lektion klickt,  erscheint nachher im Lehrerstundenplan eine  busy  Lektion.  So geschehen bei LP roger.ruetti.kzi   s. Beilage  Bitte diese Lektion l schen oder mir mitteilen, wie ich das erledigen kann.     Lieben Gruss Daniel Stucki     Das ist eine der Grundfunktionen des IU Planners  Will man bei einem Sch ler zus tzlich zum Grundstundenplan eine Lektion sperren, klickt man im Sch lerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.     Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   reworked_information
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Zusammenfassung:\n- Alle Module der KEN Mobile App wurden erfolgreich freigeschaltet.\n- Der Benutzerwechsel funktioniert jetzt problemlos.\n- Für das aktuelle Login benötigen KEN-Benutzer einen LDAP-Account, da das Login über ihren Azure-Tenant erst in Version 1.8 möglich ist.\n- Die LDAP-OU und UPN sind jetzt verfügbar.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Zusammenfassung:  Benötigt wird ein Beispiel für die Einrichtung von KEN-Schildern auf einem Raspberry Pi, nachdem der Raspberry Pi eingerichtet und mit KEN verbunden wurde.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                   The technical support ticket is about activating a KEN module MBA 1127666 and configuring various components such as Basis AP 001, Basis AP 002, MATAR, IU, Micropage, Stundenplan AP 004, Absenzenerfassung AP 005, Absenzenprozesse AP 006, Newsletter AP 009, and Elektronisches Klassenbuch AP 010. The ticket indicates that most modules are ready with specific configurations provided for each component. The next step would be to finalize the configuration settings. Links to access some components are also included in the ticket.
# 3  Issue: The function to delete or strike through blocks is not working for KST MBA 1125513.\n- Users can click on "Block streichen," but the window closes without deleting or striking through the block.\n- This issue may be related to another incident (Incident 116149) where reservations were fixed but holiday blocks still cannot be modified.\n\nActions taken:\n- Changes were made on the live and stage environments to correct the issue.\n- A specific holiday (HolidayID 132, Karfreitag) cannot be deleted, and adjustments were made in the database to address this.\n- It seems someone has made changes to the schedule affecting the ability to delete all holidays.\n\nFurther steps:\n- Verify if the fix on the stage environment is successful by testing the deletion/striking through blocks.\n- Investigate why the specific holiday (Karfreitag) cannot be deleted and ensure proper functionality for modifying holiday blocks.\n\nBest regards,\n[Assistant's Name]
# 4                                                                                                                                                                                                                                                                                                                                                 Summary:\n\n- User Dani reported a problem where a "busy" entry cannot be deleted from the IU lesson plan.\n- The issue occurred when displaying a student's schedule and clicking on a free lesson, resulting in the appearance of a "busy" lesson in the teacher's schedule.\n- The user has identified the cause of the problem and requested assistance in deleting the busy lesson.\n- Another user, Daniel Stucki, shared insight that the ability to lock/unlock a lesson is a fundamental function of the IU Planner.\n- It was mentioned that this functionality dates back to the Intranet Version 1, which is approximately 15 years old.

# %%
### how many clusters do we have after the hierarchical clusteirng?
from scipy.cluster.hierarchy import fcluster
import numpy as np

# Assuming 'Z' is your linkage matrix from hierarchical clustering
# Specify the maximum cophenetic distance (this is an example value; adjust based on your dendrogram)
max_distance = 1.25

# Obtain the cluster labels
cluster_labels = fcluster(Z, max_distance, criterion='distance')

# Add the cluster labels to your DataFrame
df['cluster_label'] = cluster_labels

# Count the unique cluster labels
num_clusters = np.unique(cluster_labels).size

print(f"Number of clusters formed: {num_clusters}")
# Out:
# Number of clusters formed: 7

# %%
from transformers import AutoTokenizer, pipeline

# Load tokenizer and summarization model
tokenizer = AutoTokenizer.from_pretrained('facebook/bart-large-cnn')
summarizer = pipeline("summarization", model="facebook/bart-large-cnn", tokenizer=tokenizer)

def windowed_summarization(text, chunk_max_length=1020, stride=200, final_max_length=50):
    """
    Summarize text by dividing it into manageable chunks based on tokens,
    then summarizing each chunk and combining the summaries. Finally, summarize the combined
    summary to ensure it is concise.

    :param text: The input text to summarize.
    :param chunk_max_length: The maximum token length for each text chunk.
    :param stride: The overlap between chunks.
    :param final_max_length: The maximum token length for the final summary.
    :return: The final summarized text.
    """
    # Tokenize the entire text and split into chunks with overlap
    input_ids = tokenizer.encode(text, return_tensors="pt", truncation=True, max_length=None).squeeze()
    total_length = input_ids.size(0)
    chunk_summaries = []

    # Iterate over the tokenized input in chunks
    for i in range(0, total_length, chunk_max_length - stride):
        chunk_input_ids = input_ids[i:i+chunk_max_length]
        chunk_text = tokenizer.decode(chunk_input_ids, skip_special_tokens=True)

        # Summarize the chunk
        try:
            summary = summarizer(chunk_text, max_length=50, min_length=25, do_sample=False)[0]['summary_text']
            chunk_summaries.append(summary)
        except Exception as e:
            print(f"Error summarizing chunk starting at token {i}: {e}")

    # Combine the summaries of all chunks into a final summary
    combined_summary = " ".join(chunk_summaries)

    # Further summarize the combined summary to ensure it's not too long
    try:
        final_summary = summarizer(combined_summary, max_length=final_max_length, min_length=30, do_sample=False)[0]['summary_text']
    except Exception as e:
        print(f"Error in final summarization: {e}")
        final_summary = combined_summary  # Fallback to combined summary if error occurs

    return final_summary
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-1b4b3f08aca8> in <cell line: 5>()
#       3 # Load tokenizer and summarization model
#       4 tokenizer = AutoTokenizer.from_pretrained('facebook/bart-large-cnn')
# ----> 5 summarizer = pipeline("summarization", model="facebook/bart-large-cnn", tokenizer=tokenizer)
#       6
#       7 def windowed_summarization(text, chunk_max_length=1020, stride=200, final_max_length=50):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     903     if isinstance(model, str) or framework is None:
#     904         model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 905         framework, model = infer_framework_load_model(
#     906             model,
#     907             model_classes=model_classes,
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     277
#     278             try:
# --> 279                 model = model_class.from_pretrained(model, **kwargs)
#     280                 if hasattr(model, "eval"):
#     281                     model = model.eval()
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     559         elif type(config) in cls._model_mapping.keys():
#     560             model_class = _get_model_class(config, cls._model_mapping)
# --> 561             return model_class.from_pretrained(
#     562                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     563             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3162                         "_commit_hash": commit_hash,
#    3163                     }
# -> 3164                     resolved_archive_file = cached_file(pretrained_model_name_or_path, filename, **cached_file_kwargs)
#    3165
#    3166                     # Since we set _raise_exceptions_for_missing_entries=False, we don't get an exception but a None
#
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     396     try:
#     397         # Load from URL or cache if already cached
# --> 398         resolved_file = hf_hub_download(
#     399             path_or_repo_id,
#     400             filename,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_validators.py in _inner_fn(*args, **kwargs)
#     116             kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
#     117
# --> 118         return fn(*args, **kwargs)
#     119
#     120     return _inner_fn  # type: ignore
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, local_dir_use_symlinks, user_agent, force_download, force_filename, proxies, etag_timeout, resume_download, token, local_files_only, legacy_cache_layout, endpoint)
#    1455                     _check_disk_space(expected_size, local_dir)
#    1456
# -> 1457             http_get(
#    1458                 url_to_download,
#    1459                 temp_file,
#
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py in http_get(url, temp_file, proxies, resume_size, headers, expected_size, _nb_retries)
#     522         new_resume_size = resume_size
#     523         try:
# --> 524             for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     525                 if chunk:  # filter out keep-alive new chunks
#     526                     progress.update(len(chunk))
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in generate()
#     814             if hasattr(self.raw, "stream"):
#     815                 try:
# --> 816                     yield from self.raw.stream(chunk_size, decode_content=True)
#     817                 except ProtocolError as e:
#     818                     raise ChunkedEncodingError(e)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     934         else:
#     935             while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 936                 data = self.read(amt=amt, decode_content=decode_content)
#     937
#     938                 if data:
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     877                 return self._decoded_buffer.get(amt)
#     878
# --> 879         data = self._raw_read(amt)
#     880
#     881         flush_decoder = amt is None or (amt != 0 and not data)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in _raw_read(self, amt)
#     812
#     813         with self._error_catcher():
# --> 814             data = self._fp_read(amt) if not fp_closed else b""
#     815             if amt is not None and amt != 0 and not data:
#     816                 # Platform-specific: Buggy versions of Python.
#
# /usr/local/lib/python3.10/dist-packages/urllib3/response.py in _fp_read(self, amt)
#     797         else:
#     798             # StringIO doesn't like amt=None
# --> 799             return self._fp.read(amt) if amt is not None else self._fp.read()
#     800
#     801     def _raw_read(
#
# /usr/lib/python3.10/http/client.py in read(self, amt)
#     464                 # clip the read to the "end of response"
#     465                 amt = self.length
# --> 466             s = self.fp.read(amt)
#     467             if not s and amt:
#     468                 # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from transformers import GPT2Tokenizer

# Load the tokenizer
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')


def gpt_3_5_turbo_windowed_summarization(text, chunk_max_length=3200, stride=400, final_max_length=150):
    """
    Summarize text using the GPT-3.5-turbo model's chat completion endpoint.
    """
    # Break the text into chunks
    chunks = [text[i:i+chunk_max_length] for i in range(0, len(text), chunk_max_length - stride)]
    chunk_summaries = []

    # Summarize each chunk
    for chunk in chunks:

        # for testing length --> bug
        # Tokenize text and count tokens
        tokens = tokenizer.encode(chunk)
        token_count = len(tokens)
        print("********** TOKENS INSIDE THIS CHUNK ", token_count)

        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "system", "content": "You are are highly capable technical supporter. You categorize the following text with single-word-labels."},
                      {"role": "user", "content": chunk}]
        )
        summary = response['choices'][0]['message']['content']
        chunk_summaries.append(summary)

    # Combine the summaries of all chunks
    combined_summary = " ".join(chunk_summaries)

    # Summarize the combined summaries to ensure conciseness
    final_response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "system", "content": "You are are highly capable technical supporter. You categorize the following text with single-word-labels."},
                  {"role": "user", "content": combined_summary}]
    )
    final_summary = final_response['choices'][0]['message']['content']

    return final_summary

# %%
import pandas as pd

# Assuming 'df' is your original DataFrame with 'reworked_information' and 'cluster_label' columns

# Initialize your summarization function and models here
# from transformers import AutoTokenizer, pipeline
# tokenizer = AutoTokenizer.from_pretrained('facebook/bart-large-cnn')
# summarizer = pipeline("summarization", model="facebook/bart-large-cnn", tokenizer=tokenizer)
# def windowed_summarization(text, chunk_max_length=1020, stride=200, final_max_length=50):
    # Your function definition

# Create a new DataFrame for summaries with unique cluster labels
unique_clusters = df['cluster_label'].unique()
df_summaries = pd.DataFrame(unique_clusters, columns=['cluster_label'])
df_summaries['summary'] = "NIX"  # Initialize the 'summary' column with a placeholder

for cluster_num in df['cluster_label'].unique():
    # Extract texts for the current cluster and combine them
    cluster_texts = df[df['cluster_label'] == cluster_num]['reworked_information'].tolist()
    combined_text = " ".join(cluster_texts)
    print("******** ", cluster_num, " ******* TOTAL TEXT")
    print(combined_text)

    # Summarize the combined text
    # summary = windowed_summarization(combined_text)
    summary = gpt_3_5_turbo_windowed_summarization(combined_text)

    # Correctly update the 'summary' in df_summaries for the current cluster_label
    # We find the row where 'cluster_label' matches cluster_num and update the 'summary' for that row
    df_summaries.loc[df_summaries['cluster_label'] == cluster_num, 'summary'] = summary

    print("*************** CLUSTER NUM ************: ", cluster_num)
    print(summary)  # Optionally print the summary for verification
    print("\n")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1233 > 1024). Running this sequence through the model will result in indexing errors
# ********  3  ******* TOTAL TEXT
# Zusammenfassung:
# - Alle Module der KEN Mobile App wurden erfolgreich freigeschaltet.
# - Der Benutzerwechsel funktioniert jetzt problemlos.
# - Für das aktuelle Login benötigen KEN-Benutzer einen LDAP-Account, da das Login über ihren Azure-Tenant erst in Version 1.8 möglich ist.
# - Die LDAP-OU und UPN sind jetzt verfügbar. Zusammenfassung:  Benötigt wird ein Beispiel für die Einrichtung von KEN-Schildern auf einem Raspberry Pi, nachdem der Raspberry Pi eingerichtet und mit KEN verbunden wurde. Zusammenfassung:
# Ein Benutzer hat festgestellt, dass der Notenexport in der Notenbuch-Liste nur die Standardperiode berücksichtigt. Um auch das Semester auswählen zu können und Fächer aus abgeschlossenen Perioden bearbeiten zu können, soll das Modul angepasst werden. Der Benutzer bittet um eine Aufwandschätzung für die Anpassung. Es sind mehrere Schritte erforderlich, einschließlich des Einbaus eines Periodenswitchers im Frontend, der Anpassung von Periodendaten und der Datenübertragung zwischen Frontend und Backend. Die geschätzte Aufwandschätzung beträgt 5 Stunden für das Frontend und 6 Stunden für das Backend. Es muss auch geklärt werden, ob Probleme beim Export auftreten könnten, wenn Noten aus alten Semestern wieder freigegeben werden. Zusammenfassung des Support-Tickets:
#
# Ein Benutzer namens Yvonne meldet ein Problem mit der Mobile-Version, die sich nicht an die Einstellungen im Konfigurationseditor für das Notenbuch hält. Im Desktop wird das Frühlingssemester angezeigt, während in der Mobile-Version nur das Herbstsemester sichtbar ist. Es wird empfohlen, dass die Mobile-Version die Einstellungen aus dem Desktop übernehmen sollte. Es wird angemerkt, dass die App nur die Semester anzeigt, in denen der Schüler Noten hat, und dass dies zu Diskussionen mit der IT-Abteilung führt. Es wird vorgeschlagen, die Konfigurationen aufzuräumen und zu prüfen, ob die API die korrekten Werte liefert. Es wird auch diskutiert, dass eine Diskussion darüber notwendig ist, wie sich Desktop- und Mobile-Versionen annähern können. Philippe und Daniel stellen Rückfragen und bieten an, weiter zu helfen. Der Benutzer KEN möchte, dass die Loginseite auf der Live-Umgebung noch etwas aufgehübscht wird, um sicherzustellen, dass die beiden Kästchen ihre übliche Breite haben. Diese Änderung wurde bereits auf der Testumgebung (Stage) durchgeführt und der Benutzer fragt, ob die Änderungen nun auf die Live-Umgebung übertragen werden sollen. Zusammenfassung der Support-Tickets:
#
# 1. Ein Benutzer namens Roman bittet darum, dass ehemalige Personen einen erweiterten Zugang zum Office 365 Konto haben, sodass sie nach ihrem Austritt noch einen Monat lang darauf zugreifen können. Er bittet darum, dass die Exportverzögerung auf 30 Tage erhöht wird.
#
# 2. Lukas beschreibt, dass derzeit Benutzer am Tag nach ihrem Austritt den Zugriff auf Office 365 verlieren und bittet darum, diese Frist auf 30 Tage zu verlängern. Er führt an, dass dies ihnen ermöglichen würde, entsprechende Schreiben vorzubereiten. Derzeit müssen sie mit den Austritten warten, bis die Benutzer ihre Unterlagen archiviert haben.
#
# 3. Sandro antwortet, dass der Abgleich entsprechend angepasst wurde. Benutzer werden jetzt erst nach 30 Tagen im Office 365 deaktiviert, und die Rollenbeziehung wird auch erst nach 30 Tagen gelöscht. Dadurch können Benutzer sich nach ihrem Austritt weiterhin 30 Tage lang anmelden. Zusammenfassung: Es wurde eine Anfrage nach einem aktuellen Auszug der VDI-Nutzer gestellt. Es wird gebeten, dies per E-Mail zu senden. - Problem: Das In2mobile-System aktualisiert nicht für den Benutzer "bahar.yilmaz.wskvw"
# - Version: 1.7
# - User Agent: Mozilla 5.0 iPhone; CPU iPhone OS 16_6 like Mac OS X AppleWebKit 605.1.15 KHTML, like Gecko Mobile 15E148
# - Benutzername: bahar.yilmaz.wskvw
# - E-Mail: bahar.yilmaz@wskvw.ch
# - Beschreibung: Das neue Semester aktualisiert nicht im System, obwohl das Semester noch nicht begonnen hat. Zusammenfassung:
# Roman bittet um Zugriff auf die Stage für Martin Lehmann, um Tests für das nächste Schuljahr durchzuführen. Er bittet auch darum, einen aktuellen Datenbank-Dump auf die Stage zu spielen. Der Zugriff auf die Stage wurde eingerichtet, die Datenbank ist aktuell. Ein Slack Befehl wird genutzt, um die Daten von Live in die Stage zu kopieren. Der Benutzer sollte auch im LDAP vorhanden sein. Es wird überprüft, ob der Benutzer im dev LDAP existiert und um eine Aktualisierung der Datenbank gebeten. Die Schüler der KZO sollten den Notentab in der Matar sehen können, jedoch wird dieser nicht angezeigt. Der Fehler liegt darin, dass es aktuell nicht vorgesehen ist, dass die Schüler diesen Tab sehen. Die Schüler erhalten ihre Noten an anderen Orten und sollen vermutlich keine Noten eingeben oder bearbeiten können. Das Verhalten wird nicht über die ACL gesteuert, sondern im Frontend wird der Tab für Schüler immer ausgeblendet. Dies liegt daran, dass es sich um einen Editor handelt. Es wird empfohlen, die Noten an anderen Stellen zu erfahren und den Tab nicht zur Verfügung zu stellen. Zusammenfassung:
# - Der Benutzer hat gemeldet, dass er keine neuen Einträge in den Playlisten erstellen kann und die Meldung erhält, dass der Server nicht erreichbar ist.
# - Der Benutzer konnte auch keine neue Playlist erstellen.
# - Nach einer Überprüfung funktioniert es jetzt wieder.
# - Es gab auch eine Unverträglichkeit der neuen PHP-Version mit einem Request-Parameter, bei dem ohne Typecast eine mathematische Berechnung durchgeführt wurde. Michael Bucher, ein Lehrer, hat Probleme beim Zugriff auf das Intranet (Balloon Zimbra) auf seinem iPhone. Er kann sich bis zur Eingabe von Name und Passwort anmelden, erhält dann jedoch eine Fehlermeldung "NoSuchFlowExecutionException" und kann nicht weitermachen. Die Fehlermeldung tritt unabhängig von anderen Faktoren auf. Es wird empfohlen, den Fall direkt dem Lieferanten zu melden. Es wird auch gefragt, ob die lokale Anmeldung auf dem iPhone ohne AAI funktioniert und ob der Zugriff über den Mailclient erfolgreich ist.
# ********** TOKENS INSIDE THIS CHUNK  1233
# ********** TOKENS INSIDE THIS CHUNK  1227
# ********** TOKENS INSIDE THIS CHUNK  143
# *************** CLUSTER NUM ************:  3
# 1. Freischaltung - Configuration
# 2. Benutzerwechsel - User switch
# 3. Login - Authentication
# 4. LDAP - Protocol
# 5. Einrichtung - Setup
# 6. Notenexport - Grade export
# 7. Anpassung - Customization
# 8. Aufwandschätzung - Estimation
# 9. Support-Ticket - Ticket
# 10. Mobile-Version - Version
# 11. Konfiguration - Configuration
# 12. Semesteranzeige - Semester display
# 13. API - Interface
# 14. Desktop - Platform
# 15. IT-Abteilung - Department
# 16. Konfigurationen - Configurations
# 17. Anpassung - Customization
# 18. Live-Umgebung - Production
# 19. Testumgebung - Testing
# 20. Personen-Zugang - Access
# 21. Office 365 - Service
# 22. Exportverzögerung - Delay
# 23. Zugriffsfrist - Deadline
# 24. Abgleich - Synchronization
#
#
# ********  4  ******* TOTAL TEXT
# The technical support ticket is about activating a KEN module MBA 1127666 and configuring various components such as Basis AP 001, Basis AP 002, MATAR, IU, Micropage, Stundenplan AP 004, Absenzenerfassung AP 005, Absenzenprozesse AP 006, Newsletter AP 009, and Elektronisches Klassenbuch AP 010. The ticket indicates that most modules are ready with specific configurations provided for each component. The next step would be to finalize the configuration settings. Links to access some components are also included in the ticket. The request is to set up access to the KEN Stage for multiple individuals with specific permissions. The individuals include those from the school leadership, administration, IT team, timetable, and absences. The access should be granted with admin rights for some individuals. The request mentions that KEN currently does not use IN2, so there should be no issues accessing and configuring directly on live for testing purposes. Test data can be deleted afterward. Transferring all settings from Stage to live in this capacity will be time-consuming. All individuals have been booked for access to IN2 testing. The user is requesting the setup of a VDI service account for the KRM to allow for a general login for scanning to a specific folder. The reason for this request is to streamline the scanning process and avoid the need for individual logins for each scan. The user provides details of the MFD device, Xerox AltaLink C8170, where the general user "scan2folder krm" with specific permissions should be set up. Additionally, the user requests the password to be sent to a specific phone number for security reasons. There is also mention of an analogous user "scan2folder ksl" in OU KLI. Summary: Max requested the deletion of VDI user "asja.dinkelmann" due to the user no longer working with the company. The account has been deactivated as per the request. Summary:
# - Request to set up NAM functionality on KFR system for Intranet use.
# - Preparation for data capture and synchronization requested.
# - School needs to capture data, export is OK, small modifications are completed, NAM registration is OK, but data capture is not successful yet. Summary of technical support ticket:
#
# - Request to activate NAM in KRR system with specific instructions on making measures visible in IN2 for FLP courses and creating a new tab for NAM with memo5 measures next to Personalien Promotion.
# - Mention of following instructions to set up NAM tab in IM and fill it with test data for a student.
# - Request for enabling synchronization between IM and IN2.
# - Confirmation of setting up exports and lists in IN2, with some issues reported for NAM tab in the list 40. Summary of Technical Support Ticket:
# - User: Beatrice Zanoni
# - Organization: Kantonsschule Wiedikon
# - Issue: Transition from KEN to KWI VDI has caused problems as the IT department overwrote the VDI settings without transferring necessary access. As a result, Beatrice is unable to save files in the KWI VDI.
# - Request: Clarification on the specific network share that Beatrice is trying to save to, visibility of the share, and her access rights. Beatrice is assigned to the appropriate KWI user groups.
# - Communication has been forwarded to the Digital Service Center Sek II for further investigation and resolution. Summary:
# - The ticket is regarding the migration of the Berufsschule für Detailhandel und Pharmazie Zürich (BSDPZ) to the LEUnet network in April.
# - Access for the Swisscom Bind User is needed for the school.
# - A request was made to create an account named "wifi schulclient.dhz" with the password to be sent via SMS.
# - Groups and permissions for the school's systems were detailed in the ticket.
# - The school will use various networks, with specific IP ranges allocated for different purposes like WLAN, LAN, and BYOD.
# - The school abbreviation is "dhz" and the WiFi user is "wifi schulclient.dhz."
# - The ticket includes a list of groups for the school and specifies that the responsible person will be available for further questions next week. Summary:
# - Request to set Common Names and course labels for courses in the IM department.
# - Common Names and course labels are important for creating teams for each course.
# - Ticket opened during the semester switch.
# - Contacts:
#   - Ursula Quiblier, IN2 Poweruser, ursula.quiblier@kwi.ch, 044 457 71 20
#   - Philippe da Silva Wong, IT Responsible, philippe.dasilva@kwi.ch, 044 457 71 68
# - Issue to be resolved internally within the school. Summary:
# - Request to create a VM Ware Horizon VDI access for Martin Weber similar to Marco Bieri.
# - Marco Bieri template was used as a basis for Martin Weber since Marco is no longer available.
# - Martin Weber has been created as a user with almost all rights in the database or IM, including admin rights for all schools.
# - Individual and mass mailings have not been added to IM yet, as the necessary parameters are not clear.
# - There is currently no form available for MBA members; duplicating the Marco Bieri account for Martin Weber is suggested in the absence of a form. The ICT team has renewed their certificates and is requesting suppliers and partners to update the new certificate provided in the email attachment for their applications, specifically for the site notenbuch.kvzschule.ch. The password for the certificate will be sent via SMS to the number 0041793533775. They are asking for a prompt email confirmation once the certificate is updated. The email includes contact details for KV Zürich IT Service Desk. A follow-up response indicates that the certificate has been updated, but the recipient has not yet received the password via SMS. Summary:
# Karin Grob from Kantonsschule Wiedikon needs assistance in protecting a folder named "Personal" located within the Sekretariatsordner S. The folder contains confidential data, and she wants to restrict access to it. She has requested help in either setting up the protection or receiving instructions on how to do it herself. It is suggested that she create the folder in her Home H drive, where it will be automatically restricted only to her. The IT team does not apply special permissions to the shared folders S, R, T, and P. Summary:
# The user is requesting assistance with the automatic creation of Balloon folders for new classes (M3b, SPF, and MN3b) in the system, similar to a previous request from last summer (Ticket 1115031). They have forwarded an email thread where it was mentioned that the school needs to make the necessary adjustments. The issue has been escalated to the Digital Service Center Sek II with the request to address the missing CommonNames and Labels for the courses. The user is seeking help in resolving this ticket and mentions the involvement of a PowerUser from the KSL school for the resolution. Summary:
# - Simon Grünwald from the Kanton Zürich's Bildungsdirektion requests to add ilez.zh.ch as a Redirect URL for the authentication of the ILEZ application through Shibboleth.
# - Michael Galli and Daniel Thalmann encounter issues with LDAP synchronization, Shibboleth AAI login, and report generation after updating the server environment to TEST level.
# - Michael Galli successfully tests authentication via Azure, email sending, document upload/download, Excel generation, and automated email triggering in case of errors.
# - Simon Grünwald raises concerns about DNS resolution for ilez.zh.ch and requests assistance with resolving connectivity issues in the VDI environment.
# - Alexander Gysel informs Simon about the redirection changes for ilez.zh.ch but encounters connectivity problems and requires further assessment to ensure functionality.
# - Simon Grünwald reiterates the need to add ilez.zh.ch as a Redirect URL for ILEZ application authentication and seeks clarification on the existence of a service provider for ILEZ configuration. Summary: The ticket is a request for the creation of an ISDS (Information Security Management System) and a risk analysis for the Information Manager by mid-March. The task is related to the project "DIWASEKII" with a document link provided for reference. The user anticipates completion by Easter. Summary:
# - Daniel Stucki from Kantonsschule Zimmerberg is having trouble with the "Vom Unterricht abmelden" (unregister from class) function in the school's intranet.
# - After selecting the affected lessons, an error message stating "Es fehlen die nötigen Konfigurationen" (necessary configurations are missing) appears.
# - The issue has also been confirmed by the servicedesk.
# - Andreas Stüssel is requesting a check and feedback on the problem.
# - Contact information provided: Education Directorate of Canton Zurich, Digital Service Center for Secondary II, Zurich.
# - The email also includes an example and references to images on a ticketing system and Slack for more information. Summary:
# - A request was made to create two VDI user accounts for the Realgymnasium Rämibühl in Zürich.
# - The accounts were successfully created.
# - The school requested to remove four users from the list and add the two new VDI users, making a total of 14 users.
# - User management will be automated starting next week, allowing schools to manage their own access.
# - Confirmation was given to cover the additional costs for 11 desks if they are to be charged.
# - A request was made for a list of the 18 users associated with the school KRR to ensure accurate billing. - Lieferung von elektronischen Bestellungen an die Kantonsschule Rychenberg mit Referenz VL23 28185
# - Enthält Kopie des Lieferscheins und Zertifikat
# - Weitere Informationen zur Aktivierung des Produkts unter https://infinigate.ch/landingpages/anleitung
# - Kontakt für Fragen oder Anliegen: Mico Baralic, INFINIGATE
# - Kontaktdaten: 041 799 01 01, mico.baralic@infinigate.ch
# - Adresse: Grundstrasse 14, CH 6343 Rotkreuz, www.infinigate.ch
# - Anweisung zur Lizenzdatei-Weiterleitung
#
# Bitte lassen Sie mich wissen, wenn Sie weitere Hilfe benötigen. Summary of Technical Support Ticket:
#
# - Michael Galli reported an issue regarding the redirect URI for the ilez.zh.ch server, indicating that it needs to be set up similar to ilez.mba.zh.ch. He provided details of the error message received and suggested testing the setup by selecting a school with AAI login on the ilez.zh.ch website.
#
# - Daniel Thalmann forwarded the issue to Alexander Gysel, who confirmed that the redirect URL had been added but mentioned that the ilez.zh.ch server was still not responding.
#
# - Earlier, Simon Grünwald had requested that the Shibboleth authentication for the ILEZ application include the URL ilez.zh.ch as a redirect URL. Michael Galli had also mentioned issues with LDAP synchronization, Shibboleth authentication, and report generation on a new server environment.
#
# - The communication involves multiple stakeholders and a series of requests regarding server updates, authentication configurations, and troubleshooting redirect URI issues. The user is requesting access for Andreas to view reservations of the KUS rooms, which are managed separately due to specific regulations. Andreas, as the Head of Central Services, should have visibility into all KUS room bookings, including special rooms like Musikzimmer. They occasionally exchange rooms with the KUS and need to view those reservations as well. The user mentioned that if there are not many reservations, they can handle them through the KUS secretariat. Andreas is not satisfied with the current view of reservations and is requesting to have separate guest accounts set up for Martin Landolt and Christine Kramer. There is confusion about whether a general test account should be created or if accounts should be specific to individuals. Andreas wants more access than what is currently available, suggesting the option of being added as a guest at the KUS to view any room. Summary:
# - Request to grant administrators of KSH access to the "SuS Absenzen" area in the Konfig Editor for increased autonomy.
# - Power users need more access permissions to work autonomously, specifically in configuring student absences.
# - Markus has suggested delegating the configuration of student absences to power users.
# - Request to explore possibilities for expanding access rights and roles, particularly the role of PU Intranet.
# - Decision on these matters should involve application owners Yvonne and Nicole.
# - Discussion needed on introducing new roles within the existing role class in the Identity Management system. Summary: The user is requesting the setup of a new profile "PPP" on the IM database for the KSH KHO, including basic configuration for the new school year 2024-25. They aim to start building the timetable by the end of March or early April. Additionally, the user mentions that another PPP order from Daniel Weber will follow, indicating that the profile has been created and the initial subject sort order has been filled. Summary:
# Daniel Weber from KS Im Lee Winterthur is requesting the setup of a new profile "PPP" for the school year SJ2024/25, similar to a previous order for Markus. He seeks guidance on adding entries to the "profile" and "profile relation" tables, potentially needing entries in additional tables. Daniel asks about making these entries or if someone else should handle them, and whether there are guidelines for the profile ID. The school offers five profiles (A, N, MN, M, PPP) and desires all possible combinations for classes and courses to be covered. Daniel has already captured the profile and performed the initial subject sort order filling. Zusammenfassung des Support-Tickets:
# - Das Intranet der Kantonsschule Freudenberg in Zürich ist seit gestern nicht erreichbar. Es wird vermutet, dass dies mit einem möglichen Hacking-Vorfall im Rahmen eines Informatikunterrichtsprojekts zusammenhängen könnte, bei dem Schüler versucht haben, Schullogin-Passwörter zu knacken.
# - Trotz der Schutzmaßnahmen wird nicht ausgeschlossen, dass der Angriff erfolgreich sein könnte. Es wird beobachtet, ob es eine Verbindung zwischen den Login-Versuchen der Schüler und der aktuellen Störung gibt.
# - Die Prorektorin Lea Castiglioni steht für weitere Informationen zur Verfügung, erwähnt aber auch, dass sich die Situation mittlerweile beruhigt hat. Es wird auf einen Artikel zu ethischen Hackern und den rechtlichen Folgen des Hackens hingewiesen, ohne weiteren Kommentar. Summary of Technical Support Ticket:
#
# - User Franz Ferdinand Lehnert from KWI requested the Student Absence and Dispensations modules for a redesign of the absences system.
# - The modules are ready, but the Dispensations module still needs to be activated and integrated into the navigation.
# - Two sub-tickets were created for Carlo and Marius, who are knowledgeable about these modules.
# - Request to set up both modules, preferably on the Live system for Franz to present on Stage. Summary of technical support ticket:
#
# The ticket requests the setup of a new PPP profile for SJ2024/25 MBA 1127665 at KSL, to be implemented from the 2024/25 summer break. The user asks for necessary entries to be made in the IM database or executed by gyselroth so that they can later input class schedules. Further, it states that no additional intervention seems necessary after the adjustments have been reviewed and approved. The user indicates readiness to begin entering class schedules for the PPP profile. Additionally, it clarifies that mixed profiles are not used, and instead, there are partial classes with corresponding profiles (e.g., Class A3 with Profile A, Class N3a with Profile N). Both classes participate in subjects like German, with specific combinations denoted (Deutsch GF, GF DjTj, A3, N3a). The profile has been set up and is available in the class schedule. Finally, it inquires about any planned classes with mixed profiles as additional mixtures would need to be recorded if so. The ticket concerns the adjustment of procedures for naming new classes in the context of introducing a new profile (PPP). The KSH KHO needs to update the display names of all Gymi classes, particularly focusing on the "saveas" designation for new classes. The planned approach includes creating new Gymi classes for the HS 2024-25 term and renaming existing classes. There is a discussion about ensuring that existing "saveas" names remain while implementing new naming rules for new classes. There is also a clarification regarding the naming conventions for classes in different semesters. Additionally, there are questions raised about renaming all existing WR classes and ensuring consistency in naming across different semesters. Ultimately, there is a request to confirm if all existing WR classes should receive new names starting from the new school year and if name changes in previous semesters should be prevented. Summary: The user "Ruven Witzig" needs assistance with setting up various accounts and permissions. Specifically, they require help with setting up a mail account (witzig@gyselroth.com) with permissions similar to "Carlo," VPN access, configuring a laptop for "Alex," setting up a Redmine account for "Philippe," a Moco account for "Andi," and a gitlab account for "Dani." Additionally, they need assistance with LDAP, Kerberos user setup, Zimbra account configuration, and setting up a home directory. Summary of technical support ticket:
#
# - Request to set up a parent login for the KWI (Classroom Web Interface) system to allow parents to electronically report their child's absences.
# - Further details include modifications to the system for the integration of parent logins.
# - The ticket was forwarded from Franz Ferdinand Lehnert on behalf of the school's KWI department.
# - Additional adjustments are noted for the importer process and specific system updates to accommodate parent logins. Summary:
#
# The user is requesting to order a new PPP profile, specifically a mixed profile with a language profile of N. They mention that there will likely be only half a PPP class in the 2024-25 school year. They also inquire about when they should take action again and mention that initial subject sort order entries have been made. Summary:
# A new VDI user account has been created for Kushtrim Veliji at Bildungsdirektion Kanton Zürich. However, there seems to be an issue with dossier access at KZI, as the drive "Dossier" is not available for the institution, only accessible for the secretary of Frau La Sorte. Summary: Stephan Looser from KZO school is requesting the setup of the necessary procedures in the IM for the Matar Tool in IN2. The procedures have been created and integrated into MiniInfo for preliminary testing. Stephan will be trained by MVs next week once the setup is completed. Further assistance will be provided if needed. The user is requesting to adjust Caren Auf dem Keller's VDI access by revoking access to drive R while maintaining access to drives S and IM. The request has been completed as access to drive R has been removed. Summary:
# The user, Andreas Stüssel, from MNG School requests the immediate cancellation of 3 VDI accesses, as detailed in the attached document. They mention that the VDI Automat is now operational, and these 3 users are in the deletion process, set to be deactivated in 10 days and deleted in 30 days. They prefer this process to run automatically without manual intervention. They request manual deactivation for the 3 users not caught by the automated process. There was an error as the deactivation period is still ongoing. Going forward, users will be automatically created and deleted, with only permission assignments needing manual handling. Summary: The email requests VDI access for a new user account named KS B elrain. The requestor, Kushtrim Veliji from the Bildungsdirektion Kanton Z rich, confirms that the new account has been granted the necessary permissions. Summary:
# - Request to review and verify a procedure for adjusting PPP classes as indicated by Kaspar.
# - When creating a new PPP class, the naming convention should be consistent, for example, a 1a class with a PPP profile should be named 1aP like the WR class 1aW, and not 1aPP.
# - Urgent adjustment of the procedure requested to be forwarded to Gyselroth.
# - Confirmation that the relevant procedure has been adjusted. Summary:
# A new VDI user, Leonardo Wild, has been successfully created and granted the necessary permissions. It seems that the school, specifically Bojan Golubicic, was not informed about this new process until recently. Everything is now set up from the KRL side. The next step is for the school to set the user as a VDI user and then the desired permissions will be assigned. Summary:
# - Roman requests for Stephan Looser to be granted access to the IN2 database.
# - Stephan also requests direct access to the IN2 database.
# - The user stephan.looser.kzo has been set up with read permissions for KZO, but the system still requires his mobile number for setting up a password. Summary: The user is requesting access to the Information Manager (IM) server for a test user named Robert TestteachB. The user provides the necessary details for setting up access and requests access to specific folders and resources. Additionally, the user thanks for the quick activation and requests assistance in assigning the test user to the appropriate groups for access to specific folders. Summary: The user is requesting the creation of a new profile named Neusprachlich PPP for the KZN system due to upcoming class allocations for the next school year. The profile has been made available for selection. Summary: The user is requesting the installation of a new MiniInfo procedure to set common names and course labels on courses under the "Common Names" folder. They have already installed the procedure for setting common names on classes. The procedures for common names and labels are available at all schools, but they need the specific procedure "TAMMI set commonname on course" to be administered at the KZI. The user is asking for Roman or Danijel to handle this request. Summary:
# - The Kantonsschule Wiedikon (KWI) has a specific request for a layout adjustment on their Typo3 website for mobile devices related to a video on the Baustand der Hohlstrasse.
# - Previous contact for website adjustments was Noemi Schmid, but now they are requesting contact with Mr. Philippe da Silva Wong at 044 457 71 53 to discuss details.
# - Urgency is emphasized as the ticket has been awaiting a response since 27.02.2024.
# - Contact person is Kushtrim Veliji from the Bildungsdirektion Kanton Zurich.
# - Requesting confirmation if action has been taken on this ticket.
# ********** TOKENS INSIDE THIS CHUNK  715
# ********** TOKENS INSIDE THIS CHUNK  733
# ********** TOKENS INSIDE THIS CHUNK  701
# ********** TOKENS INSIDE THIS CHUNK  783
# ********** TOKENS INSIDE THIS CHUNK  778
# ********** TOKENS INSIDE THIS CHUNK  722
# ********** TOKENS INSIDE THIS CHUNK  693
# ********** TOKENS INSIDE THIS CHUNK  656
# ********** TOKENS INSIDE THIS CHUNK  44
# *************** CLUSTER NUM ************:  4
# - Module Activation
# - Configuration
# - Access Setup
# - Permissions
# - VDI Setup
# - Data Synchronization
# - Migration
# - Networks
# - Groups
# - Settings
# - Tickets
# - Communication
# - Resolution
# - User
# - Account
# - Password
# - IP
# - WLAN
# - LAN
# - BYOD
# - Common Names
# - Course Labels
# - Teams
# - Contacts
# - Issue
# - VM Ware Horizon
# - User Rights
# - Admin Rights
# - Database
# - IM
# - MBA
# - Certificates
# - Suppliers
# - Partners
# - Email Confirmation
# - Service Desk
# - Protection
# - Folder
# - Confidential Data
# - Requests
# - User management
# - Costs
# - Billing
# - Delivery
# - Instruction
# - Support
# - Roles
# - Profile
# - Timetable
# - Entries
# - Guidelines
# - School
# - Intranet
# - Hacking
# - Incident
# - Ethical
# - Hackers
# - Legal
# - Information
# - Integration
# - Adjustment
# - Implementation
# - Readiness
# - Naming
# - Assistance
# - Account setup
# - Mail
# - VPN
# - Laptop
# - Redmine
# - Moco
# - Gitlab
# - LDAP
# - Kerberos
# - Zimbra
# - Home directory
# - KWI
# - Parent login
# - Absences
# - Franz Ferdinand Lehnert
# - Importer process
# - PPP profile
# - Language profile
# - Dossier access
# - Stephan Looser
# - KZO school
# - IM
# - Matar Tool
# - MiniInfo
# - Caren Auf dem Keller
# - Drive access
# - Andreas Stüssel
# - MNG School
# - VDI access cancellation
# - VDI Automat
# - KS Belrain
# - Kaspar
# - PPP classes
# - Date
# - Contact
# - Organization
# - Account Setup
# - Naming Convention
# - Permission Confirmation
# - User Creation
# - Access Request
# - Database Access
# - Test User Setup
# - Profile Creation
# - Procedure Installation
# - Website Adjustment
#
#
# ********  2  ******* TOTAL TEXT
# Issue: The function to delete or strike through blocks is not working for KST MBA 1125513.
# - Users can click on "Block streichen," but the window closes without deleting or striking through the block.
# - This issue may be related to another incident (Incident 116149) where reservations were fixed but holiday blocks still cannot be modified.
#
# Actions taken:
# - Changes were made on the live and stage environments to correct the issue.
# - A specific holiday (HolidayID 132, Karfreitag) cannot be deleted, and adjustments were made in the database to address this.
# - It seems someone has made changes to the schedule affecting the ability to delete all holidays.
#
# Further steps:
# - Verify if the fix on the stage environment is successful by testing the deletion/striking through blocks.
# - Investigate why the specific holiday (Karfreitag) cannot be deleted and ensure proper functionality for modifying holiday blocks.
#
# Best regards,
# [Assistant's Name] Summary:
#
# - User Dani reported a problem where a "busy" entry cannot be deleted from the IU lesson plan.
# - The issue occurred when displaying a student's schedule and clicking on a free lesson, resulting in the appearance of a "busy" lesson in the teacher's schedule.
# - The user has identified the cause of the problem and requested assistance in deleting the busy lesson.
# - Another user, Daniel Stucki, shared insight that the ability to lock/unlock a lesson is a fundamental function of the IU Planner.
# - It was mentioned that this functionality dates back to the Intranet Version 1, which is approximately 15 years old. Summary of Technical Support Ticket:
#
# - Since January 19, 2024, there have been issues with the absence workflow where absence letters have not been generated after exceeding threshold values.
# - Emails are being sent correctly, but absence letters like referral or request for exclusion are not being generated.
# - The problem seems to be related to the absence periods, as all relevant absences are still in the old period with only 1 in the new period.
# - Suggestions were made to analyze the underlying workflows and to potentially split the workflow for request for exclusion between past and current semesters.
# - Possible solutions discussed include lifting the constraint on absence periods, focusing on the current school year, and looking into the specific timeframe for absence periods.
# - It was noted that the workflow for request for exclusion only considers absences from the current absence period to avoid incorrect counts due to overlapping periods.
# - There was a request for a meeting to discuss further and find a solution as some absences fall between semesters.
# - It was clarified that absences are still within the old period and processes should trigger accordingly.
# - The issue is attributed to no student meeting the workflow conditions in the new absence period yet. Summary:
# - A request was made to not trigger disciplinary actions for a student named Gian Luca Ragolta due to having more than 2 disciplinary entries.
# - Discussions were held regarding adjusting processes related to disciplinary measures, specifically focusing on new incidents only.
# - There were issues with triggering a process for late arrivals in the "Information Training Company Delay" workflow due to defined conditions in the Excel sheet.
# - Concerns were raised about how disciplinary actions are consolidated and displayed in workflows.
# - Further discussions revolved around customizing workflows to consider specific types of tardiness entries and refining group and status combinations for disciplinary actions. The user reported an issue with dispensations in the KRL system being separate from absences, leading to duplicate entries for the same lesson. They discussed with the KRL team and agreed to have dispensations listed under absences, similar to other schools. They requested existing dispensation entries to be transferred and the dispensation type column to be hidden. Updates were made to implement these changes on the live system.
#
# Changes included updating absence types and entries, deleting unnecessary groups and statuses, and modifying dispensation combinations. The user also requested testing changes on the stage environment. They inquired about the difference between "dispensed" and "dispensation" entries and suggested removing one if necessary.
#
# The user encountered permission issues when trying to create absences and requested assistance in enabling the feature on the stage environment. They also sought clarification on the correct entries to display in the course view under absences.
#
# Overall, the user requested technical support in integrating dispensations correctly with absences in the KRL system and making necessary adjustments for a smoother user experience. Summary:
# When selecting multiple rooms and clicking on an available lesson in one room, a reservation notice is displayed multiple times corresponding to the number of rooms selected (e.g., if 2 rooms are selected, the notice appears twice, if 4 rooms are selected, it appears 4 times). This issue started when schools were allowed to enter their own notes. It seems to be a subsequent error, and a new ticket has been created. The issue has been fixed on the live stage, and testing is recommended. The problem should now be resolved, and the notes for all selected rooms should be displayed rather than repeatedly showing the note for the first room. The student Ella Vckovski is currently booked on two classes in FS24, which should not be possible. There was an issue with setting fields in the student information system, but it has been resolved by Susanne Flury. Please verify and ensure that the student is only booked on one class. Summary of Technical Support Ticket:
#
# - The issue involves incorrect absence numbers on the absence report for students in Class 4d.
# - Students are showing significantly higher absence numbers on the report compared to the actual absences recorded.
# - The problem seems to affect Class 4d and possibly other classes as well.
# - Various attempts and alternative solutions have been explored, including adjustments to the code for handling empty fields.
# - Developers have been notified to investigate and resolve the issue with missing student data in absence reports.
# - There are concerns about the accuracy of absence numbers for classes with multiple class teachers (KLP).
# - Testing and troubleshooting efforts are ongoing to pinpoint the source of the discrepancy.
# - The urgency is emphasized as reports need to be finalized before the last school day.
# - The issue appears to primarily impact Classes 4 and 5, while Classes 1-3 seem to be unaffected.
# - Collaborative efforts are being made to address the problem promptly and ensure accurate reporting for all classes. There are two main issues reported regarding the generation of the Abwesenheitenbericht max:
#
# 1. Students with 0 absences are not being displayed.
# 2. Immersion classes 4c, 4d, 4e, 5c, 5d, 5e are generating an error message in the fall semester.
#
# Additionally, there are requests for adding signatures to the reports Abwesendheitsbericht max, Abwesendheitsbericht, and Abwesendheitsbericht Schuljahr. It is mentioned that the correction has been made for KKN, KSH, and KST, and an update has been applied to the live version.
#
# Further, there is a request to streamline the system lists for counting student absences, suggesting having separate lists for each semester and school year. There are SQL discrepancies noted where the absences from the last 2 semesters are being counted instead of just one school year.
#
# Various modifications have been made to the SQL queries to address these issues, and the report templates have been updated accordingly. It seems that the corrections have been successfully implemented on the staging environment and need to be rolled out live for KKN, KHO, and KST.
#
# Lastly, an alternative solution is being sought for handling students with 0 absences in the reports, as the current approach involving subselects is not ideal. Suggestions for a better solution are requested. Summary:
# - The user is experiencing an issue with dispensations not showing a mail template when entered.
# - The problem was previously encountered in Incident 114934.
# - Despite not being able to reproduce the error, enhanced logging has been implemented to identify the cause when it occurs again.
# - The issue seems to stem from the generation of an HTML file from a DOCX file using soffice via a shell exec call.
# - An error related to absence status value is being displayed, which may not necessarily be a critical issue.
# - The error log indicates incomplete data for absence entries, leading to a missing HTML file.
# - Specific errors in the log suggest file handling and array key issues in the application models.
#
# Recommendation:
# - Continue monitoring and logging errors for further analysis.
# - Check file generation process and ensure data integrity for absence entries.
# - Investigate file handling and array key handling in the application models for potential bugs. Summary:
# - Users are experiencing slow performance and issues with the IU Planner (MBA 1126108).
# - Users report that it takes a long time for the IU Planner to open, there are delays when selecting and creating lessons, and the application sometimes closes unexpectedly.
# - The IU Planner is crucial for creating schedules for the next semester.
# - Some attempted solutions include loading students separately, utilizing Spinner for students and Scheduler, deploying Ajax Requests asynchronously, and suggesting improvements to specific functions in the code.
# - Users suggest optimizing queries and data retrieval to improve performance, as the current system is slow and outdated.
# - It is acknowledged that a complete overhaul of the IU Planner is needed for long-term improvement, but this is not currently feasible.
#
# Further action:
# - Investigate the reported issues with the IU Planner, particularly focusing on optimizing performance through query improvements.
# - Communicate with the development team about the need for a long-term solution to modernize the IU Planner for better performance. Summary:
# The user is reporting a problem with the Absence Processes system where deleted processes are still being listed under blocked processes. They explain that this issue occurred because some processes were deleted after a learner discontinued their education. The user suggests that deleted processes should not be listed under blocked processes and recommends updating the Workflow Engine to address this issue. They provide SQL commands to set the "exception" column to NULL for specific process IDs in the database to clean up the displayed processes. The user questions whether it would be better to handle such cases manually or modify the Workflow Engine. Summary: The user is requesting that certain lessons in the schedule database be marked as half-class courses so that they can be captured in the IU LPs lesson planning tool. The affected courses are EF courses held on Tuesdays over lunchtime as half-class courses, specifically lessons at 11:30-12:15 and 12:25-13:10. They have already made the lessons half-class in Untis, but note that it's a bit cumbersome to identify these lessons. If the school does not want to define the half-classes in Untis, they should provide the UntisID of the affected lessons for easier processing. The user is requesting assistance with activating student absence on the IN2 Mobile app for KRL. They mention not being able to see the option for absence recording in the app and ask for clarification on how to make it work. There is discussion about different absence statuses and errors encountered when trying to use the feature. It is mentioned that the ACL rules are not configured correctly and need to be adjusted for the student absence functionality to work properly. The user provides specific examples of error messages and acknowledges that the activation has been completed. The user is reporting an issue with multiple email fields appearing in the Dispensationstool, specifically the fields "E-Mail bei Anträgen" and "Antragsentscheiden senden an" which seem to be duplicated. They are seeking clarification on whether these fields serve different purposes or if the duplication is accidental. Another user is also seeking explanation on the difference between the two email fields in the Dispensationstool. A response explains that the first field is a dropdown with PersonClass roles to dynamically find the email recipient and authorize viewing and approving applications. Changes have been made to the texts in Ticket 113826 and will be reflected after testing. The user questions whether the duplication of the fields with different texts is intentional or unintentional. Summary of Technical Support Ticket:
#
# - Request to add two documents to specific containers in the Dispensationstool.
# - Mention of checking if merge fields were used correctly.
# - Confirmation that changes were made live.
# - Request to deploy changes to ensure only disp requests, not entire folder content, appear.
# - Suggestion to create a separate folder for DispGesuche.
# - Implementation of document template selection per container on stage.
# - Mention of testing backward compatibility.
# - Instructions on configuring templates using JSON input for specific containers.
# - Request to deploy changes after testing on stage.
# - Discussion on allowing multiple containers with different templates simultaneously.
# - Urgent request due to schools being back in session.
# - Proposal for adding a select with templates in the container editor.
# - Estimated time for additional features like multiple templates per container and frontend changes.
# - Mention of new feature of containerspecific templates and need for further clarification.
# - Additional documents were successfully added.
#
# Please let me know if you need further assistance or details. Summary:
# - The user reported an issue with accessing Dispensation settings in a container, where clicking on "Rechte verwalten" did not display anything. There was a suspicion that this could be related to an Active Directory (AD) problem.
# - The problem was identified as being caused by debug code in the merge function, which had overridden a parent function. The issue was fixed, and the ACL window now opens correctly.
# - However, the problem resurfaced with errors related to "Editor" properties being undefined when clicking on "Rechte verwalten" again.
#
# Action Taken:
# - Identified and fixed the initial issue related to the debug code.
# - Investigated the new error regarding "Editor" properties being undefined when opening Dispensation settings and reported it for further troubleshooting. The user is requesting to extend a website page to ensure all videos are fully visible, with further videos to be embedded directly. They provided a link to the specific page in question. Additionally, they mentioned that the issue is not with their site but with the video delivery from YouTube. They suggested a possible workaround of re-uploading the video to YouTube and embedding the new version. They also mentioned a CSS issue regarding the content area being limited and requested assistance from a web designer named Thomas to investigate why the page is limited at the bottom. Summary of Technical Support Ticket:
#
# - Request to activate student absence feature in the IN2 Mobile App for KRR.
# - Request to enable students to record absences through the Mobile App and save them with comments in the absence management system.
# - Configure editor settings for student absences, allowing entries up to 7 days in advance.
# - Request to differentiate between different absence types (JT and X) in the absence list.
# - Implement list 129 to show JTs in addition to absences.
# - Enable list 129 for KRR.
# - Activate the module for KRR, but students still do not have access due to future timetable restrictions.
# - Issue with students not having access to the new semester timetable due to restrictions, causing limitations on entry dates. 1. Roman has noticed a discrepancy in the representation of vacation days in the STKK report within the IN2 system. He questions whether the negative balance should be displayed and suggests checking all schools for accuracy.
#
# ...
# - In list 3, both LPs are displayed, but not in list 46.
# - In the BG course IN2 student view, only the deputy teacher from May is shown, not the main LP.
# - Main LP seems correctly entered in the IM, as per the screenshot.
# - Other views/lists show both LPs correctly displayed.
# - An adjustment was made in the List editor: a column "Lehrperson" instead of "Name Vorname."
#
# Users involved: Dani, Kerstin
#
# Action needed: Investigate why both LPs are not displayed in list 46 and ensure proper display. Summary:
# - The user is requesting manual initiation of a invoice for KS Zürcher Oberland (BK 7316) dated 26.02.2024 as the CSV file was not received.
# - The CSV file should have been located at mbazh.ch/fs/KZO/Templates/SAP Export/KZO IM SAP/20240226/1116.csv and could have been manually sent by the school.
# - An intervention in the database was needed to manually trigger the process.
# - A different file, 20240301/1137.csv, was sent instead.
# - A poorly forwarded PRTSCR (screenshot) is mentioned in the communication.
# - There is a mention of missing CSV from KZO to MBA Finanzen.
# - The user expresses frustration with ticket readability and clarity on expectations regarding where the CSV should have been directed.
# - Assistance is requested in resolving the issue. Summary of Technical Support Ticket:
#
# Ticket Number: INC 205140
# Issue: Displaying incorrect class information for students registered in multiple classes.
# Details: Some students are seeing classes from additional offerings instead of their main class when multiple classes are involved.
# Actions Taken: Proposed solution to only transfer relationships to main classes in the data interface file 'relations'.
# Further Steps: Need coordination between KVZ for exporter adjustments and GyselRoth for mapping and import changes.
# Potential Resolutions: Add a new column in the 'Class' table, which would require testing and additional work.
# Status: Ticket is open, awaiting feedback.
# Requested by: Stefan Clenin, ICT Applications Manager.
#
# Additional Correspondence:
# - Matthias approved the estimated day's work for the issue.
# - Suggestions for resolution include modifying database columns or hiding the information.
# - Discussion on determining the primary class for students at KVZ.
# - Exploring the impact of recent changes on class display inconsistency.
# - Querying the database to distinguish between primary classes and additional offerings. Summary of Technical Support Ticket:
#
# The user is requesting to adjust the Matura prognosis list in the KRL IM Prozedur MBA 1127649. They note that despite the subject Sport being traditionally included in the interim report as a recognition of the subject, it is being calculated regardless of being a GFDnTn type subject. They suggest that the Sport subject should not be counted in the calculation. There seems to be a discrepancy between how the list is generated in the FS system versus the HS system. The user mentions an issue with the Hochpunkte Kompensationszahl not being accurate due to the inclusion of the Sport grade, which could distort the overall picture, especially for students who excel in sports but not academically. The user is also looking into discrepancies in the calculations and requests examples from KRL to identify where the incorrect calculation is happening. Ticket 1:
# Request to delete a corrupt, orphaned MATAR from the database. The user "Roman" asks for assistance in deleting it.
#
# Ticket 2:
# There is a duplicate entry for the Maturit tsarbeit titled "Frauen in MINT Bereichen der Schweiz" in the database. One entry (MatarID 13) belongs to student Maja L thi and should be kept. The other entry (MatarID 50) appears as 0 in the system but couldn't be deleted. User "Dani" requests for the deletion of the duplicate entry to prevent issues during grade downloads.
#
# Resolution:
# No SoS was assigned initially, but it has been fixed now, and the duplicate Maturit tsarbeit entry was deleted successfully. Summary of technical support ticket:
# - The user "WSKVW" believes they are being billed for more users than they actually have and would like a list of the users being charged to review and clean up.
# - The user mentions that there are no system users at their school, and only real individuals with a login and LDAP object are counted for billing.
# - They inquire whether all the users being billed for are listed and ask for clarification on the absence of system users at WSKVW.
# - The user provides a SQL query to retrieve a list of PersonIDs, usernames, and PersonRoles from their database.
# - The user also shares a link to a document dated March 5, 2024, for reference. Summary:
# The user is encountering an error when trying to change a field from 'no certificate 1' to 'no certificate 0 in a course, and is unable to directly clear the checkbox in some courses. Even modifying the SQL database is not allowing the change from old value 1 to new value 0 in the 'no certificate' check2 field. The user found that a workaround is to first set the field to 'don't care' (NULL in the database), and then change it to 'no' (0 in the database). This behavior seems to be caused by a trigger and is not intended, but can be addressed by removing the trigger in the near future. Summary:
# - Adjustment of FF invoices for 576 MBA 1127834 due to KZN relocation to Irchel, resulting in 2 weeks less of teaching. FF IU invoices to be revised from 640 to 576 weeks with corresponding note in invoice field.
# - Request to centrally manage and trigger the one-time adjustment process via GR system.
# - IU courses are yet to be rectified and invoices not correctly stored in all locations.
# - Corrections made, invoices exported with new amounts, and changes reflected in SAP export order.
# - Rebilling scheduled for Tuesday morning, with Patrizia Prestigiacomo to initiate the process if approved.
# - Giusi prefers Solution 1, planning to provide feedback later and keeping the ticket open until then.
# - Solution 1 involves deactivating export job, adjusting amount in export table, and reactivating job. Suggests updating amount in IM table for accuracy.
# - Suggestion 2 proposes creating a new cost carrier of CHF 576 linked to IU courses for a clean solution. Issue: Duplicate student count displayed for user Matthias Scheller in the "Meine Kurse" section.
# Resolution: Added DISTINCT to the query for the "Anzahl" column to display correct student count. Problem resolved. - Issue reported with sorting of exams in List 121 based on text instead of date. Request for correction made by Christian Alpiger.
# - Mention of familiar SQL statements such as DATE FORMAT, CONCAT, GROUP CONCAT, CASE WHEN THEN END, etc., used repeatedly in various lists.
# - Gratitude expressed for assistance with the issue.
# - Request for a list of correct formats or a template for commands that can be adjusted in the List Editor.
# - Mention that the issue in List 123 was due to missing 'type date' in the column definition. The user is requesting technical support to set up a photo class list sorted by course in both "All Courses" and "My Courses" categories for KRL. They mention that the current template attached is correct, but it should display the course name and instructor. They also note that the list seems to be displaying class instead of courses and there might be issues with the sorting, specifically with "Olbrich" appearing before "Bohren." They attach images for reference and mention that the participant list is integrated with PDF download enabled. The user is checking if the support team understands the issue. The user is requesting access for the administrators of KRR, specifically martin.ehrismann@rgzh.ch, to edit the SubjectMapping table in the Table Editor. They are inquiring if this access can be granted through an ACL or if it needs to be requested. The user also mentions that under the "attribute tableEditor", read or write permissions can be granted per table, and they have now set this up for Martin. Summary: The user is requesting new subjects, specifically "Pädagogik und Psychologie" for the profile "PPP." They already have "Philosophie" from the elective subject list. As per the instructions provided, the user should open a new ticket for adding the subjects "Philosophie, Pädagogik und Psychologie" in the Oberkurs and Pädagogik und Psychologie categories. The user mentioned that the subjects "PP" and "PPP" have already been added. Summary:
# Yvonne requests clarification regarding the Changelog dated 21.02.2024, which mentions the availability of the SubjectMapping table for the Table Editor. Yvonne notes that the previous ticket (114386) relates to grade books, which will now be handled through IM Eco. Yvonne seeks confirmation on whether schools can edit the SubjectMapping table via the Table Editor instead of directly in the database. Yvonne inquires about the setup process for utilizing the SubjectMapping table through the Table Editor and notes that the table is not currently available in ACL for permission management. Yvonne also mentions that along with the read feature from ticket 116233, the SubjectMapping table will be included in the ACL. Summary of the technical support ticket:
# - Users are observing that former students (SuS) who have left the school still appear on the class list in the general information management (IM) interface.
# - There seems to be confusion about why a value is still displayed in the "current class" field for inactive students, even after they have left.
# - This issue has been ongoing since 2020, with many instances of former students still being listed under their last class.
# - The users are unsure if this is a technical problem with the IM system or if there is a mismanagement of student data on their end.
# - The suggestion is made to remove the "res12" field from the interface as it is only a cosmetic issue, with the last value being retained for former students as the nightly procedure is not executed on them. Other schools likely clear this field in the exit template. Summary of technical support ticket:
#
# - Issue reported by Roman regarding the display of students (SuS) being swapped in the Matar module.
# - Under FMA, F7P SuS are displayed instead of FMATK G SuS and vice versa.
# - Question raised about the rules for assigning the correct SuS to the respective final work.
# - Explanation given that each student can have one Matar per MatarType, and students with existing Matars of a certain type will not appear in the dropdown.
# - Discussion about the connection between ClassProfile and PersonProfile in relation to the assignment of Matar Types.
# - Investigation revealed that the backend and database seem to be in order.
# - Configurations for Matar Types FMA P and FMA hardcoded, but both have the same start semester, leading to the same dropdown.
# - Possible issue with the classLevel parameter and its relation to the assignment of work types and profiles. Summary:
# The user has observed that in the MN profile, the subjects PAM and BC now appear at the end of the report card for academic years 23/24 and 24/25, whereas previously they were located directly after the subject Mathematics. The user is questioning why this change occurred and suspects it may be related to a previous issue with the Semesterzeugnis. Additionally, they note that the subjects cannot be rearranged anymore. It is suggested that the issue may be a side effect of a correction made by the ZVAdmin and requests Advellence to investigate further. The teacher, david.jaeger@kszi.ch, is having trouble importing grades from the Wirtschaft Recht course of HS 2023/24, Class 6a, into the gradebook of FS 2024. He has tried three times, but each time an additional empty grade column is added instead of importing the previous semester data.
#
# There were two courses with the same Common Name in the previous semester, WR.SP.OS2018a.jad. One without any bookings was deleted, and now the importing process should behave the same as other courses. This can also be tested on the Stage environment.
#
# In the Course table, there are multiple course entries for the previous period 79 related to the Wirtschaft Recht course of FS 24, Class 6a. These entries are filtered using CourseCommonName, and the first entry used in the code seems to have no exams or grades.
#
# There is a specific issue with the mentioned course causing this unexpected behavior during the import process. Further investigation is needed to identify what is different about this course compared to others. Summary of Technical Support Ticket:
#
# - Issue: After logging in and clicking on the Enrollment for Freifächer Herbstsemester 2024/2025, the column "Ihre Wahl" is not visible initially. It only becomes visible after going back to the Home page and then revisiting the Enrollment section. This problem occurs on all browsers and clearing cache and cookies did not solve it.
# - Observations: The problem is not limited to one user but also affects other users like Philipp Wettstein. The issue can be reproduced by clearing cache and cookies and logging in as a specific user.
# - Resolution: The problem seems to be reproducible for g teacher and g student roles but not for Admin. Refreshing the page seems to temporarily resolve the issue if the column is not visible.
# - Additional Information: A video attachment demonstrating the issue is included in the support ticket.
#
# This ticket highlights an issue with the visibility of the "Ihre Wahl" column in the Enrollment section for specific user roles and provides details on how the problem can be reproduced and observed across different users and browsers. Summary of Technical Support Ticket:
#
# - The user is reporting that a course should not be displayed in the gradebook for the current semester FS24 as the instructor Thomas Oswald is not teaching Mathematics.
# - Despite the course taking place in the previous semester from 21.08.23 to 22.01.24, it is still being shown in the gradebook.
# - The user is seeking assistance in removing the course from the gradebook with the following details:
#   - Mathematics Course ID: 3286364, 1077660
#   - Instructor: Thomas Oswald
#   - Class: ME23 D
# - The user is asking if they need to wait for the deletion process to complete for the course to disappear from the gradebook and inquiring about the typical duration of this process.
# - There is an older course booking by the instructor for the course overlapping with the new semester (29.01.2024 - 30.01.2024) that is still in the deletion process.
# - There is a course entry in the PersonCourse table for the Mathematics course with CourseID 1077667, Instructor PersonID 5824434, StartDate 2024-01-29, EndDate 2024-01-30, corresponding to PeriodID 80 that began on 2024-01-29 according to the Period table. Two users have submitted support tickets regarding adding Spanish language support to a software interface. The first user, Roman, notes that there is no option available in the configuration editor to change the language to Spanish and requests assistance in adding this language. The second user, Dani, specifies that one student will be writing their thesis in Spanish and asks for Spanish to be added to the dropdown language selection in the thesis creation dialog. Additionally, they inquire about making a table editable in the TableEditor tool and offer to suggest which tables could be made editable. The support team has successfully added Spanish language support and may consider making the mentioned table editable as well.
# ********** TOKENS INSIDE THIS CHUNK  707
# ********** TOKENS INSIDE THIS CHUNK  635
# ********** TOKENS INSIDE THIS CHUNK  643
# ********** TOKENS INSIDE THIS CHUNK  631
# ********** TOKENS INSIDE THIS CHUNK  676
# ********** TOKENS INSIDE THIS CHUNK  697
# ********** TOKENS INSIDE THIS CHUNK  689
# ********** TOKENS INSIDE THIS CHUNK  673
# ********** TOKENS INSIDE THIS CHUNK  715
# ********** TOKENS INSIDE THIS CHUNK  724
# ********** TOKENS INSIDE THIS CHUNK  682
# ********** TOKENS INSIDE THIS CHUNK  772

# %%
df_summaries.head()

# %%
# Now create the labels out of the summarized clusters
cluster_labels = {}

def generate_label_for_summary(summary):
    conversation = [
        {"role": "system", "content": "You are a highly capable technical consultant."},
        {"role": "user", "content": f"Create 3 one-word-labels, that describes the following summary: {summary}"}
    ]

    try:
        # Call to OpenAI's GPT-3.5 Turbo API using the ChatCompletion endpoint
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=conversation,
            max_tokens=40,  # Adjust based on desired label length
            temperature=0.3  # A lower temperature for more deterministic output
        )
        label = response['choices'][0]['message']['content'].strip()
        return label
    except Exception as e:
        print(f"Error generating label: {e}")
        return "Label generation error"

# Iterate over the DataFrame and generate labels for each summary
for index, row in df_summaries.iterrows():
    summary = row['summary']
    label = generate_label_for_summary(summary)
    df_summaries.at[index, 'label'] = label

df_summaries.head()

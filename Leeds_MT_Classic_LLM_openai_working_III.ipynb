# %% [markdown]
# <a href="https://colab.research.google.com/github/andipasti/smupo/blob/main/Leeds_MT_Classic_LLM_openai_working_III.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os



# Now you can proceed with your code that requires this environment variable

from google.colab import userdata
os.environ['HUGGINGFACE_TOKEN'] = userdata.get('HUGGINGFACE_TOKEN')

# %%
import pandas as pd
# Loading the dataset from a JSON file
df = pd.read_json('./drive/Othercomputers/X1/code/datas.json')
display(df)
# Out:
#      issue_id                                        issue_title  \
# 0      116550  [MBA#1127156] Layout-Anpassung auf Typo 3 - We...
# 1      116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# 2      116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# 3      116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# 4      116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# ..        ...                                                ...
# 995    116165             KEN: Module freischalten [MBA#1127666]
# 996    116165             KEN: Module freischalten [MBA#1127666]
# 997    116164                            KEN: Signage einrichten
# 998    116163                        KEN: mobile App aufschalten
# 999    116163                        KEN: mobile App aufschalten
#
#                                      issue_description  journal_id  \
# 0    Guten Morgen\r\n\r\nIch habe eine eher speziel...      266857
# 1    Guten Morgen allerseits\r\n\r\nSchule: KSLZH\r...      266862
# 2    Guten Morgen allerseits\r\n\r\nSchule: KSLZH\r...      266861
# 3    Guten Morgen allerseits\r\n\r\nSchule: KSLZH\r...      266851
# 4    Guten Morgen allerseits\r\n\r\nSchule: KSLZH\r...      266847
# ..                                                 ...         ...
# 995  - Basis (AP 001)\r\n- Basis+ (AP 002) MATAR, I...      265988
# 996  - Basis (AP 001)\r\n- Basis+ (AP 002) MATAR, I...      264323
# 997        Bitte einen Beispiel-Raspi startklar machen      266525
# 998               Einfach mal alle Module freischalten      264890
# 999               Einfach mal alle Module freischalten      264884
#
#       journal_created_on                                      journal_notes  \
# 0    2024-03-25 10:02:24                                   Bist du da dran?
# 1    2024-03-25 10:28:33  > PS: Weiss man was das Problem war? LG Andrea...
# 2    2024-03-25 10:17:20  KRW Andreas Berger\r\nKSL Cseri Laszlo\r\n\r\n...
# 3    2024-03-25 09:49:46  Super danke :-)\r\n\r\nTest Servicedesk erfolg...
# 4    2024-03-25 09:40:21  Die Warteschlangen werden nun abgebaut, das Sy...
# ..                   ...                                                ...
# 995  2024-03-04 13:35:30  * Basis (AP 001) *ok*\r\n* Basis+ (AP 002)\r\n...
# 996  2024-02-02 15:04:40  * Basis (AP 001)\n* Basis+ (AP 002)\n** MATAR ...
# 997  2024-03-13 16:23:45            Raspi aufgesetzt und mit KEN verbunden.
# 998  2024-02-13 13:35:56  Super, der Benutzer wechsel klappt nun auch.\r...
# 999  2024-02-13 12:01:04              LDAP: ou und upn sind jetzt vorhanden
#
#      journal_author
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 995               0
# 996               0
# 997               0
# 998               0
# 999               0
#
# [1000 rows x 7 columns]

# %%
column_names = list(df.columns)
print(column_names)
# Out:
# ['issue_id', 'issue_title', 'issue_description', 'journal_id', 'journal_created_on', 'journal_notes', 'journal_author']

# %%
df.drop(['journal_id', 'journal_created_on', 'journal_author'], axis=1, inplace=True)

# %%
import pandas as pd

df_merged = df.groupby(['issue_id', 'issue_title', 'issue_description'])['journal_notes'].apply(lambda notes: '\n---\n'.join(notes)).reset_index()

df_merged.rename(columns={'journal_notes': 'merged_journal_notes'}, inplace=True)

# %%
import pandas as pd

# Assuming 'df' is your DataFrame
# First, convert all relevant columns to string type to avoid any concatenation issues
df = df.astype(str)

# Now, group by 'issue_id' and concatenate all information into a single cell
df_merged = df.groupby('issue_id').apply(lambda x: x['issue_title'].iloc[0] + '\n---\n' +
                                         x['issue_description'].iloc[0] + '\n---\n' +
                                         '\n---\n'.join(x['journal_notes'])).reset_index(name='all_information')

df_merged
# Out:
#     issue_id                                    all_information
# 0     116163  KEN: mobile App aufschalten\n---\nEinfach mal ...
# 1     116164  KEN: Signage einrichten\n---\nBitte einen Beis...
# 2     116165  KEN: Module freischalten [MBA#1127666]\n---\n-...
# 3     116166  KST [MBA#1125513] - IN2 - Blöcke streichen/lös...
# 4     116167  KZI [MBA#1125671] - IN2 - IU-Stundenplan - bus...
# ..       ...                                                ...
# 251   116537  KZN [MBA#1128871] IM: Neues gemischtes Profil ...
# 252   116538  Fwd: [MBA#1128639] AW: Druckereinstellungen Se...
# 253   116539  KZI Miniinfo Neue Common Name Prozedur für Kur...
# 254   116543  [MBA#1128940] Zimbra Störung komplette Schule:...
# 255   116550  [MBA#1127156] Layout-Anpassung auf Typo 3 - We...
#
# [256 rows x 2 columns]

# %%
column_names = list(df_merged.columns)
print(column_names)
# Out:
# ['issue_id', 'all_information']

# %%
# Set Pandas display options to show the full content of 'merged_journal_notes'
pd.set_option('display.max_colwidth', None)

df = df_merged
df
# Out:
#     issue_id  \
# 0     116163
# 1     116164
# 2     116165
# 3     116166
# 4     116167
# ..       ...
# 251   116537
# 252   116538
# 253   116539
# 254   116543
# 255   116550
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       all_information
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               KEN: mobile App aufschalten\n---\nEinfach mal alle Module freischalten\n---\nSuper, der Benutzer wechsel klappt nun auch.\r\nAber für das aktuelle Login bräuchten die KEN-User einen LDAP-Account, das Login über ihren Azure-Tenant geht erst mit v1.8.\n---\nLDAP: ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             KEN: Signage einrichten\n---\nBitte einen Beispiel-Raspi startklar machen\n---\nRaspi aufgesetzt und mit KEN verbunden.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         KEN: Module freischalten [MBA#1127666]\n---\n- Basis (AP 001)\r\n- Basis+ (AP 002) MATAR, IU & Micropage\r\n- Stundenplan (AP 004)\r\n- Absenzenerfassung (AP 005)\r\n- Absenzenprozesse (AP 006) \r\n- Newsletter (AP 009)\r\n- Elektronisches Klassenbuch (AP 010)\n---\n* Basis (AP 001) *ok*\r\n* Basis+ (AP 002)\r\n** MATAR *ok* https://intranet.tam.ch/ken/matar\r\n** IU *ok*\r\n** Micropage *ok*  https://intranet.tam.ch/ken/micropage\r\n* Stundenplan (AP 004) *ok*\r\n* Absenzenerfassung (AP 005)\r\n* Absenzenprozesse (AP 006) \r\n* Newsletter (AP 009) *ok* https://intranet.tam.ch/ken/newsletter\r\n* Elektronisches Klassenbuch (AP 010) *ok*\r\n\r\nDie Module sind weitgehend bereit, die konkrete Konfiguration wäre der nächste Schritt\n---\n* Basis (AP 001)\n* Basis+ (AP 002)\n** MATAR *ok* https://intranet.tam.ch/ken/matar\n** IU *ok*\n** Micropage *ok*  https://intranet.tam.ch/ken/micropage\n* Stundenplan (AP 004) *ok*\n* Absenzenerfassung (AP 005)\n* Absenzenprozesse (AP 006) \n* Newsletter (AP 009) *ok* https://intranet.tam.ch/ken/newsletter\n* Elektronisches Klassenbuch (AP 010) *ok*
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       KST [MBA#1125513] - IN2 - Blöcke streichen/löschen funktioniert nicht\n---\nHallo zusammen\r\n\r\nDas streichen von Blöcken funktioniert aktuell bei der KST nicht.\r\nDas Fenster öffnet sich zwar, man kann auch auf "Block streichen" klicken,\r\naber das Fenster schliesst sich dann und der Block ist dann nicht\r\ngelöscht/gestrichen.\r\n\r\nEvtl. hat es etwas mit diesem Ticket zu tun Incident #116149 \r\n\r\nFreundliche Grüsse\r\nDani\r\n——\r\n\r\n> \r\n> Hoi Dani\r\n> \r\n> Reservationen funktionieren wieder, Ferien-Blocks können nach wie vor nicht\r\n> verändert werden.\r\n> \r\n> LG\r\n> \r\n> Kai Homberg\r\n> \r\n>\n---\nAuf live korrigiert.\n---\nIst auf live\n---\nAuf stage korrigiert\n---\nfunktioniert\n---\nSollte auf stage gefixed sein. Kannst noch testen?\n---\nHabe es in diesem Fall in der DB gelöscht.\r\n\r\nBitte anschauen\n---\nJemand scheint Änderungen am Stundenplan unternommen zu haben. \r\nAlle Ferien können nicht mehr gelöscht werden.\n---\nHolidayID = 132, Karfreitag. Wieso lässt sich das nicht löschen?
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        KZI [MBA#1125671] - IN2 - IU-Stundenplan - busy-Lektion\n---\nHallo zusammen\r\n\r\nKönnt Ihr bitte die Lektion im Anhang für die KZI löschen? \r\n\r\nFreundliche Grüsse\r\nDani\r\n——\r\n\r\n>  Hallo Support\r\n \r\nDas in Ticket MBA#1124354 gemeldete Problem, dass im IU-Stundenplantool in\r\neinem IU-Lehrstundenplan ein «busy» Eintrag nicht gelöscht werden kann, trat\r\nnun wieder auf:\r\nImmerhin weiss ich unterdessen, wie das passiert: Wenn man den Stundenplan\r\neines Schülers eingblendet hat und dann dort auf eine frei Lektion klickt,\r\nerscheint nachher im Lehrerstundenplan eine «busy» Lektion.\r\nSo geschehen bei LP roger.ruetti.kzi - s. Beilage\r\nBitte diese Lektion löschen oder mir mitteilen, wie ich das erledigen kann.\r\n \r\nLieben Gruss Daniel Stucki\n---\nDas ist eine der Grundfunktionen des IU-Planners: Will man bei einem Schüler zusätzlich zum Grundstundenplan eine Lektion sperren, klickt man im Schülerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.\r\n\r\n(Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt :-) )
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  KZN [MBA#1128871] IM: Neues gemischtes Profil N/PPP\n---\nHallo zusammen\r\n\r\nBitte das neue Profil erfassen.\r\n\r\nVielen Dank im voraus\r\nGruess\r\nRoman\r\n  > Geschätztes Support-Team  \r\n> \r\n> Aufgrund der sich abzeichnenden Klasseneinteilung für das nächste Schuljahr\r\n> braucht die KZN neu das gemischte Profil Neusprachlich/PPP, das wir hiermit\r\n> gerne bestellen würden.\r\n> \r\n> LG\r\n> \r\n> Giusi\r\n> \r\n>\n---\nDas Profil N/PPP steht jetzt zur Auswahl
# 252                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Fwd: [MBA#1128639] AW: Druckereinstellungen Sekretariat KFR\n---\nHallo\r\n\r\nSeit der Umstellung auf Leunet hat die KFR Schwierigkeiten beim Drucken mit\r\ndem Drucker Canon ImageRunner Advance  C5560i, IP: 10.95.36.110\r\nDie Probleme treten nur in der VDI auf. Jedes Mal, wenn sie drucken wollen,\r\nmüssen sie zuerst den Drucker in der Liste anwählen, da dieser nicht als\r\nStandard eingestellt ist und es müssen auch alle weiteren Einstellungen wie\r\n«einseitig drucken» neu ausgewählt werden. Ausserdem druckt es immer nur ein\r\nExemplar aus, auch wenn man die Anzahl der Exemplare anpasst. Das Papierfach\r\nwird ebenfalls willkürlich ausgewählt. Habt ihr eine Idee wie man das beheben\r\nkönnte? Ihr könnt gerne etwas versuchen und wir testen das dann. Falls ihr\r\nnoch mehr Infos benötigt, dann liefere ich diese gerne nach. Danke!\r\n\r\nVG\r\nMax\n---\nSali,\r\n\r\nBitte kurz folgenden Drucker hinzufügen und testen:\r\n\\print002.mbazh.ch\KFR: Canon iR-ADV C5550-5560 PCL6.2\r\n\r\nUm die Liste für den Standard Drucker zu prüfen, benötige ich noch die Namen derjenigen, welche den als Standard hinterlegt haben sollten.\r\nDie Drucker sind normalerweise eingestellt Doppelseitig zu drucken, kann ich aber ändern.\r\nAuch das Papierfach kann ich anpassen, die Auswahl besteht hier aus Auto, Mehrzweck-Fach, Einzug 1, Einzug 2.\r\n\r\nGruss\r\nMartin\r\n\r\n\n---\nIst der Drucker in der Tabelle eingetragen?
# 253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            KZI Miniinfo Neue Common Name Prozedur für Kurse [MBA#1128844]\n---\nNach Rücksprache mit den MV verstehe ich, dass die Anleitung "CommonNames"\r\nnicht ohne eine weitere Installation einer Prozedur greift, deshalb gebe ich\r\ndas Ticket nun mit dem Auftrag zur untigen Anfrage von Daniel Stucki\r\n\r\nIch bitte um Installation der neuen MiniInfo-Prozedur zum Setzen der Common\r\nNames und Kurslabels auf KURSEN - wenn möglich im Ordner «Common Names».\r\nDie neue Prozedur zum Setzen der cn auf Klassen habe ich bereits installiert.\n---\nDie Prozeduren für CN und Labels sind bei allen Schulen vorhanden. An der KZI muss einfach noch spr_TAMMI_set_commonname_on_course im MiniInfo administriert werden (=> Roman, Danijel?)
# 254  [MBA#1128940] Zimbra Störung komplette Schule: E-Mails senden und empfangen (kslzh.ch) funktioniert nicht\n---\nGuten Morgen allerseits\r\n\r\nSchule: KSLZH\r\nMelder: Laszlo Cseri\r\n\r\nProblem Zimbra:\r\n\r\nWir (kslzh.ch) können keine E-Mails senden (auch Mails von GMX und icloud.com versendet) und empfangen. Im Webmail erhalten wir folgende Hinweise beim versenden von E-Mails:\r\n\r\n!clipboard-202403250751-h8l4i.png!\r\n\r\n!clipboard-202403250751-h6e8a.png!\r\n\r\nEine Überprüfung mit MXToolbox zeigt bei einem SMTP-Check folgendes an: \r\n\r\n!clipboard-202403250751-2pdnb.png!\r\n\r\nDürfen wir euch bitten, das Problem sofort zu beheben?\r\n\r\nNachtrag: Bei meinen Recherchen habe ich festgestellt, dass es auch die stud.kslzh.ch-Domain auch betrifft:\r\n\r\n!clipboard-202403250752-fxdsc.png!\r\n\n---\n> PS: Weiss man was das Problem war? LG Andreas Stössel\r\nIm Detail nicht.  Die Kommunikation zwischen MTA und Edge-Server war gestört, aber man sieht nicht, was das ausgelöst hat.\r\n(Das System ist schon länger im EoL-Status, wir investieren keine Zeit mehr in Fehlersuche)\r\n\r\n\n---\nKRW Andreas Berger\r\nKSL Cseri Laszlo\r\n\r\nRückmeldung Zimbra funktioniert wieder :-) \r\n\r\nPS: Weiss man was das Problem war? LG Andreas Stössel\n---\nSuper danke :-)\r\n\r\nTest Servicedesk erfolgreich. Versand von Zimbra und Empfang auf MBA Adresse i.o.\r\n\r\n!clipboard-202403250948-gpgxs.png!\r\n!clipboard-202403250948-st3cq.png!\r\n\r\nSieht also soweit wieder gut aus :-) Ich werde mal die Schulen anschreiben und warte auf Rückmeldung. LG Andreas Stössel\n---\nDie Warteschlangen werden nun abgebaut, das System scheint wieder normal unterwegs zu sein.\r\nKontrolliert doch mit euren Konten auch noch schnell.\n---\nNachtrag von KZU:\r\n\r\nMelderin: Andrea Emonds\r\n\r\nProblem: Absenzen können nicht versendet werden. (Wird Zimbra Problem sein, dies noch zur Kenntnisnahme):\r\n!clipboard-202403250922-bernz.png!\r\n\r\n\n---\nFolgende Details:\r\n!clipboard-202403250816-hxubf.png!\r\n\r\nAusserdem habe ich den Fehlerbericht im Zimbra gesendet.\n---\n\r\nServicedesk: Ich habe eine Test Mail erfolglos gesendet. Von Zimbra an andreas.stoessel@mba.zh.ch\r\n!clipboard-202403250810-kmwuh.png!\r\n\n---\nDie KRW und die KZU haben jetzt ebenfalls dieses Problem gemeldet\n---\nBeobachtet ihr mit eurer Domain it.mba.zh.ch den gleichen Effekt (für uns funktioniert alles, an den edge-Servern liegt's kaum)?
# 255                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [MBA#1127156] Layout-Anpassung auf Typo 3 - Webseite (KWI)\n---\nGuten Morgen\r\n\r\nIch habe eine eher spezielle Anfrage von der Kantonsschule Wiedikon.\r\n\r\nDie Kantonsschule Wiedikon wünscht eine Layout Anpassung für mobile Geräte zu machen für das Video welches auf der Webseite der KWI (Baustand der Hohlstrasse) hochgeladen wurde. Die Kontaktperson (bei früheren Anpassungen) bei euch war Noemi Schmid. Die Schule wünscht nun eine Kontaktaufnahme von euch  mit Herrn Philippe da Silva Wong, Tel. 044 457 71 53 um die Einzelheiten zu besprechen.\r\nWäre eine Kontaktaufnahme seitens von euch möglich?\r\n\r\nDieses Ticket eilt ein wenig da es schon länger auf eine Antwort wartet. Ich habe das Ticket am 27.02.2024 an euch weitergeleitet ohne Rückmeldung bis jetzt.\r\n \r\nFreundliche Grüsse\r\nKushtrim Veliji\r\n——\r\nBildungsdirektion Kanton Zürich\r\nMittelschul- und Berufsbildungsamt\r\nDigital Service Center Sek II\r\nAusstellungsstrasse 80\r\n8090 Zürich\r\nTelefon 043 259 77 27\n---\nBist du da dran?
#
# [256 rows x 2 columns]

# %%
import pandas as pd

# Example DataFrame
# df = pd.DataFrame({'text': ["Example text\r\n\r\nwith special characters &*%$#@!"]})

# Replace "\r\n\r\n" with a space
df['all_information'] = df['all_information'].str.replace(r"\n", " ", regex=True)
df['all_information'] = df['all_information'].str.replace(r"\r", " ", regex=True)

# Replace any character that is not a letter, number, or common punctuation with a space
df['all_information'] = df['all_information'].str.replace(r"[^a-zA-Z0-9\s.,;!?']", " ", regex=True)

print(df)
# Out:
#     issue_id  \
# 0     116163
# 1     116164
# 2     116165
# 3     116166
# 4     116167
# ..       ...
# 251   116537
# 252   116538
# 253   116539
# 254   116543
# 255   116550
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           all_information
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           KEN  mobile App aufschalten     Einfach mal alle Module freischalten     Super, der Benutzer wechsel klappt nun auch.  Aber f r das aktuelle Login br uchten die KEN User einen LDAP Account, das Login  ber ihren Azure Tenant geht erst mit v1.8.     LDAP  ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     KEN  Signage einrichten     Bitte einen Beispiel Raspi startklar machen     Raspi aufgesetzt und mit KEN verbunden.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              KEN  Module freischalten  MBA 1127666        Basis  AP 001     Basis   AP 002  MATAR, IU   Micropage    Stundenplan  AP 004     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009     Elektronisches Klassenbuch  AP 010        Basis  AP 001   ok     Basis   AP 002      MATAR  ok  https   intranet.tam.ch ken matar     IU  ok      Micropage  ok   https   intranet.tam.ch ken micropage    Stundenplan  AP 004   ok     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter    Elektronisches Klassenbuch  AP 010   ok     Die Module sind weitgehend bereit, die konkrete Konfiguration w re der n chste Schritt       Basis  AP 001    Basis   AP 002     MATAR  ok  https   intranet.tam.ch ken matar    IU  ok     Micropage  ok   https   intranet.tam.ch ken micropage   Stundenplan  AP 004   ok    Absenzenerfassung  AP 005    Absenzenprozesse  AP 006     Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter   Elektronisches Klassenbuch  AP 010   ok
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 KST  MBA 1125513    IN2   Bl cke streichen l schen funktioniert nicht     Hallo zusammen    Das streichen von Bl cken funktioniert aktuell bei der KST nicht.  Das Fenster  ffnet sich zwar, man kann auch auf  Block streichen  klicken,  aber das Fenster schliesst sich dann und der Block ist dann nicht  gel scht gestrichen.    Evtl. hat es etwas mit diesem Ticket zu tun Incident  116149     Freundliche Gr sse  Dani              Hoi Dani        Reservationen funktionieren wieder, Ferien Blocks k nnen nach wie vor nicht    ver ndert werden.        LG        Kai Homberg            Auf live korrigiert.     Ist auf live     Auf stage korrigiert     funktioniert     Sollte auf stage gefixed sein. Kannst noch testen?     Habe es in diesem Fall in der DB gel scht.    Bitte anschauen     Jemand scheint  nderungen am Stundenplan unternommen zu haben.   Alle Ferien k nnen nicht mehr gel scht werden.     HolidayID   132, Karfreitag. Wieso l sst sich das nicht l schen?
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          KZI  MBA 1125671    IN2   IU Stundenplan   busy Lektion     Hallo zusammen    K nnt Ihr bitte die Lektion im Anhang f r die KZI l schen?     Freundliche Gr sse  Dani           Hallo Support     Das in Ticket MBA 1124354 gemeldete Problem, dass im IU Stundenplantool in  einem IU Lehrstundenplan ein  busy  Eintrag nicht gel scht werden kann, trat  nun wieder auf   Immerhin weiss ich unterdessen, wie das passiert  Wenn man den Stundenplan  eines Sch lers eingblendet hat und dann dort auf eine frei Lektion klickt,  erscheint nachher im Lehrerstundenplan eine  busy  Lektion.  So geschehen bei LP roger.ruetti.kzi   s. Beilage  Bitte diese Lektion l schen oder mir mitteilen, wie ich das erledigen kann.     Lieben Gruss Daniel Stucki     Das ist eine der Grundfunktionen des IU Planners  Will man bei einem Sch ler zus tzlich zum Grundstundenplan eine Lektion sperren, klickt man im Sch lerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.     Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            KZN  MBA 1128871  IM  Neues gemischtes Profil N PPP     Hallo zusammen    Bitte das neue Profil erfassen.    Vielen Dank im voraus  Gruess  Roman      Gesch tztes Support Team          Aufgrund der sich abzeichnenden Klasseneinteilung f r das n chste Schuljahr    braucht die KZN neu das gemischte Profil Neusprachlich PPP, das wir hiermit    gerne bestellen w rden.        LG        Giusi            Das Profil N PPP steht jetzt zur Auswahl
# 252                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Fwd   MBA 1128639  AW  Druckereinstellungen Sekretariat KFR     Hallo    Seit der Umstellung auf Leunet hat die KFR Schwierigkeiten beim Drucken mit  dem Drucker Canon ImageRunner Advance  C5560i, IP  10.95.36.110  Die Probleme treten nur in der VDI auf. Jedes Mal, wenn sie drucken wollen,  m ssen sie zuerst den Drucker in der Liste anw hlen, da dieser nicht als  Standard eingestellt ist und es m ssen auch alle weiteren Einstellungen wie   einseitig drucken  neu ausgew hlt werden. Ausserdem druckt es immer nur ein  Exemplar aus, auch wenn man die Anzahl der Exemplare anpasst. Das Papierfach  wird ebenfalls willk rlich ausgew hlt. Habt ihr eine Idee wie man das beheben  k nnte? Ihr k nnt gerne etwas versuchen und wir testen das dann. Falls ihr  noch mehr Infos ben tigt, dann liefere ich diese gerne nach. Danke!    VG  Max     Sali,    Bitte kurz folgenden Drucker hinzuf gen und testen     print002.mbazh.ch KFR  Canon iR ADV C5550 5560 PCL6.2    Um die Liste f r den Standard Drucker zu pr fen, ben tige ich noch die Namen derjenigen, welche den als Standard hinterlegt haben sollten.  Die Drucker sind normalerweise eingestellt Doppelseitig zu drucken, kann ich aber  ndern.  Auch das Papierfach kann ich anpassen, die Auswahl besteht hier aus Auto, Mehrzweck Fach, Einzug 1, Einzug 2.    Gruss  Martin         Ist der Drucker in der Tabelle eingetragen?
# 253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                KZI Miniinfo Neue Common Name Prozedur f r Kurse  MBA 1128844      Nach R cksprache mit den MV verstehe ich, dass die Anleitung  CommonNames   nicht ohne eine weitere Installation einer Prozedur greift, deshalb gebe ich  das Ticket nun mit dem Auftrag zur untigen Anfrage von Daniel Stucki    Ich bitte um Installation der neuen MiniInfo Prozedur zum Setzen der Common  Names und Kurslabels auf KURSEN   wenn m glich im Ordner  Common Names .  Die neue Prozedur zum Setzen der cn auf Klassen habe ich bereits installiert.     Die Prozeduren f r CN und Labels sind bei allen Schulen vorhanden. An der KZI muss einfach noch spr TAMMI set commonname on course im MiniInfo administriert werden     Roman, Danijel?
# 254   MBA 1128940  Zimbra St rung komplette Schule  E Mails senden und empfangen  kslzh.ch  funktioniert nicht     Guten Morgen allerseits    Schule  KSLZH  Melder  Laszlo Cseri    Problem Zimbra     Wir  kslzh.ch  k nnen keine E Mails senden  auch Mails von GMX und icloud.com versendet  und empfangen. Im Webmail erhalten wir folgende Hinweise beim versenden von E Mails     !clipboard 202403250751 h8l4i.png!    !clipboard 202403250751 h6e8a.png!    Eine  berpr fung mit MXToolbox zeigt bei einem SMTP Check folgendes an      !clipboard 202403250751 2pdnb.png!    D rfen wir euch bitten, das Problem sofort zu beheben?    Nachtrag  Bei meinen Recherchen habe ich festgestellt, dass es auch die stud.kslzh.ch Domain auch betrifft     !clipboard 202403250752 fxdsc.png!         PS  Weiss man was das Problem war? LG Andreas St ssel  Im Detail nicht.  Die Kommunikation zwischen MTA und Edge Server war gest rt, aber man sieht nicht, was das ausgel st hat.   Das System ist schon l nger im EoL Status, wir investieren keine Zeit mehr in Fehlersuche          KRW Andreas Berger  KSL Cseri Laszlo    R ckmeldung Zimbra funktioniert wieder         PS  Weiss man was das Problem war? LG Andreas St ssel     Super danke        Test Servicedesk erfolgreich. Versand von Zimbra und Empfang auf MBA Adresse i.o.    !clipboard 202403250948 gpgxs.png!  !clipboard 202403250948 st3cq.png!    Sieht also soweit wieder gut aus     Ich werde mal die Schulen anschreiben und warte auf R ckmeldung. LG Andreas St ssel     Die Warteschlangen werden nun abgebaut, das System scheint wieder normal unterwegs zu sein.  Kontrolliert doch mit euren Konten auch noch schnell.     Nachtrag von KZU     Melderin  Andrea Emonds    Problem  Absenzen k nnen nicht versendet werden.  Wird Zimbra Problem sein, dies noch zur Kenntnisnahme    !clipboard 202403250922 bernz.png!         Folgende Details   !clipboard 202403250816 hxubf.png!    Ausserdem habe ich den Fehlerbericht im Zimbra gesendet.       Servicedesk  Ich habe eine Test Mail erfolglos gesendet. Von Zimbra an andreas.stoessel mba.zh.ch  !clipboard 202403250810 kmwuh.png!       Die KRW und die KZU haben jetzt ebenfalls dieses Problem gemeldet     Beobachtet ihr mit eurer Domain it.mba.zh.ch den gleichen Effekt  f r uns funktioniert alles, an den edge Servern liegt's kaum ?
# 255                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  MBA 1127156  Layout Anpassung auf Typo 3   Webseite  KWI      Guten Morgen    Ich habe eine eher spezielle Anfrage von der Kantonsschule Wiedikon.    Die Kantonsschule Wiedikon w nscht eine Layout Anpassung f r mobile Ger te zu machen f r das Video welches auf der Webseite der KWI  Baustand der Hohlstrasse  hochgeladen wurde. Die Kontaktperson  bei fr heren Anpassungen  bei euch war Noemi Schmid. Die Schule w nscht nun eine Kontaktaufnahme von euch  mit Herrn Philippe da Silva Wong, Tel. 044 457 71 53 um die Einzelheiten zu besprechen.  W re eine Kontaktaufnahme seitens von euch m glich?    Dieses Ticket eilt ein wenig da es schon l nger auf eine Antwort wartet. Ich habe das Ticket am 27.02.2024 an euch weitergeleitet ohne R ckmeldung bis jetzt.     Freundliche Gr sse  Kushtrim Veliji      Bildungsdirektion Kanton Z rich  Mittelschul  und Berufsbildungsamt  Digital Service Center Sek II  Ausstellungsstrasse 80  8090 Z rich  Telefon 043 259 77 27     Bist du da dran?
#
# [256 rows x 2 columns]

# %%
# !pip install openai==0.28
# Out:
# Collecting openai==0.28
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (4.66.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai==0.28) (3.9.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai==0.28) (2024.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai==0.28) (4.0.3)
# Installing collected packages: openai
# Successfully installed openai-0.28.0

# %%
import openai
import pandas as pd

from google.colab import userdata
os.environ['OPENAI_API_KEY'] = userdata.get('OPENAI_API_KEY')
print("DONE")
# Out:
# DONE

# %%
import os

# Check if the OPENAI_API_KEY environment variable is set
if "OPENAI_API_KEY" in os.environ:
    print("OpenAI API key is set.")
else:
    print("OpenAI API key is not set.")
# Out:
# OpenAI API key is set.

# %% [markdown]
# TEST

# %%
import os
import pandas as pd
import openai


def rework_ticket_description_with_gptturbo(ticket_text):
    """
    Reworks a ticket description into a structured summary using the GPT-3.5 Turbo model through Chat Completion.

    :param ticket_text: The text of the ticket.
    :return: Reworked ticket text.
    """

    # Explicitly set the OpenAI API key
    openai.api_key = os.getenv("OPENAI_API_KEY")


    try:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[
                {"role": "system", "content": "You are a helpful assistant tasked with summarizing technical support tickets."},
                {"role": "user", "content": ticket_text}
            ]

        )

        # Assuming the response structure has a 'choices' list with at least one item,
        # and 'message' contains the 'content' field with our reworked text.
        if response and 'choices' in response and len(response['choices']) > 0:
            reworked_text = response['choices'][0].get('message', {}).get('content', '')
            return reworked_text.strip()
        else:
            return "Failed to generate reworked text. No valid response."
    except Exception as e:
        return f"An error occurred: {str(e)}"

# %%
# Apply the function to your DataFrame
df['reworked_information'] = df['all_information'].apply(rework_ticket_description_with_gptturbo)

# Display the first few rows of the processed DataFrame
print(df.head())
# Out:
#   issue_id  \
# 0   116163
# 1   116164
# 2   116165
# 3   116166
# 4   116167
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   all_information  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   KEN  mobile App aufschalten     Einfach mal alle Module freischalten     Super, der Benutzer wechsel klappt nun auch.  Aber f r das aktuelle Login br uchten die KEN User einen LDAP Account, das Login  ber ihren Azure Tenant geht erst mit v1.8.     LDAP  ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             KEN  Signage einrichten     Bitte einen Beispiel Raspi startklar machen     Raspi aufgesetzt und mit KEN verbunden.
# 2      KEN  Module freischalten  MBA 1127666        Basis  AP 001     Basis   AP 002  MATAR, IU   Micropage    Stundenplan  AP 004     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009     Elektronisches Klassenbuch  AP 010        Basis  AP 001   ok     Basis   AP 002      MATAR  ok  https   intranet.tam.ch ken matar     IU  ok      Micropage  ok   https   intranet.tam.ch ken micropage    Stundenplan  AP 004   ok     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter    Elektronisches Klassenbuch  AP 010   ok     Die Module sind weitgehend bereit, die konkrete Konfiguration w re der n chste Schritt       Basis  AP 001    Basis   AP 002     MATAR  ok  https   intranet.tam.ch ken matar    IU  ok     Micropage  ok   https   intranet.tam.ch ken micropage   Stundenplan  AP 004   ok    Absenzenerfassung  AP 005    Absenzenprozesse  AP 006     Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter   Elektronisches Klassenbuch  AP 010   ok
# 3                                                                                         KST  MBA 1125513    IN2   Bl cke streichen l schen funktioniert nicht     Hallo zusammen    Das streichen von Bl cken funktioniert aktuell bei der KST nicht.  Das Fenster  ffnet sich zwar, man kann auch auf  Block streichen  klicken,  aber das Fenster schliesst sich dann und der Block ist dann nicht  gel scht gestrichen.    Evtl. hat es etwas mit diesem Ticket zu tun Incident  116149     Freundliche Gr sse  Dani              Hoi Dani        Reservationen funktionieren wieder, Ferien Blocks k nnen nach wie vor nicht    ver ndert werden.        LG        Kai Homberg            Auf live korrigiert.     Ist auf live     Auf stage korrigiert     funktioniert     Sollte auf stage gefixed sein. Kannst noch testen?     Habe es in diesem Fall in der DB gel scht.    Bitte anschauen     Jemand scheint  nderungen am Stundenplan unternommen zu haben.   Alle Ferien k nnen nicht mehr gel scht werden.     HolidayID   132, Karfreitag. Wieso l sst sich das nicht l schen?
# 4  KZI  MBA 1125671    IN2   IU Stundenplan   busy Lektion     Hallo zusammen    K nnt Ihr bitte die Lektion im Anhang f r die KZI l schen?     Freundliche Gr sse  Dani           Hallo Support     Das in Ticket MBA 1124354 gemeldete Problem, dass im IU Stundenplantool in  einem IU Lehrstundenplan ein  busy  Eintrag nicht gel scht werden kann, trat  nun wieder auf   Immerhin weiss ich unterdessen, wie das passiert  Wenn man den Stundenplan  eines Sch lers eingblendet hat und dann dort auf eine frei Lektion klickt,  erscheint nachher im Lehrerstundenplan eine  busy  Lektion.  So geschehen bei LP roger.ruetti.kzi   s. Beilage  Bitte diese Lektion l schen oder mir mitteilen, wie ich das erledigen kann.     Lieben Gruss Daniel Stucki     Das ist eine der Grundfunktionen des IU Planners  Will man bei einem Sch ler zus tzlich zum Grundstundenplan eine Lektion sperren, klickt man im Sch lerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.     Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         reworked_information
# 0                                                                                                                                                                                                                                                                                                                                                 Zusammenfassung der Support-Anfrage:\n\n- Benutzer möchten die KEN Mobile App aktivieren und alle Module freischalten.\n- Der Benutzerwechsel funktioniert nun, aber KEN-Benutzer benötigen einen LDAP-Account für das aktuelle Login, da das Login über ihren Azure-Tenant erst mit Version 1.8 möglich ist.\n- LDAP "ou" und "upn" sind jetzt verfügbar.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Zusammenfassung: \nEs wird um Unterstützung bei der Einrichtung von KEN-Signage gebeten, indem ein Raspberry Pi für den Start vorbereitet wird und eine Verbindung zu KEN hergestellt wird.
# 2                                                                                                                                                    The technical support ticket is related to unlocking the KEN module MBA 1127666. The following modules are mentioned: Basis AP 001, Basis AP 002, MATAR, IU, Micropage, Stundenplan AP 004, Absenzenerfassung AP 005, Absenzenprozesse AP 006, Newsletter AP 009, and Elektronisches Klassenbuch AP 010. The ticket indicates that most modules are ready, and the next step would be the specific configuration. Links for MATAR, Micropage, Newsletter, and the Elektronisches Klassenbuch are provided. The status of each module is listed as "ok."
# 3  Summary:\n- The issue is related to the inability to delete or strike off blocks in KST MBA 1125513.\n- When trying to strike off a block, the window opens, the "Block striken" button can be clicked, but the window closes and the block remains unchanged.\n- The problem may be linked to Incident 116149.\n- Reservation functionality is restored, but modifying vacation blocks remains problematic.\n- Corrections were made on the live and staging environments.\n- A specific holiday block with HolidayID 132 (Karfreitag) cannot be deleted, potentially due to someone making changes to the schedule.\n- Further investigation is required to understand why the block cannot be deleted.
# 4                                                                                                                                              Summary of Technical Support Tickets:\n\nTicket MBA 1125671: Dani requests deletion of a busy lesson in the IU schedule.\nTicket MBA 1124354: Daniel Stucki reports an issue where a busy entry in the IU schedule cannot be deleted and outlines the steps to reproduce the problem.\n\nAdditional Information:\n- The issue occurs when clicking on a free lesson in a student's schedule, causing a busy entry to appear in the teacher's schedule.\n- This feature has been part of the IU Planner for about 15 years, dating back to Intranet Version 1.

# %%
# Save the DataFrame to a JSON file
df.to_json('./drive/Othercomputers/X1/code/processed_summarization_per_ticket.json', orient='records', lines=True)

# To ensure it's saved, you can also download it to your local system with the following:
from google.colab import files
files.download('./drive/Othercomputers/X1/code/processed_summarization_per_ticket.json')

# %%
df
# Out:
#     issue_id  \
# 0     116163
# 1     116164
# 2     116165
# 3     116166
# 4     116167
# ..       ...
# 251   116537
# 252   116538
# 253   116539
# 254   116543
# 255   116550
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           all_information  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           KEN  mobile App aufschalten     Einfach mal alle Module freischalten     Super, der Benutzer wechsel klappt nun auch.  Aber f r das aktuelle Login br uchten die KEN User einen LDAP Account, das Login  ber ihren Azure Tenant geht erst mit v1.8.     LDAP  ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     KEN  Signage einrichten     Bitte einen Beispiel Raspi startklar machen     Raspi aufgesetzt und mit KEN verbunden.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              KEN  Module freischalten  MBA 1127666        Basis  AP 001     Basis   AP 002  MATAR, IU   Micropage    Stundenplan  AP 004     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009     Elektronisches Klassenbuch  AP 010        Basis  AP 001   ok     Basis   AP 002      MATAR  ok  https   intranet.tam.ch ken matar     IU  ok      Micropage  ok   https   intranet.tam.ch ken micropage    Stundenplan  AP 004   ok     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter    Elektronisches Klassenbuch  AP 010   ok     Die Module sind weitgehend bereit, die konkrete Konfiguration w re der n chste Schritt       Basis  AP 001    Basis   AP 002     MATAR  ok  https   intranet.tam.ch ken matar    IU  ok     Micropage  ok   https   intranet.tam.ch ken micropage   Stundenplan  AP 004   ok    Absenzenerfassung  AP 005    Absenzenprozesse  AP 006     Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter   Elektronisches Klassenbuch  AP 010   ok
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 KST  MBA 1125513    IN2   Bl cke streichen l schen funktioniert nicht     Hallo zusammen    Das streichen von Bl cken funktioniert aktuell bei der KST nicht.  Das Fenster  ffnet sich zwar, man kann auch auf  Block streichen  klicken,  aber das Fenster schliesst sich dann und der Block ist dann nicht  gel scht gestrichen.    Evtl. hat es etwas mit diesem Ticket zu tun Incident  116149     Freundliche Gr sse  Dani              Hoi Dani        Reservationen funktionieren wieder, Ferien Blocks k nnen nach wie vor nicht    ver ndert werden.        LG        Kai Homberg            Auf live korrigiert.     Ist auf live     Auf stage korrigiert     funktioniert     Sollte auf stage gefixed sein. Kannst noch testen?     Habe es in diesem Fall in der DB gel scht.    Bitte anschauen     Jemand scheint  nderungen am Stundenplan unternommen zu haben.   Alle Ferien k nnen nicht mehr gel scht werden.     HolidayID   132, Karfreitag. Wieso l sst sich das nicht l schen?
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          KZI  MBA 1125671    IN2   IU Stundenplan   busy Lektion     Hallo zusammen    K nnt Ihr bitte die Lektion im Anhang f r die KZI l schen?     Freundliche Gr sse  Dani           Hallo Support     Das in Ticket MBA 1124354 gemeldete Problem, dass im IU Stundenplantool in  einem IU Lehrstundenplan ein  busy  Eintrag nicht gel scht werden kann, trat  nun wieder auf   Immerhin weiss ich unterdessen, wie das passiert  Wenn man den Stundenplan  eines Sch lers eingblendet hat und dann dort auf eine frei Lektion klickt,  erscheint nachher im Lehrerstundenplan eine  busy  Lektion.  So geschehen bei LP roger.ruetti.kzi   s. Beilage  Bitte diese Lektion l schen oder mir mitteilen, wie ich das erledigen kann.     Lieben Gruss Daniel Stucki     Das ist eine der Grundfunktionen des IU Planners  Will man bei einem Sch ler zus tzlich zum Grundstundenplan eine Lektion sperren, klickt man im Sch lerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.     Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            KZN  MBA 1128871  IM  Neues gemischtes Profil N PPP     Hallo zusammen    Bitte das neue Profil erfassen.    Vielen Dank im voraus  Gruess  Roman      Gesch tztes Support Team          Aufgrund der sich abzeichnenden Klasseneinteilung f r das n chste Schuljahr    braucht die KZN neu das gemischte Profil Neusprachlich PPP, das wir hiermit    gerne bestellen w rden.        LG        Giusi            Das Profil N PPP steht jetzt zur Auswahl
# 252                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Fwd   MBA 1128639  AW  Druckereinstellungen Sekretariat KFR     Hallo    Seit der Umstellung auf Leunet hat die KFR Schwierigkeiten beim Drucken mit  dem Drucker Canon ImageRunner Advance  C5560i, IP  10.95.36.110  Die Probleme treten nur in der VDI auf. Jedes Mal, wenn sie drucken wollen,  m ssen sie zuerst den Drucker in der Liste anw hlen, da dieser nicht als  Standard eingestellt ist und es m ssen auch alle weiteren Einstellungen wie   einseitig drucken  neu ausgew hlt werden. Ausserdem druckt es immer nur ein  Exemplar aus, auch wenn man die Anzahl der Exemplare anpasst. Das Papierfach  wird ebenfalls willk rlich ausgew hlt. Habt ihr eine Idee wie man das beheben  k nnte? Ihr k nnt gerne etwas versuchen und wir testen das dann. Falls ihr  noch mehr Infos ben tigt, dann liefere ich diese gerne nach. Danke!    VG  Max     Sali,    Bitte kurz folgenden Drucker hinzuf gen und testen     print002.mbazh.ch KFR  Canon iR ADV C5550 5560 PCL6.2    Um die Liste f r den Standard Drucker zu pr fen, ben tige ich noch die Namen derjenigen, welche den als Standard hinterlegt haben sollten.  Die Drucker sind normalerweise eingestellt Doppelseitig zu drucken, kann ich aber  ndern.  Auch das Papierfach kann ich anpassen, die Auswahl besteht hier aus Auto, Mehrzweck Fach, Einzug 1, Einzug 2.    Gruss  Martin         Ist der Drucker in der Tabelle eingetragen?
# 253                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                KZI Miniinfo Neue Common Name Prozedur f r Kurse  MBA 1128844      Nach R cksprache mit den MV verstehe ich, dass die Anleitung  CommonNames   nicht ohne eine weitere Installation einer Prozedur greift, deshalb gebe ich  das Ticket nun mit dem Auftrag zur untigen Anfrage von Daniel Stucki    Ich bitte um Installation der neuen MiniInfo Prozedur zum Setzen der Common  Names und Kurslabels auf KURSEN   wenn m glich im Ordner  Common Names .  Die neue Prozedur zum Setzen der cn auf Klassen habe ich bereits installiert.     Die Prozeduren f r CN und Labels sind bei allen Schulen vorhanden. An der KZI muss einfach noch spr TAMMI set commonname on course im MiniInfo administriert werden     Roman, Danijel?
# 254   MBA 1128940  Zimbra St rung komplette Schule  E Mails senden und empfangen  kslzh.ch  funktioniert nicht     Guten Morgen allerseits    Schule  KSLZH  Melder  Laszlo Cseri    Problem Zimbra     Wir  kslzh.ch  k nnen keine E Mails senden  auch Mails von GMX und icloud.com versendet  und empfangen. Im Webmail erhalten wir folgende Hinweise beim versenden von E Mails     !clipboard 202403250751 h8l4i.png!    !clipboard 202403250751 h6e8a.png!    Eine  berpr fung mit MXToolbox zeigt bei einem SMTP Check folgendes an      !clipboard 202403250751 2pdnb.png!    D rfen wir euch bitten, das Problem sofort zu beheben?    Nachtrag  Bei meinen Recherchen habe ich festgestellt, dass es auch die stud.kslzh.ch Domain auch betrifft     !clipboard 202403250752 fxdsc.png!         PS  Weiss man was das Problem war? LG Andreas St ssel  Im Detail nicht.  Die Kommunikation zwischen MTA und Edge Server war gest rt, aber man sieht nicht, was das ausgel st hat.   Das System ist schon l nger im EoL Status, wir investieren keine Zeit mehr in Fehlersuche          KRW Andreas Berger  KSL Cseri Laszlo    R ckmeldung Zimbra funktioniert wieder         PS  Weiss man was das Problem war? LG Andreas St ssel     Super danke        Test Servicedesk erfolgreich. Versand von Zimbra und Empfang auf MBA Adresse i.o.    !clipboard 202403250948 gpgxs.png!  !clipboard 202403250948 st3cq.png!    Sieht also soweit wieder gut aus     Ich werde mal die Schulen anschreiben und warte auf R ckmeldung. LG Andreas St ssel     Die Warteschlangen werden nun abgebaut, das System scheint wieder normal unterwegs zu sein.  Kontrolliert doch mit euren Konten auch noch schnell.     Nachtrag von KZU     Melderin  Andrea Emonds    Problem  Absenzen k nnen nicht versendet werden.  Wird Zimbra Problem sein, dies noch zur Kenntnisnahme    !clipboard 202403250922 bernz.png!         Folgende Details   !clipboard 202403250816 hxubf.png!    Ausserdem habe ich den Fehlerbericht im Zimbra gesendet.       Servicedesk  Ich habe eine Test Mail erfolglos gesendet. Von Zimbra an andreas.stoessel mba.zh.ch  !clipboard 202403250810 kmwuh.png!       Die KRW und die KZU haben jetzt ebenfalls dieses Problem gemeldet     Beobachtet ihr mit eurer Domain it.mba.zh.ch den gleichen Effekt  f r uns funktioniert alles, an den edge Servern liegt's kaum ?
# 255                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  MBA 1127156  Layout Anpassung auf Typo 3   Webseite  KWI      Guten Morgen    Ich habe eine eher spezielle Anfrage von der Kantonsschule Wiedikon.    Die Kantonsschule Wiedikon w nscht eine Layout Anpassung f r mobile Ger te zu machen f r das Video welches auf der Webseite der KWI  Baustand der Hohlstrasse  hochgeladen wurde. Die Kontaktperson  bei fr heren Anpassungen  bei euch war Noemi Schmid. Die Schule w nscht nun eine Kontaktaufnahme von euch  mit Herrn Philippe da Silva Wong, Tel. 044 457 71 53 um die Einzelheiten zu besprechen.  W re eine Kontaktaufnahme seitens von euch m glich?    Dieses Ticket eilt ein wenig da es schon l nger auf eine Antwort wartet. Ich habe das Ticket am 27.02.2024 an euch weitergeleitet ohne R ckmeldung bis jetzt.     Freundliche Gr sse  Kushtrim Veliji      Bildungsdirektion Kanton Z rich  Mittelschul  und Berufsbildungsamt  Digital Service Center Sek II  Ausstellungsstrasse 80  8090 Z rich  Telefon 043 259 77 27     Bist du da dran?
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        reworked_information
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Zusammenfassung der Support-Anfrage:\n\n- Benutzer möchten die KEN Mobile App aktivieren und alle Module freischalten.\n- Der Benutzerwechsel funktioniert nun, aber KEN-Benutzer benötigen einen LDAP-Account für das aktuelle Login, da das Login über ihren Azure-Tenant erst mit Version 1.8 möglich ist.\n- LDAP "ou" und "upn" sind jetzt verfügbar.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Zusammenfassung: \nEs wird um Unterstützung bei der Einrichtung von KEN-Signage gebeten, indem ein Raspberry Pi für den Start vorbereitet wird und eine Verbindung zu KEN hergestellt wird.
# 2                                                                                                                                                                                                                                                                                                                                                                   The technical support ticket is related to unlocking the KEN module MBA 1127666. The following modules are mentioned: Basis AP 001, Basis AP 002, MATAR, IU, Micropage, Stundenplan AP 004, Absenzenerfassung AP 005, Absenzenprozesse AP 006, Newsletter AP 009, and Elektronisches Klassenbuch AP 010. The ticket indicates that most modules are ready, and the next step would be the specific configuration. Links for MATAR, Micropage, Newsletter, and the Elektronisches Klassenbuch are provided. The status of each module is listed as "ok."
# 3                                                                                                                                                                                                                 Summary:\n- The issue is related to the inability to delete or strike off blocks in KST MBA 1125513.\n- When trying to strike off a block, the window opens, the "Block striken" button can be clicked, but the window closes and the block remains unchanged.\n- The problem may be linked to Incident 116149.\n- Reservation functionality is restored, but modifying vacation blocks remains problematic.\n- Corrections were made on the live and staging environments.\n- A specific holiday block with HolidayID 132 (Karfreitag) cannot be deleted, potentially due to someone making changes to the schedule.\n- Further investigation is required to understand why the block cannot be deleted.
# 4                                                                                                                                                                                                                                                                                                                                                             Summary of Technical Support Tickets:\n\nTicket MBA 1125671: Dani requests deletion of a busy lesson in the IU schedule.\nTicket MBA 1124354: Daniel Stucki reports an issue where a busy entry in the IU schedule cannot be deleted and outlines the steps to reproduce the problem.\n\nAdditional Information:\n- The issue occurs when clicking on a free lesson in a student's schedule, causing a busy entry to appear in the teacher's schedule.\n- This feature has been part of the IU Planner for about 15 years, dating back to Intranet Version 1.
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# 251                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Summary: The user is requesting to create a new mixed profile called Neusprachlich PPP due to the upcoming class assignments for the next school year. They would like to order this new profile. The profile N PPP is now available for selection.
# 252  Summary:\n- The KFR team is experiencing difficulties with printing on the Canon ImageRunner Advance C5560i printer after switching to Leunet.\n- The issues occur only in the VDI environment, where the printer needs to be selected from the list every time, as it is not set as the default printer. Additionally, all printing settings such as one-sided printing need to be reselected.\n- The printer only prints one copy regardless of the specified quantity, and the paper tray selection is random.\n- The requester suggests adding and testing the print002.mbazh.ch KFR Canon iR ADV C5550 5560 PCL6.2 printer.\n- They also need to check the list for the default printer and provide names of those who should have it set as default.\n- The standard settings for double-sided printing and paper tray selection can be adjusted by the requester.\n\nFurther details may be provided if needed.
# 253                                                                                                                                                                                                                                                                                                                                                                                                                                                                             The user is requesting installation of a new MiniInfo procedure to set Common Names and course labels on courses in the "Common Names" folder. They have already installed the procedure to set common names on classes. Additionally, the user mentions that procedures for Common Names and Labels are available at all schools but need to be administered at KZI. The user is requesting Roman or Danijel to follow up on this request.
# 254                                Summary:\n- The technical support ticket is related to an issue with sending and receiving emails through the Zimbra system for the school domain kslzh.ch.\n- Users reported errors and were unable to send emails, including to domains such as GMX and icloud.com.\n- An investigation revealed communication issues between the MTA and Edge Server, leading to email disruptions. The system is in End-of-Life status, so no further troubleshooting efforts will be made.\n- Subsequent updates confirmed that Zimbra is functioning properly again, allowing successful testing of email services.\n- A new issue was reported regarding the inability to send absences notifications through Zimbra, which is under investigation.\n- Other departments also reported similar email sending issues. Further inquiries were made regarding the impact on the domain it.mba.zh.ch.
# 255                                                                                                                                                                                                                                                                                                                                                                   Summary:\n- The Kantonsschule Wiedikon has a request for a layout adjustment on their Typo 3 website for mobile devices for a video uploaded on the website.\n- The contact person for previous adjustments was Noemi Schmid.\n- The school now requests contact with Mr. Philippe da Silva Wong at 044 457 71 53 to discuss the details.\n- Urgent response is needed as the ticket has been waiting for a reply since 27.02.2024.\n- Contact details provided for follow-up: Kushtrim Veliji, Bildungsdirektion Kanton Zürich, Phone 043 259 77 27.
#
# [256 rows x 3 columns]

# %% [markdown]
# END TEST

# %%
# TEST VERSIONfrom transformers import AutoTokenizer, AutoModel
import torch
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt
import pandas as pd
from transformers import AutoTokenizer, AutoModel, AutoModelForSeq2SeqLM


# Assuming df is your DataFrame
# Load pre-trained model tokenizer and model
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')
model = AutoModel.from_pretrained('bert-base-uncased')

# Function to get embeddings
def get_bert_embeddings(texts):
    model.eval()  # Ensure the model is in evaluation mode
    with torch.no_grad():
        embeddings = []
        for text in texts:
            inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=512)
            outputs = model(**inputs)
            # Use mean pooling for sentence-level embeddings
            embeddings.append(outputs.last_hidden_state.mean(dim=1).squeeze().cpu().numpy())
    return embeddings

# Generate embeddings from your DataFrame's 'reworked_information' column
embeddings = get_bert_embeddings(df['reworked_information'].tolist())

# Perform hierarchical clustering
Z = linkage(embeddings, 'ward')

# Plot the dendrogram to visualize clusters
plt.figure(figsize=(10, 7))
# Use DataFrame index or a specific identifier column if you prefer
ticket_labels = [f'Ticket {i+1}' for i in range(len(df))]
dendrogram(Z, labels=ticket_labels)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]

# %%
df.head()
# Out:
#   issue_id  \
# 0   116163
# 1   116164
# 2   116165
# 3   116166
# 4   116167
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   all_information  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   KEN  mobile App aufschalten     Einfach mal alle Module freischalten     Super, der Benutzer wechsel klappt nun auch.  Aber f r das aktuelle Login br uchten die KEN User einen LDAP Account, das Login  ber ihren Azure Tenant geht erst mit v1.8.     LDAP  ou und upn sind jetzt vorhanden
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             KEN  Signage einrichten     Bitte einen Beispiel Raspi startklar machen     Raspi aufgesetzt und mit KEN verbunden.
# 2      KEN  Module freischalten  MBA 1127666        Basis  AP 001     Basis   AP 002  MATAR, IU   Micropage    Stundenplan  AP 004     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009     Elektronisches Klassenbuch  AP 010        Basis  AP 001   ok     Basis   AP 002      MATAR  ok  https   intranet.tam.ch ken matar     IU  ok      Micropage  ok   https   intranet.tam.ch ken micropage    Stundenplan  AP 004   ok     Absenzenerfassung  AP 005     Absenzenprozesse  AP 006      Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter    Elektronisches Klassenbuch  AP 010   ok     Die Module sind weitgehend bereit, die konkrete Konfiguration w re der n chste Schritt       Basis  AP 001    Basis   AP 002     MATAR  ok  https   intranet.tam.ch ken matar    IU  ok     Micropage  ok   https   intranet.tam.ch ken micropage   Stundenplan  AP 004   ok    Absenzenerfassung  AP 005    Absenzenprozesse  AP 006     Newsletter  AP 009   ok  https   intranet.tam.ch ken newsletter   Elektronisches Klassenbuch  AP 010   ok
# 3                                                                                         KST  MBA 1125513    IN2   Bl cke streichen l schen funktioniert nicht     Hallo zusammen    Das streichen von Bl cken funktioniert aktuell bei der KST nicht.  Das Fenster  ffnet sich zwar, man kann auch auf  Block streichen  klicken,  aber das Fenster schliesst sich dann und der Block ist dann nicht  gel scht gestrichen.    Evtl. hat es etwas mit diesem Ticket zu tun Incident  116149     Freundliche Gr sse  Dani              Hoi Dani        Reservationen funktionieren wieder, Ferien Blocks k nnen nach wie vor nicht    ver ndert werden.        LG        Kai Homberg            Auf live korrigiert.     Ist auf live     Auf stage korrigiert     funktioniert     Sollte auf stage gefixed sein. Kannst noch testen?     Habe es in diesem Fall in der DB gel scht.    Bitte anschauen     Jemand scheint  nderungen am Stundenplan unternommen zu haben.   Alle Ferien k nnen nicht mehr gel scht werden.     HolidayID   132, Karfreitag. Wieso l sst sich das nicht l schen?
# 4  KZI  MBA 1125671    IN2   IU Stundenplan   busy Lektion     Hallo zusammen    K nnt Ihr bitte die Lektion im Anhang f r die KZI l schen?     Freundliche Gr sse  Dani           Hallo Support     Das in Ticket MBA 1124354 gemeldete Problem, dass im IU Stundenplantool in  einem IU Lehrstundenplan ein  busy  Eintrag nicht gel scht werden kann, trat  nun wieder auf   Immerhin weiss ich unterdessen, wie das passiert  Wenn man den Stundenplan  eines Sch lers eingblendet hat und dann dort auf eine frei Lektion klickt,  erscheint nachher im Lehrerstundenplan eine  busy  Lektion.  So geschehen bei LP roger.ruetti.kzi   s. Beilage  Bitte diese Lektion l schen oder mir mitteilen, wie ich das erledigen kann.     Lieben Gruss Daniel Stucki     Das ist eine der Grundfunktionen des IU Planners  Will man bei einem Sch ler zus tzlich zum Grundstundenplan eine Lektion sperren, klickt man im Sch lerplan auf die Lektion. Und mit einem nochmaligen Klick ist sie wieder freigegeben.     Das stammt noch aus der Intranet Version 1, ist also etwa 15 Jahre alt
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         reworked_information
# 0                                                                                                                                                                                                                                                                                                                                                 Zusammenfassung der Support-Anfrage:\n\n- Benutzer möchten die KEN Mobile App aktivieren und alle Module freischalten.\n- Der Benutzerwechsel funktioniert nun, aber KEN-Benutzer benötigen einen LDAP-Account für das aktuelle Login, da das Login über ihren Azure-Tenant erst mit Version 1.8 möglich ist.\n- LDAP "ou" und "upn" sind jetzt verfügbar.
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Zusammenfassung: \nEs wird um Unterstützung bei der Einrichtung von KEN-Signage gebeten, indem ein Raspberry Pi für den Start vorbereitet wird und eine Verbindung zu KEN hergestellt wird.
# 2                                                                                                                                                    The technical support ticket is related to unlocking the KEN module MBA 1127666. The following modules are mentioned: Basis AP 001, Basis AP 002, MATAR, IU, Micropage, Stundenplan AP 004, Absenzenerfassung AP 005, Absenzenprozesse AP 006, Newsletter AP 009, and Elektronisches Klassenbuch AP 010. The ticket indicates that most modules are ready, and the next step would be the specific configuration. Links for MATAR, Micropage, Newsletter, and the Elektronisches Klassenbuch are provided. The status of each module is listed as "ok."
# 3  Summary:\n- The issue is related to the inability to delete or strike off blocks in KST MBA 1125513.\n- When trying to strike off a block, the window opens, the "Block striken" button can be clicked, but the window closes and the block remains unchanged.\n- The problem may be linked to Incident 116149.\n- Reservation functionality is restored, but modifying vacation blocks remains problematic.\n- Corrections were made on the live and staging environments.\n- A specific holiday block with HolidayID 132 (Karfreitag) cannot be deleted, potentially due to someone making changes to the schedule.\n- Further investigation is required to understand why the block cannot be deleted.
# 4                                                                                                                                              Summary of Technical Support Tickets:\n\nTicket MBA 1125671: Dani requests deletion of a busy lesson in the IU schedule.\nTicket MBA 1124354: Daniel Stucki reports an issue where a busy entry in the IU schedule cannot be deleted and outlines the steps to reproduce the problem.\n\nAdditional Information:\n- The issue occurs when clicking on a free lesson in a student's schedule, causing a busy entry to appear in the teacher's schedule.\n- This feature has been part of the IU Planner for about 15 years, dating back to Intranet Version 1.

# %%
### how many clusters do we have after the hierarchical clusteirng?
from scipy.cluster.hierarchy import fcluster
import numpy as np

# Assuming 'Z' is your linkage matrix from hierarchical clustering
# Specify the maximum cophenetic distance (this is an example value; adjust based on your dendrogram)
max_distance = 10

# Obtain the cluster labels
cluster_labels = fcluster(Z, max_distance, criterion='distance')

# Add the cluster labels to your DataFrame
df['cluster_label'] = cluster_labels

# Count the unique cluster labels
num_clusters = np.unique(cluster_labels).size

print(f"Number of clusters formed: {num_clusters}")
# Out:
# Number of clusters formed: 5

# %%
from transformers import AutoTokenizer, pipeline

# Load tokenizer and summarization model
tokenizer = AutoTokenizer.from_pretrained('facebook/bart-large-cnn')
summarizer = pipeline("summarization", model="facebook/bart-large-cnn", tokenizer=tokenizer)

def windowed_summarization(text, chunk_max_length=1020, stride=200, final_max_length=50):
    """
    Summarize text by dividing it into manageable chunks based on tokens,
    then summarizing each chunk and combining the summaries. Finally, summarize the combined
    summary to ensure it is concise.

    :param text: The input text to summarize.
    :param chunk_max_length: The maximum token length for each text chunk.
    :param stride: The overlap between chunks.
    :param final_max_length: The maximum token length for the final summary.
    :return: The final summarized text.
    """
    # Tokenize the entire text and split into chunks with overlap
    input_ids = tokenizer.encode(text, return_tensors="pt", truncation=True, max_length=None).squeeze()
    total_length = input_ids.size(0)
    chunk_summaries = []

    # Iterate over the tokenized input in chunks
    for i in range(0, total_length, chunk_max_length - stride):
        chunk_input_ids = input_ids[i:i+chunk_max_length]
        chunk_text = tokenizer.decode(chunk_input_ids, skip_special_tokens=True)

        # Summarize the chunk
        try:
            summary = summarizer(chunk_text, max_length=50, min_length=25, do_sample=False)[0]['summary_text']
            chunk_summaries.append(summary)
        except Exception as e:
            print(f"Error summarizing chunk starting at token {i}: {e}")

    # Combine the summaries of all chunks into a final summary
    combined_summary = " ".join(chunk_summaries)

    # Further summarize the combined summary to ensure it's not too long
    try:
        final_summary = summarizer(combined_summary, max_length=final_max_length, min_length=30, do_sample=False)[0]['summary_text']
    except Exception as e:
        print(f"Error in final summarization: {e}")
        final_summary = combined_summary  # Fallback to combined summary if error occurs

    return final_summary
# Out:
# config.json:   0%|          | 0.00/1.58k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]

# %%
def gpt_3_5_turbo_windowed_summarization(text, chunk_max_length=800, stride=200, final_max_length=150):
    """
    Summarize text using the GPT-3.5-turbo model's chat completion endpoint.
    """
    # Break the text into chunks
    chunks = [text[i:i+chunk_max_length] for i in range(0, len(text), chunk_max_length - stride)]
    chunk_summaries = []

    # Summarize each chunk
    for chunk in chunks:
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=[{"role": "system", "content": "You are a helpful assistant. Summarize the following text."},
                      {"role": "user", "content": chunk}]
        )
        summary = response['choices'][0]['message']['content']
        chunk_summaries.append(summary)

    # Combine the summaries of all chunks
    combined_summary = " ".join(chunk_summaries)

    # Summarize the combined summaries to ensure conciseness
    final_response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "system", "content": "You are a helpful assistant. Provide a concise summary of the following combined summaries."},
                  {"role": "user", "content": combined_summary}]
    )
    final_summary = final_response['choices'][0]['message']['content']

    return final_summary

# %%
import pandas as pd

# Assuming 'df' is your original DataFrame with 'reworked_information' and 'cluster_label' columns

# Initialize your summarization function and models here
# from transformers import AutoTokenizer, pipeline
# tokenizer = AutoTokenizer.from_pretrained('facebook/bart-large-cnn')
# summarizer = pipeline("summarization", model="facebook/bart-large-cnn", tokenizer=tokenizer)
# def windowed_summarization(text, chunk_max_length=1020, stride=200, final_max_length=50):
    # Your function definition

# Create a new DataFrame for summaries with unique cluster labels
unique_clusters = df['cluster_label'].unique()
df_summaries = pd.DataFrame(unique_clusters, columns=['cluster_label'])
df_summaries['summary'] = "NIX"  # Initialize the 'summary' column with a placeholder

for cluster_num in df['cluster_label'].unique():
    # Extract texts for the current cluster and combine them
    cluster_texts = df[df['cluster_label'] == cluster_num]['reworked_information'].tolist()
    combined_text = " ".join(cluster_texts)
    print("******** ", cluster_num, " ******* TOTAL TEXT")
    print(combined_text)

    # Summarize the combined text
    # summary = windowed_summarization(combined_text)
    summary = gpt_3_5_turbo_windowed_summarization(combined_text)

    # Correctly update the 'summary' in df_summaries for the current cluster_label
    # We find the row where 'cluster_label' matches cluster_num and update the 'summary' for that row
    df_summaries.loc[df_summaries['cluster_label'] == cluster_num, 'summary'] = summary

    print("*************** CLUSTER NUM ************: ", cluster_num)
    print(summary)  # Optionally print the summary for verification
    print("\n")
# Out:
# ********  1  ******* TOTAL TEXT
# Zusammenfassung der Support-Anfrage:
#
# - Benutzer möchten die KEN Mobile App aktivieren und alle Module freischalten.
# - Der Benutzerwechsel funktioniert nun, aber KEN-Benutzer benötigen einen LDAP-Account für das aktuelle Login, da das Login über ihren Azure-Tenant erst mit Version 1.8 möglich ist.
# - LDAP "ou" und "upn" sind jetzt verfügbar. Zusammenfassung:
# Es wird um Unterstützung bei der Einrichtung von KEN-Signage gebeten, indem ein Raspberry Pi für den Start vorbereitet wird und eine Verbindung zu KEN hergestellt wird. Zusammenfassung des Support-Tickets:
#
# - Benutzer möchte, dass die Notenbuchliste "Notenexport verwalten" auch das Semester berücksichtigt, nicht nur die Standardperiode.
# - Es wird eine Aufwandschätzung für diese Anpassung angefordert.
# - Der ICT-Applikationsmanager schätzt den Aufwand als relativ hoch ein, da es sich um ein Modul handelt, das von allen Schulen verwendet wird.
# - Die erforderlichen Schritte umfassen den Einbau eines Periodenschalters im Frontend, die Konfigurierbarkeit der Periodendaten und die Anpassung des Queries im Backend.
# - Aufwandschätzung: Frontend (5 Stunden), Backend (6 Stunden).
# - Es muss geklärt werden, ob Probleme beim Export entstehen könnten, wenn Noten aus alten Semestern erneut freigegeben werden. Es wird um Einschätzung dieses Problems gebeten. Zusammenfassung des technischen Supports:
#
# - Der Benutzer hat Schwierigkeiten mit dem Importieren eines Enrollment (ID 30) in die Tabelle VDI.dbo.enrollment.
# - Beim Testlauf der MiniInfo Prozedur für den Import treten keine Fehlermeldungen oder Ergebnisse auf.
# - Das Enrollment ist online in der Sammelansicht verfügbar.
# - Es wird davon ausgegangen, dass das Enrollment bald synchronisiert wird.
# - Der Benutzer hat bewusst die Priorität nicht auf "High" gesetzt, um die SLA nicht zu beeinflussen, aber dennoch den Dringlichkeitsstatus verwendet, da es für ihn sehr wichtig ist, dass das Problem schnell behoben wird.
# - Es wird vorgeschlagen, den nächsten Abgleich um 15:30 Uhr abzuwarten, um weitere Tests durchzuführen. - Roman bittet darum zu prüfen, warum an der KZO irrtümlicherweise eine zusätzliche Seite im Semesterzeugnis erstellt wird.
# - Stephan beschreibt, dass es seit dem aktuellen Semester im Semesterzeugnis NMRZeugnis2022.dot gelegentlich eine zusätzliche leere Seite gibt.
# - Stephan hat versucht, den letzten Zeilenumbruch zu entfernen, aber ohne Erfolg und bittet um Hilfe bei diesem Problem. Zusammenfassung des Support-Tickets:
#
# Ein Benutzer namens Yvonne meldet ein Problem mit der mobilen Version, die sich nicht an die im Desktop-Konfigurationseditor festgelegten Einstellungen für das Notenbuch hält. Die Mobile-Version zeigt nur das Herbstsemester 2023/24 an, während der Desktop korrekt das Frühjahrssemester anzeigt. Es wird darum gebeten, dieses Problem dringend zu beheben, damit die Einstellungen aus dem Desktop in der mobilen Version übernommen werden.
#
# Es wird diskutiert, dass die App nur die Semester anzeigt, in denen der Schüler Noten hat. Es gibt Überlegungen, wie die beiden Versionen (Desktop und Mobile) besser aneinander angeglichen werden können, da Unterschiede zu ständigen Diskussionen mit dem Management führen. Es wird vorgeschlagen, im Konfigurationseditor zu kennzeichnen, welche Einstellungen die App beeinflussen. Es wird erwähnt, dass die API nur Semester mit Noten liefert, was zu dem unterschiedlichen Verhalten zwischen Desktop und Mobile führen kann.
#
# Es wird nachgefragt, ob die API die korrekten Werte liefert. Der Benutzer KEN bittet darum, die Loginseite etwas zu optimieren, indem die beiden Eingabefelder ihre übliche Breite haben sollen. Dies wurde bereits auf der Testumgebung behoben und KEN möchte wissen, ob diese Änderungen auch auf der Live-Website übernommen werden sollen. Ticket Summary:
#
# - Semesterwechsel für das FS 2024 wurde im Intranet angepasst.
# - Es fehlen Daten des Semesters pr id 80 im View person course aufgrund unvollständiger Umstellung.
# - Bitte Filter im View auf Semester 80 setzen.
# - Kursbuchungs-View zeigt nun auch Daten vom FS24. Es wird darum gebeten, einen aktuellen Auszug aller VDI-Nutzer zu erstellen. Die Anfrage bezieht sich auf die Nutzer mit der Bezeichnung "MBA 1126654". Ein Anhang mit weiteren Informationen ist vorhanden. Ticket-Zusammenfassung:
# - Die Benutzer können keine Abstracts erfassen, ohne Fehlermeldung.
# - Das Erfassen von Abstracts funktioniert für Administratoren, aber nicht für Studenten.
# - Es wird vermutet, dass Einstellungen oder Berechtigungen fehlen.
# - Die Konfiguration und Bearbeitung der Schularbeiten ist dringend erforderlich.
# - Es gibt Probleme mit dem Hinzufügen von Arbeiten, nur Titel können gespeichert werden.
# - Es gibt Schwierigkeiten mit Berechtigungen und Rollenzuweisungen.
# - Es wird um schnelle Hilfe bei der Lösung des Problems gebeten. - Update der ESXi Server wurde durchgeführt, nicht die HP Server selbst.
# - Update des VDI Images wurde durchgeführt.
# - Überprüfung von Firefox, Zimbra Connector und Adobe wurde abgeschlossen.
# - Windows Update wurde teilweise durchgeführt, ein Update hat jedoch einen Fehler verursacht. Die Lösung ist bekannt und kann unter folgendem Link gefunden werden: https://www.windowslatest.com/2024/01/15/windows-10-kb5034441-fails-with-a-0x80070643-error-but-theres-a-fix
# - Es wurde ein Update durchgeführt, das ein Problem verursacht hat und daher gelöscht wurde. Es handelte sich um ein Bitlocker Security Update, jedoch wird Bitlocker nicht verwendet. Es wird auf einen Fix von Microsoft gewartet.
# - Eine Checkliste für die Umbenennung von Benutzern wurde erstellt und ist fertig.
# - Firefox, Zimbra Connector und Adobe wurden erfolgreich aktualisiert. Zusammenfassung des Support-Tickets:
#
# Der Nutzer Roman bittet darum, Martin Lehmann Zugriff auf die Stage-Umgebung zu gewähren, damit er Tests durchführen kann. Es wird darum gebeten, einen aktuellen Datenbank-Dump auf die Stage zu spielen. Es wird bestätigt, dass der Zugriff für den Benutzer eingerichtet ist und die Datenbank aktuell ist.
#
# Ein Slack-Befehl wurde verwendet, um Daten von der Live-Umgebung auf die Stage zu kopieren. Der Benutzer sollte im LDAP vorhanden sein, da alle 4 Stunden ein Update durchgeführt wird. Es wird jedoch festgestellt, dass der Benutzer noch nicht auf der Stage-Umgebung vorhanden ist. Roman weist darauf hin, dass der Benutzer der Gruppe in2 testing im dev LDAP zugewiesen wurde und bittet darum, die Datenbank zu aktualisieren. Zusammenfassung des Technical Support Tickets:
#
# Es gibt Diskussionen über das Anpassen der Einstellungen für Kurse, die im Information Management (IM) als "Kein Zeugnis" markiert sind, damit Notenbücher im IN2 nicht erstellt werden. Einige Schulen möchten jedoch trotzdem Noten für diese Kurse erfassen, z.B. für Teilfächer. Es wird vorgeschlagen, diese Funktion so anzupassen, dass die Schulen die Sichtbarkeit über eine Liste (Liste 601) steuern können. Es wird um die Anpassung dieser Funktion bis Ende Juni gebeten, damit es für das neue Schuljahr wieder funktioniert. Des Weiteren wird vorgeschlagen, dass Kurse mit den Profilen "SV" und "Maturit tsarbeiten" standardmäßig ausgeblendet werden. Es ist lediglich eine Anpassung am Export notwendig; die Funktionalitäten im IN2 bleiben unverändert. Zusammenfassung der technischen Support-Tickets:
#
# - Im Schüleransicht Liste 46 werden nicht beide Lehrpersonen (LP) angezeigt, obwohl sie in Liste 3 sichtbar sind.
# - In der IN2 Schüleransicht des BG Kurses wird nur die Stellvertreterin ab Mai, aber nicht die Stamm-Lehrperson (LP) angezeigt.
# - Im Listeneditor wurde eine Spalte von "Name Vorname" zu "Lehrperson" geändert.
#
# Es scheint ein Anzeigeproblem mit den Lehrpersonen in den verschiedenen Ansichten zu geben, das möglicherweise durch Anpassungen im Listeneditor beeinflusst wurde. Es wird nach der Ursache für diese Darstellungsdifferenzen gefragt. - Der Nutzer hat festgestellt, dass die Ferien für die Stundenpläne im Mandanten 11 nicht mehr korrekt berücksichtigt werden.
# - Die Ferien werden im Mandanten 59 erfasst und an IN2 exportiert. Die Stundenpläne kommen aus den Mandanten 11, 39, 40 und 59.
# - Es scheint, dass seit den Sportferien die Ferien für die Stundenpläne im Mandanten 11 nicht mehr oder nur halb berücksichtigt werden.
# - Trotz des Eintrags "Ferien" in den Stundenplänen sind auch Lektionen während der Ferien sichtbar.
# - Es wird nachgefragt, ob die Ferien wieder korrekt berücksichtigt werden können.
# - Es wird diskutiert, dass möglicherweise die fehlende HolidayID auf den Lektionen das Problem verursacht hat, und es gab eine Unklarheit bezüglich der Auswirkungen auf Absenzenprozesse.
# - Nach einer Intervention werden die Lektionen in den Ferien nicht mehr angezeigt.
# - Es wird sich gewundert, ob der Importer Unterschiede zwischen den Mandanten macht und warum die HolidayID nicht auf alle Lektionen geschrieben wird. Zusammenfassung des technischen Support-Tickets:
#
# Ein Benutzer mit dem Namen robert.hofmann.kbw konnte keine neuen Einträge in Playlisten erstellen, da eine Meldung angezeigt wurde, dass der Server nicht erreichbar sei. Der Benutzer selbst hatte das gleiche Problem. Nach einer Überprüfung durch den Support konnte das Problem behoben werden. Es stellte sich heraus, dass es eine Unverträglichkeit zwischen der neuen PHP-Version und einem Request-Parameter gab, bei dem eine mathematische Berechnung ohne Typumwandlung durchgeführt wurde. Ticket Zusammenfassung:
# - Seit gestern ist das Intranet nicht erreichbar.
# - Es gibt die Vermutung, dass dies mit Login-Versuchen im Rahmen eines Informatikunterrichtsprojekts zusammenhängt.
# - Möglicherweise wurde versucht, Schullogin-Passwörter zu knacken.
# - Es wird davon ausgegangen, dass die Schutzmechanismen den Angriff abgewehrt haben.
# - Die Situation hat sich beruhigt.
# - Es wird auf einen Artikel über die Strafbarkeit von Hacking hingewiesen.
#
# Aktionen:
# - Überprüfen Sie die Ursache des Intranet-Ausfalls.
# - Stellen Sie sicher, dass die Sicherheitsmechanismen des Intranets intakt sind.
# - Prüfen Sie, ob es Anzeichen für erfolgreiche Angriffe gibt.
# - Kontaktieren Sie bei Bedarf die Person, die den Artikel über die Strafbarkeit des Hackings erwähnt hat. Zusammenfassung des Support-Tickets:
#
# Der Benutzer hat festgestellt, dass im Stundenplaneditor des IN2-Systems früher nur eine Lehrperson für eine neue Lektion auswählbar war, auch wenn zwei Lehrpersonen für den Kurs im IM-System gebucht waren. Aufgrund der Einführung der von-bis-Funktion für Stellvertretungen wurden jedoch beide Lehrpersonen automatisch auf die neue Lektion gebucht. Nun scheint es, als ob es wieder möglich ist, nur eine Lehrperson auszuwählen. Der Benutzer möchte sicherstellen, dass dies weiterhin möglich ist, da er bald mit der Tagesstundenplanung beginnen wird. Es wird geklärt, dass bei temporären Änderungen, wie im Beispielbild zu sehen, eine der vorgeschlagenen Lehrpersonen weggeklickt werden kann. Zusammenfassung des technischen Supports: Einige Entwickler können nicht auf die Verwaltungsdokumente zugreifen, da beim Aufrufen der Funktion "Application Manager Balloon" eine Exception auftritt. Die Ursache dafür ist, dass im Access Token "aaistage.tam.ch" und "aai.tam.ch" von Benutzer Carlo der Anspruch "tam primary role" fehlt. Zusammenfassung des technischen Support-Tickets:
# - Der Benutzer hat Schwierigkeiten, bestimmte Attribute einer Gruppe in MBAZH Azure Sync zu synchronisieren.
# - Die spezifischen Attribute, die nicht synchronisiert werden können, sind die deaktivierten, aber nicht gelöschten Benutzer in eol, die noch in den Gruppen enthalten sind.
# - Die Empfehlung lautet, die betroffenen Benutzer endgültig zu löschen und dann die Synchronisierung erneut zu starten. Zusammenfassung der Support-Tickets:
#
# 1. Der Benutzer hat festgestellt, dass es ein Problem mit einem Nameserver (ns002.gyselroth.net) für design.kzn.ch gibt, da dieser keine Datensätze zurückgibt. Die anderen beiden Nameserver funktionieren jedoch einwandfrei. Es wird vermutet, dass dies kein großes Problem darstellt, aber der Benutzer wollte darauf aufmerksam machen.
#
# 2. Es gab Schwierigkeiten mit dem DNS-Slave, der nach einem IP-Adresswechsel nicht aktualisiert wurde, da der Master die Aktualisierung verweigerte. Die Lösung bestand darin, die IP des Slaves zur Konfigurationsdatei des Masters (named.conf.options) hinzuzufügen. Nach dieser Änderung scheint die Kommunikation wieder funktioniert zu haben. Es wird empfohlen, weitere Nachforschungen anzustellen, um die genaue Ursache für das Kommunikationsproblem zu ermitteln. Es wurde auch angemerkt, dass viele Zonen mit der öffentlichen Master-IP-Adresse eingestellt waren, was aus Leistungsgründen geändert wurde, obwohl beide Adressen funktionierten.
# *************** CLUSTER NUM ************:  1
# Die Supportanfragen umfassen die Aktivierung der KEN Mobile App, LDAP-Accounts für KEN-Benutzer, die Einrichtung von KEN-Signage mit einem Raspberry Pi, sowie die Anpassung der Notenbuchliste für Semester im "Grade Export Management." Es wird nach Anpassungsaufwänden und potenziellen Problemen bei alten Noten gefragt. Es gab Schwierigkeiten beim Import eines Enrollments, sowie Anfragen zur Kurs- und Lehrpersonendarstellung. Es wurden Probleme mit der Anzeige von Ferien im Stundenplan und dem Hinzufügen von Abstracts gemeldet, sowie IT-Updates durchgeführt. Zudem gab es Herausforderungen bei der Authentifizierung von Benutzern und der Synchronisation von Gruppen. In Bezug auf das IN2-System wurden Probleme mit dem Stundenplan-Editor und dem Zugriff auf Verwaltungsdokumente verzeichnet. Es wird empfohlen, deaktivierte Benutzer zu löschen und die Synchronisierung zu wiederholen, sowie Untersuchungen bzgl. DNS-Problemen durchzuführen.
#
#
# ********  2  ******* TOTAL TEXT
# The technical support ticket is related to unlocking the KEN module MBA 1127666. The following modules are mentioned: Basis AP 001, Basis AP 002, MATAR, IU, Micropage, Stundenplan AP 004, Absenzenerfassung AP 005, Absenzenprozesse AP 006, Newsletter AP 009, and Elektronisches Klassenbuch AP 010. The ticket indicates that most modules are ready, and the next step would be the specific configuration. Links for MATAR, Micropage, Newsletter, and the Elektronisches Klassenbuch are provided. The status of each module is listed as "ok." Summary of technical support tickets:
#
# 1. The staff at KS Stadelhofen's secretariat is unable to print in A3 format on printer PRINT002 KST TA3508ci TASekretariat42 as they do not have the necessary permissions to change settings. They have requested assistance in enabling A3 printing on the printer.
#
# 2. There was an issue with the printer driver causing problems with printing options. The driver was replaced, and the printer was reconfigured for Stefanie Graf, Marion Sawires, and Kai Homberg as standard users. Further testing was requested.
#
# 3. The printer disappeared from the system and manual retrieval only allowed basic printing functions without any advanced settings like double-sided printing or brochure printing. The printer also started printing gibberish characters. A solution was urgently requested as they rely on the printer.
#
# 4. Troubleshooting continues with attempts to resolve the A3 printing issue, but the output on A3 paper remains in A4 size. It is speculated that the problem may lie with the printer driver, and on-site assistance or a different approach may be needed to address the situation.
#
# Overall, these tickets highlight persistent challenges with printing settings, driver management, and printer functionality that require thorough investigation and troubleshooting to provide a resolution for the users. Summary of Technical Support Ticket:
#
# - The requester is asking for access to the KEN Stage platform for the following individuals:
#   - School Management: Moritz Spillmann, Patricia Eichholzer, Dominique Fluri
#   - Admin Rights: Silvio Stucki, Daniela Schwarz
#   - Secretariat: Marisa Ley, Yolanda Hug, Brigitte Egger
#   - IT Team with Admin Rights: Gregor Lüdi, Marco Zanoli, Mac Baumgartner, Rintsen Deshar, Benjamin Stocker
#   - Timetable Team: Oliver Nideröst
#   - Absences: Christian Clerc, Peter Deller
# - The requester also mentions that they will address this matter the next day.
# - They mention that KEN is not using IN2 yet, so they can directly test and configure without any issues and delete test data afterward.
# - Transferring all settings from Stage to live will be a complex task.
# - All mentioned individuals are booked in for testing on the IN2 platform. The technical support ticket is related to the re-engineering of templates for a specific project. The templates need to be updated for Jahrespromotion Semester 9 (JZZ) and 10 (JZ) and PZ with SZ, and should be generally usable for all types of certificates. There is a special case mentioned for a warning letter without a decision in ZZ or JZZ. The focus is on mapping immersion for certificates and letters, displaying subjects with subcategories, resolving issues with Zeugnisadministrator ZZ, JZZ, JZ, and handling Bio Ch SP and PAM. Additionally, there are specific options listed for the templates such as zeugniskopf, 2. Vorname, Unterfächer anzeigen, Statistikblock Kompensationszahl, and a time schedule starting in February. The ticket also mentions testing and feedbacks from KSH, KZN, KST, and communication tasks related to letters. Lastly, there is a link provided for a Kanban board for task management. Summary of Technical Support Ticket:
#
# - User: Uwe Christian from Kantonsschule Stadelhofen
# - Request: Assistance with updating Zimbra during the sport holidays
# - Assigned IT Technicians: Roger Leemann and Peter Haslebacher designated as Zimbra administrators
# - Issue: Technicians can log in to ZimbraAdmin but cannot see accounts or check settings, may require additional permissions from Gyselroth
# - Feedback from Servicedesk: Technicians are listed as admins in Zimbra management
# - Additional Information: Provided contact details and instructions for displaying images in Outlook
#
# Action Required:
# - Investigate and resolve permissions issue for technicians to access Zimbra accounts and settings Summary of Technical Support Ticket:
#
# - Sender (Laszlo Cseri) is experiencing mail delivery failure when sending emails to info@mkw.ch.
# - The error message indicates that all hosts for 'mkw.ch' have been failing for a long time.
# - The issue seems to be related to mail server problems either with Zimbra or the recipient's mail server (mkw.ch) or DNS issues with mkw.ch.
# - Laszlo is seeking confirmation that the problem does not lie with Zimbra and requests assistance in resolving the issue.
# - Laszlo mentions previous similar problems and asks for confirmation if the issue is not with Zimbra.
# - Andreas Stüssel from the Education Department of the Canton of Zurich suggests checking with MXTOOLBOX and possibly blocking the site in the cantonal network.
# - Laszlo mentions that the Zimbra system is not the cause of the issue as the error is generated at a later stage.
# - Laszlo suggests that if mkw.ch servers are unreachable, the only solution is to wait and try again.
# - Feedback is received that the website of mkw.ch appears correctly despite the email delivery issue. Summary:
# The email thread involves requests to update the QR IBAN for invoices from a Postkonto to a GKB Konto to save on fees. Regina Just Brodbeck asks Alexander Gysel to make the necessary changes, with Renata Meli as the contact person. Cornelia Camathias also sends a request for Renata to switch the QR IBAN from the Postkonto to CH12 3077 4130 1804 7820 0 on the ZAP and BKS system. Both stressed that the account holder's name remains the same, and there should be minimal reprogramming needed. Cornelia provides contact information for further assistance. Summary:
# - Srikanthan is requesting feedback on an email regarding the migration of the Berufsschule für Detailhandel und Pharmazie Zürich (BSDPZ) to the LEUnet network in April.
# - He needs read access for the Swisscom Bind User to the school and requests the creation of a new account for wifi access.
# - Srikanthan also asks for verification of user rights, school groups, and network configurations that the school will be using.
# - He provides the school code "dhz" and the WiFi username "wifi schulclient.dhz".
# - The school has various groups set up for admin, management, teachers, students, etc.
# - Srikanthan mentions that the responsible person will be available next week for further inquiries. Summary of Technical Support Tickets:
#
# 1. Ticket #1126793:
# - Issue: Printer "TA UTAX 3508ci vdi" is missing for Marion Sawires and Fiona Schmid.
# - Attempted resolution: Replaced the driver and re-added the printer. Test page printed successfully.
# - Follow-up needed: Printer disappeared from the system, manual retrieval is possible but functionalities like double-sided printing are not working. Printer currently only prints hieroglyphs. Urgent solution required, as the issue was reported on 20/02.
#
# 2. Ticket #116168:
# - Issue: Standard printer settings reset overnight, causing ongoing printer troubles at Kantonsschule Stadelhofen.
# - Users affected: Stefanie Graf, Kai Homberg, Fiona Schmid, Marion Sawires.
# - Request: Investigation needed as double-sided printing is not functioning properly. Summary of Technical Support Ticket:
#
# - School: Kantonsschule Zimmerberg
# - Reporter: Daniel Stucki
# - Student: andreas.simek
# - Issue: Unable to reset Intranet password for student andreas.simek
# - The student is new to Kantonsschule Zimmerberg
# - The error has been confirmed by the Service Desk
# - The user andreas.simek has not changed their initial password yet, so the admin cannot overwrite it. Summary of Technical Support Ticket:
#
# - Request: Create VM Ware Horizon VDI access for Martin Weber similar to Marco Bieri.
# - Action Taken: Marco Bieri was not found, so Max Hoellstin was used as a template for Martin Weber.
# - Status: User has been successfully created with almost all rights on the database and IM, including administrative rights for all schools.
# - Information: Individual and bulk letters were not added to IM as it was not deemed necessary unless absolutely required.
# - Note: There is currently no form available for MBA members, so duplicating the marco.bieri user was done without a form.
# - Additional Note: The order form is not available in this case. Summary:
# - Issue reported: Emails could not be sent or received via Zimbra server at Kantonsschule Rychenberg.
# - Request for urgent resolution was made by Andreas Berger and Reto Nutt.
# - Subsequent update mentioned that Zimbra at Kantonsschule Rychenberg is now functioning.
# - Ticket number: MBA 1126895, Incident 116304.
# - User feedback requested detailed information for future reference to help diagnose and resolve similar issues efficiently. Summary of ICT Support Ticket:
#
# - The ICT team has renewed their certificates and requests all suppliers and partners to update the new certificate provided in the email attachment for their applications.
# - The new certificate is needed for the site notenbuch.kvzschule.ch.
# - The password for the certificate will be received via SMS on 0041793533775.
# - Confirmation of the update is requested via email.
# - Roger Heid, the Senior System Administrator, confirms that the certificate has been updated.
# - Dani mentions that they have not received the password via SMS yet.
#
# Additional Information:
# - If the email was received in error, recipients are requested to delete it and inform the sender immediately.
# - Contact details for Roger Heid: rheid@kvzschule.ch, phone: +41 44 444 65 73.
# - The email includes confidential information. Summary: Karin Grob has requested to protect a folder named "Personal" in the Sekretariatsordner S to ensure that confidential data remains secure. She has asked the IT team to implement the protection or provide guidance on how to do so. The suggestion is for Karin to create this folder in her Home H drive to ensure it is automatically restricted to her access only. It is noted that no special permissions are set on the shares S, R, T, P. Summary of Technical Support Ticket:
#
# - User Stefan Montalta is unable to change his initial password after initial login.
# - Error message "Der Benutzer wurde auf dem Zielsystem nicht gefunden" (The user was not found on the target system) is appearing.
# - Initial password change requirement has been disabled to allow user to login.
# - The issue seems to be originating from the UCS (Univention Corporate Server) where the user with UID stefan.montalta is not found.
# - Multiple attempts have been made to resolve the issue, including manual intervention by IT staff and verifying LDAP configurations.
# - The user's access is crucial for teaching purposes, as mentioned by Stefan Montalta.
# - Different systems involved include UCS, O365, and local school systems.
# - It is suggested to clarify in which target system the user is missing for password change.
#
# Further actions needed:
# - Confirm the correct target system for password change.
# - Ensure proper synchronization between systems.
# - Check for any conflicts due to previous user configurations.
#
# Overall, the issue of password change for user Stefan Montalta across different IT systems needs to be resolved urgently to facilitate his access for teaching. Summary:
# - School: Kantonsschule Zimmerberg
# - Person reporting issue: Daniel Stucki
# - Issue: Unable to use the function "Vom Unterricht abmelden" (student absence) in the Intranet. After selecting the affected lessons, an error message appears saying "Es fehlen die nötigen Konfigurationen" (necessary configurations are missing).
# - Confirmation of issue by the Service Desk.
# - Request for investigation and feedback.
# - Contact information: Andreas Stüssel at Bildungsdirektion Kanton Zürich.
# - Reference to a specific example attached.
# - Mention of the issue being experienced by multiple schools.
# - Request to check for missing configurations. Summary:
# - Peter Haslebacher from Kantonsschule Stadelhofen was unable to send an email to all students, teachers, and staff.
# - The email addresses were sourced from the intranet, but there were errors such as "faulty email address."
# - Despite attempting to send the email to different groups separately, the issue persisted.
# - It is suggested to investigate the cause of the error and how to prevent similar issues in the future, possibly by using the newsletter module for sending emails individually and generating error reports.
# - Andreas Stüssel from the Digital Service Center Sek II suggested checking if the issue is specific to one user (Andreas Huessy), verifying if mass emails work for other users, and trying to send directly from the intranet. Summary:
# - A request was made to create two VDI user accounts for the Realgymnasium Rämibühl school in Zürich.
# - The accounts were successfully created.
# - The school requested to remove four users from the licensing list in order to accommodate the two new VDI users, bringing the total to 14 users.
# - User management will be automated starting next week, allowing schools to directly control access.
# - Confirmation was given to proceed with the additional costs for 11 new desks.
# - A list of 18 users for the school KRR was requested, noting discrepancies in the number of users currently accounted for. Summary of technical support ticket:
#
# - Andreas needs access to view the reservations of KUS rooms.
# - BFSU is responsible for renting out rooms at BZU, so Andreas should be able to see the occupancy of all KUS rooms, including the Music room.
# - Andreas wants to be able to view room reservations, including the exchange of rooms 071 and 072D with KUS.
# - The KUS will create test accounts for Andreas to access room reservations.
# - Andreas wants the solution to involve creating guest accounts for Martin Landolt and Christine Kramer.
# - There is a discussion about creating a general test account or setting up accounts for specific individuals.
# - Andreas currently has visibility to some BZU rooms and vice versa, but he requires more access specifically to room reservations 071D and 072.
# - An alternative solution suggested is to register Andreas as a guest at KUS to allow him to view any rooms. Summary of Technical Support Ticket:
#
# - User KSH MBA 1127411 is requesting access for the admins of KSH to the "SuS Absenzen" area in the Konfig Editor.
# - Power users need more access permissions to work autonomously, especially in relation to the Student Absence Integration.
# - Markus suggested delegating the configuration of Student Absences to the Power Users (PU).
# - It is recommended that the Application Owners of both applications, Yvonne and Nicole, decide on granting additional access permissions.
# - The PU Markus.killer now has access to configure Student Absences, suggesting that the role PU Intranet would be useful for such settings.
# - Discussion is needed on introducing new roles within the IM role class. Summary of technical support ticket:
#
# - The user Dani requested access for Fiona Schmid (email: fiona.schmid@ksstadelhofen.ch) to IM.
# - Uwe Christian from the IT team confirmed that Fiona Schmid has been granted access to the IM.
# - It is noted that Fiona Schmid still needs to change her initial password. Summary of technical support ticket:
# - Request to set up a new profile "PPP" for KSH KHO on the IM DB including basic configuration for the upcoming school year 2024-25.
# - Planning to start building the class schedule by the end of March or beginning of April.
# - Confirmation of profile creation and initial setup of subject sort order done by Daniel Weber.
# - Additional request for another PPP order from Daniel Weber is expected to follow. Summary:
# Several schools are experiencing issues with the tos.tam.ch server, preventing them from sending or receiving emails and accessing webmail. Affected schools include KS Zimmerberg, KS Stadelhofen, and KS Rychenberg. Error messages from KS Zimmerberg are attached. The Education Directorate of the Canton of Zurich's Digital Service Center Sek II is working on resolving the issue, which seems to be related to a problem with one of the proxies. Some users may still be affected, so further investigation is needed to identify specific affected users. Ticket Summary:
# - Issue: Notenbuch Klassenbezeichnungen anpassen (INC 205140)
# - Problem: Students assigned to multiple classes are displaying additional class information instead of the main class.
# - Proposed Solution: Consider only transferring relationships to main classes in the interface file.
# - Additional Information: Technical steps needed for adjustment include modifying the exporter, mapping, and imports.
# - Communication: Several email exchanges regarding the issue and potential solutions.
# - Actions Needed: Verification and potential adjustments to display the correct main classes for students.
# - Priority: Normal
# - Status: Feedback needed
# - Assigned to: Stefan Clenin
# - Begin Date: March 4, 2024
# - School: All Schools
# - Files Attached: image002.jpg (19.3 KB) Summary of Technical Support Ticket:
#
# - Request: Reconfiguration of KWI Absence Management system with the addition of Student Absence and Dispensations modules.
# - Requester: Franz Ferdinand Lehnert
# - Action taken: Two sub-tickets were created for Carlo and Marius, who are knowledgeable about these modules.
# - Current status: Both modules are ready. The Dispensations module requires activation and integration into the navigation.
# - Next steps: Set up the modules, preferably on the live system, for Franz to later transfer to the staging environment for presentation.
# - Contact details: Franz Ferdinand Lehnert, developer at gyselroth.
# - Date and Time: 04.03.2024 11:20 Europe/Zurich timezone. Summary of the technical support ticket:
#
# - The Kantonsschule Limmattal is experiencing an issue with their Zimbra email system.
# - A user named Regula Damman is not receiving emails from a distribution list, even though she is correctly included in the distribution list.
# - Regula Damman has reported that she is not receiving emails she sends to herself or emails sent to all teachers.
# - The issue seems to be related to Zimbra delivering identical emails to a recipient only once, which is considered normal behavior.
# - The support request is asking for assistance in resolving this issue and ensuring that Regula Damman receives emails from the distribution list and her own emails.
#
# Additional information:
# - Contact details: Nicola Balzano, Kantonsschule Limmattal, Rawinder Singh at Kantonsschule Limmattal Informatikdienste.
# - Dates: Issue reported on 01.03.2024 by Regula Damman.
# - Communication mentions the involvement of the Digital Service Center Sek II at the Bildungsdirektion Kanton Zürich. Summary of technical support ticket:
#
# - User is experiencing an issue with password change for 'SK Mitglied' in a specific system.
# - Error message indicates "Zielsystem nicht gefunden" (Target system not found).
# - Service desk feedback indicates that the target system is the own AD (Active Directory) and the vendor cannot assist externally.
# - Internal investigation reveals that the AD is not the target system causing the login issue.
# - Feedback from Manuel Prukner states that SK members are no longer synchronized in the AD since July 21, 2023, due to exclusion from IM AD Sync.
# - Manually deleting SK members from the AD was done as instructed.
# - New users are facing problems with initial login and password change regardless of their AD status.
# - Instructions are given to Manuel to manually delete or deactivate specific users and groups from the AD.
# - Andreas Stüssel inquires about proactive communication with the school and requests information once the password change for SK members is functional.
# - Communication issues are noted, and the need for implementing an exception for password change for SK members is highlighted.
# - Temporary solution: password change requirement for SK members has been lifted, allowing them to use their initial password for login. Summary:
# - Adjustment of FF (Forschungsfelder) invoices needed at KZN due to students being taught 2 weeks less because of relocation to Irchel.
# - Request is to change the FF IU (Forschungsfelder Individualeinheiten) invoices for all 576 units from 640 to 576 weeks.
# - Mention of moving to new location Irchel leading to changes in the billing cycle.
# - Proposal to adjust invoices centrally through GR system if possible.
# - Mention of IU courses still needing adjustments in SAP system.
# - Correction was made, and invoices were exported with the new amount.
# - Patrizia Prestigiacomo scheduled to initiate the billing process on 12th March at around 10 am.
# - Two solutions proposed: 1) Adjust the billing amount manually before running the export job. 2) Create a new cost carrier with CHF 576 for the IU courses.
# - Giusi prefers the first solution and will provide further updates. Summary: The user has requested a VDI account creation but there seems to be a problem with providing access to the Dossier folder at KZI. The user account was created without access to the Dossier folder, which is only available for the Sekretariat team for Frau La Sorte. Summary: The user Caren, who was the deputy headmistress at LG until the sports holidays, is no longer part of the school management but still responsible for the NAMs. Her VDI access needs to be adjusted by removing access to Drive R while maintaining access to Drives S and IM. The requested adjustment has been made by removing access to Drive R. Issue: Role "Gast" does not have access to the timetable IN2.
# Resolution: Added the group "guest" to the system default timetable, allowing users in the "Gast" role such as alberto.arribas to access the IN2 timetable. Now the class schedules are visible for alberto.arribas. Summary of Technical Support Ticket:
#
# - Sender: Kaspar Jost from Kantonsschule Belrain
# - Issue: Emails sent from kbw.ch addresses to gmx.ch addresses are generating error messages indicating delivery failure
# - Error Message: Server error 554 5.7.1 - Relay access denied
# - Requested Investigation and Feedback from incident history related to Email Problem with gmx Addresses
# - Mention of delays in email communication and reference to communication through the official school address
# - Received feedback from the school with delays in responses to emails sent to levini.zachi@gmx.ch
# - Mention of a successful KBW to GMX email delivery one hour later indicating a possible temporary issue with GMX
# - Question raised regarding whether the issue is an isolated incident or a systematic problem
# - Inquiry about the origin of the specific email on the Zimbra Web or Mailclient platform
#
# Additional information includes informal communication exchanges regarding closing the ticket, humorous responses, and references to email communication protocols and visual aids provided. Summary: The email forwards a request for new VDI access with the addition of a new user, KS B elrain, made by Kushtrim Veliji from Bildungsdirektion Kanton Z rich. A new account has been successfully set up and authorized accordingly. Summary:
# - Various security groups at BBZ did not synchronize with Active Directory.
# - Many teachers and students currently do not have licenses due to empty groups.
# - Issue was resolved, users are now assigned to role groups and should have licenses.
# - Group "L BI SEK2 02 Student PR WB" still has no members due to missing relationships in Eco Export.
# - Problem stemmed from data import from Eco Export where relationships were not correctly read.
# - Import process has been adjusted to prevent similar issues in the future.
# - Issue appears to be resolved according to the response provided by Sandro. Summary of Technical Support Ticket:
#
# - Requester: Thomas Brändli on behalf of Dominic Kleiner
# - Request: Increase mailbox size for dominic.kleiner@kbw.ch
# - Initial request made on 15.03.2024 at 16:22 by Dominic Kleiner due to mailbox nearing capacity after 3 years.
# - Digital Service Center Sek II confirmed receipt of request and forwarded it to the appropriate team.
# - Follow-up response from Digital Service Center Sek II on 15.03.2024 at 16:34 confirmed that the quota has been increased.
# - Acknowledgement of the request and appreciation expressed for the patience.
# - Contact information provided for further assistance.
#
# Requested Action: Mailbox size increase for dominic.kleiner@kbw.ch. Summary: The urgent ticket concerns an issue with scanning using PaperCut at KRW. Users are getting automatically logged out when trying to initiate a scan. This problem has occurred before and was supposedly resolved. The request is for KRW to test the scanning functionality again and provide feedback on whether the issue persists.
#
# Ticket details:
# - Issue: Scanning not possible in PaperCut
# - Ticket number: MBA 1128526
# - Previous ticket reference: https://ticket.gyselroth.net/issues/116230/change/265162
# - Resolution request: KRW to test scanning functionality and provide feedback
#
# Support team members involved:
# - Alban Trolli
# - Janosch
#
# Action required: KRW to test scanning and provide feedback. Summary:
# - A new VDI user, Leonardo Wild, has been created with the desired permissions.
# - The school, specifically Bojan Golubicic, may not have been aware of the new process which has been in place for approximately 3 weeks.
# - Everything is now ready from the KRL side.
# - The school needs to first designate the user as a VDI user by setting a keyword. Subsequently, the desired permissions will be granted. Summary:
# A user named Gael Jauch from Kanton Zurich's Bildungsdirektion reported an issue with the SSL VPN configuration client for user emanuela.lasorte.kzi. The user was unable to download the client as the "VPN" option was missing. Martin Hoechli, from the Digital Service Center Sek II, provided feedback on the ticket and mentioned that a permission needed to be added for the user. He also advised using "emanuela.lasorte" as the username instead of "emanuela.lasorte.kzi" as only MBAZH users are VPN authorized. Instructions were given to test the configuration again with the correct username. The incident was opened on March 19, 2024, and is currently in the feedback status. Two users, Roman and Stephan Looser, have requested access to the IN2 database. Roman asked for IN2 DB Zugriff for Stephan Looser to be granted, while Stephan himself asked for direct access to the IN2 database. It appears that Stephan's access has been partially set up with read access to the account "stephan.looser.kzo" on the "kzo" system, but his mobile number is needed for setting up the password. Summary of the technical support ticket:
#
# - The user requested access to the Information Manager (IM) server for testing purposes using an EDU test account.
# - They provided the details of the test user: Name - Robert TestteachB, UPN - robert.testteachb@edu.zh.ch, sAMAccountname - E0101444.
# - Requested access for the test user to the User Homelaufwerk and any test data storage on the file server with IM templates.
# - Asked for access to the IM Testschule for the test user.
# - The user, Simon Grünwald, expressed gratitude for the quick activation of the access and mentioned contacting for further steps.
# - Simon provided contact details and organizational information from the Bildungsdirektion Kanton Zürich.
# - It was stated that the test user now has access to the DB ZZZ on the DB004.mbazh.ch server and is in the necessary groups for accessing the shared resources for ZZZ.
# - Asked for assistance in assigning the test user to the appropriate groups in the OU ZZZ. Summary:
# The KRR IT technicians reported that MS Office accounts stopped working on 18.03. The issue was found to be related to the AD security group "L BI SEK2 2130 Secretariat" in the local AD of KRR, resulting in license removal. Despite manual re-addition of the group, it kept disappearing. The problem was resolved by granting admin rights to the bind user and manually inputting proxy addresses for affected users. The users should actually be members of the "L BI SEK2 2130 Personal" group, but there are permission issues preventing the AD sync user from making changes. To circumvent this, manual proxy address updates were suggested. In the future, ensuring the bind user has necessary permissions for user management in AD is advised. Summary:
# - The Kantonsschule Wiedikon has a request for a layout adjustment on their Typo 3 website for mobile devices for a video uploaded on the website.
# - The contact person for previous adjustments was Noemi Schmid.
# - The school now requests contact with Mr. Philippe da Silva Wong at 044 457 71 53 to discuss the details.
# - Urgent response is needed as the ticket has been waiting for a reply since 27.02.2024.
# - Contact details provided for follow-up: Kushtrim Veliji, Bildungsdirektion Kanton Zürich, Phone 043 259 77 27.
# *************** CLUSTER NUM ************:  2
# Multiple technical support tickets and requests are summarized, including unlocking and configuring various modules, printing issues with missing permissions on printers, KEN Stage platform access requests, Zimbra email server problems, certificate and letter template updates, password change issues, VDI access requests, and various system configuration and access issues. Other mentions include email delivery problems, invoice adjustments, permission synchronization errors, SSL VPN configuration challenges, and layout adjustments for websites. The ongoing support involves troubleshooting and resolving a wide range of technical challenges across different departments and schools in Kanton Zurich.
#
#
# ********  5  ******* TOTAL TEXT
# Summary:
# - The issue is related to the inability to delete or strike off blocks in KST MBA 1125513.
# - When trying to strike off a block, the window opens, the "Block striken" button can be clicked, but the window closes and the block remains unchanged.
# - The problem may be linked to Incident 116149.
# - Reservation functionality is restored, but modifying vacation blocks remains problematic.
# - Corrections were made on the live and staging environments.
# - A specific holiday block with HolidayID 132 (Karfreitag) cannot be deleted, potentially due to someone making changes to the schedule.
# - Further investigation is required to understand why the block cannot be deleted. An error occurred: This model's maximum context length is 16385 tokens. However, your messages resulted in 19043 tokens. Please reduce the length of the messages. Summary: Cornelia requested entries to be added to the IU table in the SubjectMapping table of the IN2 database. Roman also mentioned the request and asked for the entries to be added if he didn't have the necessary permissions. The additional entries have been made. Summary:
# - User reported duplicates of classes 1a, 1b, 1c, 3c in the IN2 database.
# - User could not find classes with IDs 1320, 1321, 1322, and 1328 in IM or the database.
# - Suspected that classes were deleted and recreated after a semester change.
# - Requested assistance in deleting the duplicate classes.
# - Support team confirmed duplicate classes were deleted and closed the ticket. Summary: The user is requesting a name change in the Balloon system due to a user getting married. The old name was "lea.naegeli" and the new name should be "lea.buchmann." The user has already updated the name in other systems like IM and Zimbra and is requesting the Balloon username to be changed to "lea.buchmann.krw." The name change has been successfully completed. Summary of Technical Support Ticket:
#
# - Request from Roman to add a subject to the mapping table for KKN with SubjectID 313, SubjectTypeID 19, and SubjectShortNameUntis WK WR and WK.
# - Confirmation from Cornelia that the entry has been created with the requested information. Summary of technical support ticket:
#
# - Request for new access for user annina.naef at KZU school, forwarded by Andreas Stüssel.
# - Password reset was done due to a typo by Martin.
# - New password provided: vdi4XXXZZ, where XXX represents the school initials and ZZ represents the first letters of the first and last name.
# - User annina.naef has been created as requested by Martin. Summary: The user is requesting the setup of a VDI service account for a specific purpose related to scanning to a folder in the VDI environment. The current process requires individual logins for each scan, causing delays. They need a general login with write permissions only to a specific folder. They provided details of the MFD device where they want to set up a general user for scanning purposes. The user has requested the setup of a login named "scan2folder krm" and provided contact information for sending the password separately. Summary: The request is to delete the VDI user account "asja.dinkelmann" associated with the KWI location as the user's account had already been deactivated. Summary:
# - Some admins at BBZ have access to the Table Editor while others do not. The request is for all admins to have access.
# - Additional admins who should have access to the Table Editor are listed.
# - All administrators are now authorized to access the Table Editor. The ACLs can be found under the "pre" backend ACL system.
# - There is a question regarding whether all new admins in the future will automatically have access to the Table Editor or if they need to be reported. It has been implemented as requested. Summary:
# - Task: Set up NAM functionality for KFR.
# - Request: Configure NAM functionality for Intranet use and prepare for data capture and synchronization.
# - Status: Data export and NAM registration successfully completed, but data capture still pending. Summary of Technical Support Ticket:
#
# 1. Issue: SLK Login option visible for Administrators on BBZ Logout Button. Users cannot log in but the visibility is undesirable.
#    Request: Remove SLK Login option from the Logout Button for Administrators.
#
# 2. Updates:
#    - SLK Login option successfully removed for all schools on live environment.
#    - Removed SLK Login entry from Meta Navigation on the top right side in the stage environment.
# ...
#
# The user is reporting an issue with attaching files to open applications. Despite being able to attach any number of files in the application, only 3 attachments are showing up in the open applications. They are requesting to increase the number of attachments from 3 to 5 and add a hint or error message when exceeding the maximum number of attachments. Another user confirms that the issue has been resolved on their end. They request more details and screenshots to understand the situation better and inquire if there has been an update regarding this issue. Additionally, there is a discussion about the technical reasons for the 3-attachment limitation and whether increasing it to 5 is feasible. Summary:
# - Thomas requested the removal of a Group Policy Object (GPO) that sets the server citrix.mba.ktzh.ch for users in Citrix Workspace.
# - Martin acknowledged the request and made adjustments to the GPO as requested.
# - There was an overlap with another GPO, which Martin also updated to remove citrixSEKII and add citrixDSC.
# - Thomas confirmed that the changes were made successfully.
# - However, there was an issue where the old Citrix environment (citrix.mba.ktzh.ch) was still present instead of the new environment (citrix.dsc.ktzh.ch).
# - Multiple users reported the problem, and GPOs were checked and linkages removed. Confirmation of successful resolution was requested. Summary:
# - The BZU wants to adjust and expand its disciplinary processes to include BM2.
# - They have provided an updated Excel file and two new email templates for these processes.
# - They request that the processes be set up on the Stage environment, run every 3 minutes, and grant access to andreas.corazza.
# - Testing of workflows on Stage is recommended, with possible revisions needed for class filters in the Excel file.
# - Corrections have been made in the Excel file for the wrong template in the Ermahnung disciplinary process.
# - Missing email templates for the workflows "weitere Disziplinarmassnahme Verweis" and "Direkter Verweis" in the Excel file need to be addressed.
# - A check is needed to determine if the templates "wfm ermahnung disziplin bzu.docx" and "wfm verweis disziplin bzu.docx" are still required.
# - A missing email template for the process step "Mail" in the workflows "weitere Disziplinarmassnahme Verweis" and "Direkter Verweis" needs to be resolved. Summary of technical support tickets:
#
# 1. Susanne Flury is experiencing access issues with the Stage system at stage.tam.ch. It seems that her password is not working despite it supposedly being the same as last week. There is no record in Redmine of her being granted access to Stage previously.
# 2. Susanne requested the IT team to provide her with access credentials for stage.tam.ch as she is unable to log in with the information she has. Password reset attempts have been unsuccessful.
# 3. The requirement for a password change has been removed for Susanne, and the attribute tamResetPassword has been set to FALSE for her account, susanne.flury.krm.
# 4. There was a request to set the password reset attribute to FALSE for Susanne as the requester was unable to access the dev LDAP.
# 5. Susanne was not previously authorized for Stage access, but now she has been granted permission to try again.
#
# Overall, Susanne has been experiencing access issues with the Stage system, and the IT team has been working to resolve them by adjusting account attributes and permissions. The ticket is regarding vulnerabilities found on the website. The user, Oliver, has identified two vulnerabilities - Clickjacking and Email Spoofing. Clickjacking involves tricking users into clicking on elements unintentionally, potentially leading to malicious actions. The recommended fix for Clickjacking is implementing a X-Frame-Options header. For Email Spoofing, it is advised to publish a DMARC record and enable a Reject policy to prevent spoofed emails. Oliver is requesting a bounty reward for their responsible disclosure of these vulnerabilities. Additionally, Oliver has provided references and examples for both issues. Summary:
# - The user requests the immediate cancellation of 3 VDI accesses.
# - The VDI Automat is now operational, with a process in place to deactivate users within 10 days and delete them within 30 days automatically.
# - The automated process did not deactivate the specified users, so the request is to manually disable them.
# - Moving forward, user generation and deletion will be automated, with only rights assignment requiring manual intervention. Summary:
# Users are noticing that some former students are still appearing in the general information management (IM) interface with an "akt. Klasse" designation, even after their exit. This issue has been observed since 2020. It seems that the field res12 retains a value for former students, as the nightly procedure to clear it is not executed for those individuals. It is suggested that the res12 field could be removed from the interface as a cosmetic solution. The problem may lie with how persons are managed in the system, possibly related to handling exits and templates at other schools. The situation raises concerns about the accuracy of displayed information and potential confusion when searching for students by name. Two users, Roman and Daniel Stucki, reported an issue where a student named victor.demouchy was unable to log in to Enrollment due to missing dropdown fields for priority selection. This occurred after the student switched classes from 6b to 5b about a week ago. The problem was experienced in both Chrome and Firefox browsers. However, the issue resolved itself later on without any changes, possibly due to a configuration update or a browser effect. Roman confirmed the resolution and closed the incident ticket. Summary of technical support ticket:
# - Users are experiencing issues with the synchronization of absences entered in the KST mobile app to the IN2 web version.
# - Despite entering and confirming absences in the app, they are not reflected in the Intranet when opened.
# - The synchronization problem has been ongoing since January, as per the user's list of unconfirmed absences.
# - The user, Uwe, suspects that the issue may be related to the version of the app (1.8.0) or the Play Store account used for registration.
# - It was discovered that Uwe had entered data on a stage version of the app, not the production database, explaining why the data was not found in the DB.
# - There are concerns about whether the absences entered in the app are being written to the database correctly or if there is a cache effect causing discrepancies in data visibility and availability. Summary of Technical Support Ticket:
#
# - The users are reporting issues with synchronizing their Zimbra email with Outlook.
# - The problem seems to be related to ongoing Zimbra migration at KST.
# - There are temporary fixes in place, and users are advised that there might be interruptions until a definitive fix is implemented.
# - The connection with ActiveSync is currently working, but a ticket needs to be opened for a permanent fix.
# - An example of error messages related to syncing issues with Zimbra and Outlook is provided.
# - Support is requesting log files to investigate the root cause of the syncing problem between Outlook and Zimbra.
# - There is confusion regarding the different effects experienced by KUS (Exchange) and KST (Zimbra) users, and it is suggested that this could be a case for the DSC.
# - There is mention of potential separate tickets for KUS and KST users and uncertainty about which users are affected and in what environments. User "martin.ehrismann.krr" is reporting an issue with the "Inkosistenz App IN2" version 1.7 on an Android device. They are experiencing inconsistencies in the app related to enrolling in courses where only specific individuals are allowed. Despite proper access control lists (ACL) working in the IN2 system to restrict saving, users are still able to enroll in roles they shouldn't have access to in the app. The user expresses concern that this issue was supposedly fixed previously. The enrollment period mentioned runs until March 27, 2024. The user's email for contact is martin.ehrismann@rgzh.ch. Issue: Account thierry.lauper@stud.krw.ch blocked due to spam email sending.
# Resolution: The Zimbra account of thierry.lauper@stud.krw.ch was blocked for sending spam. The account has been reactivated. The user may receive bounce back messages, which can be deleted. The issue should resolve within one to two days.
# Note: Thierry Lauper has changed the password for the account. Summary of Technical Support Tickets:
#
# Ticket 1:
# - Users with a ksuster.ch email address can submit contact form data successfully.
# - External email addresses do not receive the form data, but it is stored in the CMS and users receive confirmation emails.
# - The issue seems to be related to how the email recipient field is configured.
# - It is suggested to check the configuration settings and potential spam filter or firewall rules affecting the reception of form data.
#
# Ticket 2:
# - Emails from forms with KUS email addresses are received, but those with private email addresses are not.
# - Despite receiving confirmation email, actual form data is not delivered.
# - The problem may lie with spam filtering rather than firewall restrictions.
# - The issue might be related to recipient settings and potential misconfiguration causing emails to be sorted or blocked.
#
# Ticket 3:
# - Some observations made related to the email recipient settings in the configuration.
# - Problems with multiple recipient email addresses and naming conventions.
# - Issues with emails being sent only to specific recipients and potential spam filtering or sorting.
# - Suggested reaching out to the mail server administrator to resolve email delivery problems.
#
# Overall, the common theme across the tickets is email delivery issues, possibly due to misconfigurations in the recipient settings and interactions with spam filters. Users are receiving confirmation emails, but the actual form data is not always reaching the intended recipients. It is recommended to review and adjust the email recipient configurations and consult with the mail server administrator if necessary. Summary of Technical Support Ticket:
#
# - User Nikola Jovanov is experiencing connectivity issues with the Exchange server to Zimbra, where emails cannot be received or sent.
# - Users are resorting to IMAP connection as a workaround, but issues persist even when using Zimbra Webmail.
# - The problem is impacting several users, including the SL (Service Level) team, making it crucial to resolve promptly.
# - Requesting high priority resolution to ensure emails can be sent and received effectively.
#
# Additional Note: The issue also extends to mobile devices. Summary:
# - The email sender, Dani, is reporting that the server is categorizing an email address as spoofing.
# - There is an issue with email delivery to a specific recipient, Simone Diezi, due to SPF failure.
# - The IT technician, Rawinder Singh, has identified a general problem with the mail server and is requesting a review.
# - The email includes details of the failed delivery message and relevant headers for analysis.
# - There is a suggestion to involve the O365 team in addressing the SPF failure issue. Ticket: DB004
# Issue: Backups are not being deleted after 3 days
# Resolution: A separate script has been set up to clean up backups older than 3 days for the Microsoft SQL Server MSSQL14.MSSQLSERVER MSSQL Backup job on DB004. The Maintenance Cleanup Task has been added to achieve this and backups older than 3 days are now being deleted successfully. Summary of technical support tickets:
#
# 1. User renee.mueller is present in LDAP with status "ResetPW True", but unable to log in as the account. There are discrepancies in Active Directory sync, causing uncertainty regarding the user's status. Further investigation is required to address the issue.
#
# 2. Former staff member Renee Muller requires access for current tasks. Although set to active in the system, there are issues with changing the password and the user seems to be missing from Active Directory. Errors in the sync process or overlooked details may be causing the issue. Additionally, the password complexity requirements were not met when setting the initial password. Further troubleshooting and adjustments are needed to resolve the situation. Summary:
#
# Users, specifically g teachers and g students, are experiencing an issue where the "Ihre Wahl" column is not visible when clicking on the Enrollment for elective courses for the Fall semester 2024/2025 directly after logging in. This issue is observed across all browsers and clearing cache and cookies did not resolve it. The problem is reproducible by logging in as a specific user and clicking on Enrollment, not seeing the column, then clicking on Home and going back to the same Enrollment to see the column. This issue does not occur for Admin users. Similar problems have been reported by other schools and a simple reload usually resolves the visibility of the column.
#
# It is noted that a video demonstrating the issue has been attached for reference. Summary of technical support ticket:
# - Carlina Capaul updated a meeting in Zimbra on March 15, 2024 which was accepted by Joanna Romer. However, on March 18, 2024, the old meeting appeared again in Zimbra.
# - The issue of old meetings reappearing after updates has been observed multiple times recently, causing inconvenience.
# - Logs do not provide clear indications of the problem, and it is difficult to reproduce the issue due to limited Zimbra logging.
# - Suggestions were made to delete the individual occurrence and set a new correct meeting to address the problem.
# - The provided calendar event details show an event related to VDI training in Zürich.
# - Further clarification and details are requested regarding the specific recurring meeting in question for troubleshooting.
# - Challenges with updating recurring meetings were mentioned, questioning if only individual occurrences were selected for modification. Summary:
# - The technical support ticket is related to an issue with sending and receiving emails through the Zimbra system for the school domain kslzh.ch.
# - Users reported errors and were unable to send emails, including to domains such as GMX and icloud.com.
# - An investigation revealed communication issues between the MTA and Edge Server, leading to email disruptions. The system is in End-of-Life status, so no further troubleshooting efforts will be made.
# - Subsequent updates confirmed that Zimbra is functioning properly again, allowing successful testing of email services.
# - A new issue was reported regarding the inability to send absences notifications through Zimbra, which is under investigation.
# - Other departments also reported similar email sending issues. Further inquiries were made regarding the impact on the domain it.mba.zh.ch.
# *************** CLUSTER NUM ************:  4
# Various technical support tickets were discussed to address a range of issues, including storage space notifications on the Abrechnungstool server, problems with new employee data exports, and complications with the deactivation process in EcoWeb. Additionally, challenges with Word files, login credentials requests, dispensations management, and reservation notes issues were highlighted. Furthermore, server storage usage investigations, server login problems, and performance upgrade requests were shared. Email delivery issues, technical problems with servers, security vulnerabilities, form data delivery concerns, and Zimbra connectivity challenges were among the reported issues requiring resolution. Lastly, issues with enrollment visibility and meeting update problems in Zimbra were also noted.

# %%
df_summaries.head()
# Out:
#    cluster_label  \
# 0              1
# 1              2
# 2              5
# 3              3
# 4              4
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             summary
# 0  Die Supportanfragen umfassen die Aktivierung der KEN Mobile App, LDAP-Accounts für KEN-Benutzer, die Einrichtung von KEN-Signage mit einem Raspberry Pi, sowie die Anpassung der Notenbuchliste für Semester im "Grade Export Management." Es wird nach Anpassungsaufwänden und potenziellen Problemen bei alten Noten gefragt. Es gab Schwierigkeiten beim Import eines Enrollments, sowie Anfragen zur Kurs- und Lehrpersonendarstellung. Es wurden Probleme mit der Anzeige von Ferien im Stundenplan und dem Hinzufügen von Abstracts gemeldet, sowie IT-Updates durchgeführt. Zudem gab es Herausforderungen bei der Authentifizierung von Benutzern und der Synchronisation von Gruppen. In Bezug auf das IN2-System wurden Probleme mit dem Stundenplan-Editor und dem Zugriff auf Verwaltungsdokumente verzeichnet. Es wird empfohlen, deaktivierte Benutzer zu löschen und die Synchronisierung zu wiederholen, sowie Untersuchungen bzgl. DNS-Problemen durchzuführen.
# 1                                                                                                                                                                                                                                                  Multiple technical support tickets and requests are summarized, including unlocking and configuring various modules, printing issues with missing permissions on printers, KEN Stage platform access requests, Zimbra email server problems, certificate and letter template updates, password change issues, VDI access requests, and various system configuration and access issues. Other mentions include email delivery problems, invoice adjustments, permission synchronization errors, SSL VPN configuration challenges, and layout adjustments for websites. The ongoing support involves troubleshooting and resolving a wide range of technical challenges across different departments and schools in Kanton Zurich.
# 2                                                                                                              The text discusses various technical support tickets related to system issues and user requests. It involves troubleshooting problems with system functionalities, such as deleting blocks in the KST MBA 1125513 system, technical setups like VDI service accounts for scanning, and configuration adjustments like adding subjects to mapping tables. Requests cover a wide range, from name changes and user access permissions to enabling features like NAM functionality and interventions like the removal of outdated information. Additionally, it outlines tasks for setting up and resolving issues with modules, containers, and documents across different systems, including Balloon, KWI, and IN2 databases. Communication between users, administrators, and support teams is detailed to address various IT-related tasks and system enhancements.
# 3                                                                                                                                                                                                            Multiple technical support tickets have been submitted related to various issues in different systems. These include problems with the IU schedule, absence workflow system, grading process, student enrollment, and data entry errors. Adjustments and tests have been conducted to resolve these issues, with a focus on accuracy in scheduling, grading, and absence tracking. Further investigations and testing are required for ongoing challenges, such as incorrect class entries, missing grades, and insufficient data transfers. Additionally, requests for profile creations, system updates, email adjustments, report generation accuracy, and document creation have been made, emphasizing the importance of functionality testing before deployment.
# 4                                                                                                                                             Various technical support tickets were discussed to address a range of issues, including storage space notifications on the Abrechnungstool server, problems with new employee data exports, and complications with the deactivation process in EcoWeb. Additionally, challenges with Word files, login credentials requests, dispensations management, and reservation notes issues were highlighted. Furthermore, server storage usage investigations, server login problems, and performance upgrade requests were shared. Email delivery issues, technical problems with servers, security vulnerabilities, form data delivery concerns, and Zimbra connectivity challenges were among the reported issues requiring resolution. Lastly, issues with enrollment visibility and meeting update problems in Zimbra were also noted.

# %%
# Now create the labels out of the summarized clusters
cluster_labels = {}

def generate_label_for_summary(summary):
    conversation = [
        {"role": "system", "content": "You are a highly capable technical consultant."},
        {"role": "user", "content": f"Create 3 one-word-labels, that describes the following summary: {summary}"}
    ]

    try:
        # Call to OpenAI's GPT-3.5 Turbo API using the ChatCompletion endpoint
        response = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            messages=conversation,
            max_tokens=40,  # Adjust based on desired label length
            temperature=0.3  # A lower temperature for more deterministic output
        )
        label = response['choices'][0]['message']['content'].strip()
        return label
    except Exception as e:
        print(f"Error generating label: {e}")
        return "Label generation error"

# Iterate over the DataFrame and generate labels for each summary
for index, row in df_summaries.iterrows():
    summary = row['summary']
    label = generate_label_for_summary(summary)
    df_summaries.at[index, 'label'] = label

df_summaries.head()
# Out:
#    cluster_label  \
# 0              1
# 1              2
# 2              5
# 3              3
# 4              4
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             summary  \
# 0  Die Supportanfragen umfassen die Aktivierung der KEN Mobile App, LDAP-Accounts für KEN-Benutzer, die Einrichtung von KEN-Signage mit einem Raspberry Pi, sowie die Anpassung der Notenbuchliste für Semester im "Grade Export Management." Es wird nach Anpassungsaufwänden und potenziellen Problemen bei alten Noten gefragt. Es gab Schwierigkeiten beim Import eines Enrollments, sowie Anfragen zur Kurs- und Lehrpersonendarstellung. Es wurden Probleme mit der Anzeige von Ferien im Stundenplan und dem Hinzufügen von Abstracts gemeldet, sowie IT-Updates durchgeführt. Zudem gab es Herausforderungen bei der Authentifizierung von Benutzern und der Synchronisation von Gruppen. In Bezug auf das IN2-System wurden Probleme mit dem Stundenplan-Editor und dem Zugriff auf Verwaltungsdokumente verzeichnet. Es wird empfohlen, deaktivierte Benutzer zu löschen und die Synchronisierung zu wiederholen, sowie Untersuchungen bzgl. DNS-Problemen durchzuführen.
# 1                                                                                                                                                                                                                                                  Multiple technical support tickets and requests are summarized, including unlocking and configuring various modules, printing issues with missing permissions on printers, KEN Stage platform access requests, Zimbra email server problems, certificate and letter template updates, password change issues, VDI access requests, and various system configuration and access issues. Other mentions include email delivery problems, invoice adjustments, permission synchronization errors, SSL VPN configuration challenges, and layout adjustments for websites. The ongoing support involves troubleshooting and resolving a wide range of technical challenges across different departments and schools in Kanton Zurich.
# 2                                                                                                              The text discusses various technical support tickets related to system issues and user requests. It involves troubleshooting problems with system functionalities, such as deleting blocks in the KST MBA 1125513 system, technical setups like VDI service accounts for scanning, and configuration adjustments like adding subjects to mapping tables. Requests cover a wide range, from name changes and user access permissions to enabling features like NAM functionality and interventions like the removal of outdated information. Additionally, it outlines tasks for setting up and resolving issues with modules, containers, and documents across different systems, including Balloon, KWI, and IN2 databases. Communication between users, administrators, and support teams is detailed to address various IT-related tasks and system enhancements.
# 3                                                                                                                                                                                                            Multiple technical support tickets have been submitted related to various issues in different systems. These include problems with the IU schedule, absence workflow system, grading process, student enrollment, and data entry errors. Adjustments and tests have been conducted to resolve these issues, with a focus on accuracy in scheduling, grading, and absence tracking. Further investigations and testing are required for ongoing challenges, such as incorrect class entries, missing grades, and insufficient data transfers. Additionally, requests for profile creations, system updates, email adjustments, report generation accuracy, and document creation have been made, emphasizing the importance of functionality testing before deployment.
# 4                                                                                                                                             Various technical support tickets were discussed to address a range of issues, including storage space notifications on the Abrechnungstool server, problems with new employee data exports, and complications with the deactivation process in EcoWeb. Additionally, challenges with Word files, login credentials requests, dispensations management, and reservation notes issues were highlighted. Furthermore, server storage usage investigations, server login problems, and performance upgrade requests were shared. Email delivery issues, technical problems with servers, security vulnerabilities, form data delivery concerns, and Zimbra connectivity challenges were among the reported issues requiring resolution. Lastly, issues with enrollment visibility and meeting update problems in Zimbra were also noted.
#
#                                                               label
# 0                             1. Support\n2. Anpassung\n3. Probleme
# 1                                   Diverse\nChallenges\nResolution
# 2  1. Technical Support\n2. Troubleshooting\n3. System Enhancements
# 3                    1. Troubleshooting\n2. Testing\n3. Enhancement
# 4                              1. Support\n2. Tickets\n3. Technical
